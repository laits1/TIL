# %% [markdown]
# 내기준 (QQQ-일봉)
#
#
#
# RSI 30이하 = 졸업 (주식100%)
#
# RSI 30~35 = 2차 매수 고려 (주식80%)
#
# RSI 40~45 = 1차 매수 고려 (주식60%)
#
#
#
# RSI 50은 중립
#
#
#
# RSI 60으로 오르면, 1차 매도 고려 (주식50%)
#
# RSI 70으로 오르면, 2차 매도 고려 (주식25%)
#
# RSI 80으로 오르면, 졸업 (주식0%)

# %%
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
def message(i) :
    print(f"==={i}일 째===")
    print(f"RSI         : {RSI.RSI[i]}")
    print(f"balance     : {balance}")
    print(f"{Ticker} 현재가 : {RSI['Adj Close'][i]}")
    print(f"qty         : {qty}")
    print(f"총 자산     : {balance + (RSI['Adj Close'][i] * qty)}")
    print("")

# %%
def cal(Ticker, start, end, balance) :
    
    
    global ticker 
    ticker = data.DataReader(Ticker,'yahoo', start, end)
    global delta 
    delta = ticker['Close'].diff()
    global up 
    up = delta.clip(lower=0)
    global down 
    down = -1*delta.clip(upper=0)
    global ema_up 
    ema_up = up.ewm(com=13, adjust=False).mean()
    global ema_down 
    ema_down = down.ewm(com=13, adjust=False).mean()
    global rs 
    rs = ema_up/ema_down

    ticker['RSI'] = 100 - (100/(1 + rs))

    # Skip first 14 days to have real values
    ticker = ticker.iloc[14:]
    global RSI 
    RSI= ticker[['Adj Close','RSI']]

    
    print(f"===0일 째===")
    print(f"RSI         : 0")
    print(f"balance     : {balance}")
    print(f"{Ticker} 현재가 : 0")
    print(f"qty         : 0")
    print(f"총 자산     : {balance}")
    print("")

    global total_yield 
    total_yield = []
    global qty
    qty = 0
   
    
    
    for i in range(len(RSI)) :
        total_yield.append(balance + (RSI['Adj Close'][i] * qty))
        
        if (RSI.RSI[i] <= 30) :
            qty += divmod(balance,RSI['Adj Close'][i])[0]
            print(balance - divmod(balance,RSI['Adj Close'][i])[0] * RSI['Adj Close'][i])
            balance = balance - (divmod(balance,RSI['Adj Close'][i])[0] * RSI['Adj Close'][i])

        elif (30 < RSI.RSI[i] <= 35) :
            qty += divmod((balance * 0.5) , RSI['Adj Close'][i])[0]
            balance += - (divmod((balance * 0.6) , RSI['Adj Close'][i])[0] * RSI['Adj Close'][i])

        elif (35 < RSI.RSI[i] <= 50) :
            qty += divmod((balance * 0.6) , RSI['Adj Close'][i])[0]
            balance += - (divmod((balance * 0.6) , RSI['Adj Close'][i])[0] * RSI['Adj Close'][i])

        elif (50 < RSI.RSI[i] <= 60) :
            pass
        
        elif (60 <= RSI.RSI[i] < 70) :
            qty += - divmod(qty,2)[0]
            balance += qty * RSI['Adj Close'][i]

        elif (70 <= RSI.RSI[i] < 80) :
            qty += - divmod(qty,2)[0]
            balance += qty * RSI['Adj Close'][i]

        elif (80 <= RSI.RSI[i] < 101) :
            balance += qty * RSI['Adj Close'][i]
            qty =0

        print(f"==={i}일 째===")
        print(f"RSI         : {RSI.RSI[i]}")
        print(f"balance     : {balance}")
        print(f"{Ticker} 현재가 : {RSI['Adj Close'][i]}")
        print(f"qty         : {qty}")
        print(f"총 자산     : {balance + (RSI['Adj Close'][i] * qty)}")
        print("")

# %%
# def message(i) :
#     print(f"==={i}일 째===")
#     print(f"RSI         : {RSI.RSI[i]}")
#     print(f"balance     : {balance}")
#     print(f"{Ticker} 현재가 : {RSI['Adj Close'][i]}")
#     print(f"qty         : {qty}")
#     print(f"총 자산     : {balance + (RSI['Adj Close'][i] * qty)}")
#     print("")

# %%
Ticker = 'QLD'
start = '2021-01-01'
end = '2021-10-10'
balance = 10000

# %%
cal(Ticker, start, end, balance)
# Out:
# ===0일 째===
# RSI         : 0
# balance     : 10000
# QLD 현재가 : 0
# qty         : 0
# 총 자산     : 10000
#
# ===0일 째===
# RSI         : 38.669661764258194
# balance     : 4007.824851989746
# QLD 현재가 : 61.775001525878906
# qty         : 97.0
# 총 자산     : 10000.0
#
# ===1일 째===
# RSI         : 42.18672537629623
# balance     : 1618.764892578125
# QLD 현재가 : 62.869998931884766
# qty         : 135.0
# 총 자산     : 10106.214748382568
#
# ===2일 째===
# RSI         : 42.47870219906929
# balance     : 674.3649063110352
# QLD 현재가 : 62.959999084472656
# qty         : 150.0
# 총 자산     : 10118.364768981934
#
# ===3일 째===
# RSI         : 35.256066314732024
# balance     : 316.94490814208984
# QLD 현재가 : 59.56999969482422
# qty         : 156.0
# 총 자산     : 9609.864860534668
#
# ===4일 째===
# RSI         : 37.27205666996734
# balance     : 136.4499053955078
# QLD 현재가 : 60.165000915527344
# qty         : 159.0
# 총 자산     : 9702.685050964355
#
# ===5일 째===
# RSI         : 32.701441175586595
# balance     : 78.7649040222168
# QLD 현재가 : 57.685001373291016
# qty         : 160.0
# 총 자산     : 9308.36512374878
#
# ===6일 째===
# RSI         : 41.528598006507806
# balance     : 78.7649040222168
# QLD 현재가 : 60.52000045776367
# qty         : 160.0
# 총 자산     : 9761.964977264404
#
# ===7일 째===
# RSI         : 46.791094388128265
# balance     : 78.7649040222168
# QLD 현재가 : 62.505001068115234
# qty         : 160.0
# 총 자산     : 10079.565074920654
#
# ===8일 째===
# RSI         : 45.5890314601228
# balance     : 78.7649040222168
# QLD 현재가 : 61.96500015258789
# qty         : 160.0
# 총 자산     : 9993.16492843628
#
# ===9일 째===
# RSI         : 49.4239872109398
# balance     : 78.7649040222168
# QLD 현재가 : 63.44499969482422
# qty         : 160.0
# 총 자산     : 10229.964855194092
#
# ===10일 째===
# RSI         : 50.55248620527008
# balance     : 78.7649040222168
# QLD 현재가 : 63.88999938964844
# qty         : 160.0
# 총 자산     : 10301.164806365967
#
# ===11일 째===
# RSI         : 52.60011166371775
# balance     : 78.7649040222168
# QLD 현재가 : 64.69000244140625
# qty         : 160.0
# 총 자산     : 10429.165294647217
#
# ===12일 째===
# RSI         : 52.54152152770406
# balance     : 78.7649040222168
# QLD 현재가 : 64.66999816894531
# qty         : 160.0
# 총 자산     : 10425.964611053467
#
# ===13일 째===
# RSI         : 51.56747648015606
# balance     : 78.7649040222168
# QLD 현재가 : 64.3550033569336
# qty         : 160.0
# 총 자산     : 10375.565441131592
#
# ===14일 째===
# RSI         : 53.66714417765226
# balance     : 78.7649040222168
# QLD 현재가 : 65.06999969482422
# qty         : 160.0
# 총 자산     : 10489.964855194092
#
# ===15일 째===
# RSI         : 55.74762698864275
# balance     : 78.7649040222168
# QLD 현재가 : 65.79000091552734
# qty         : 160.0
# 총 자산     : 10605.165050506592
#
# ===16일 째===
# RSI         : 54.50302327999564
# balance     : 78.7649040222168
# QLD 현재가 : 65.44999694824219
# qty         : 160.0
# 총 자산     : 10550.764415740967
#
# ===17일 째===
# RSI         : 52.16084478604159
# balance     : 78.7649040222168
# QLD 현재가 : 64.81500244140625
# qty         : 160.0
# 총 자산     : 10449.165294647217
#
# ===18일 째===
# RSI         : 50.01039489849718
# balance     : 78.7649040222168
# QLD 현재가 : 64.2249984741211
# qty         : 160.0
# 총 자산     : 10354.764659881592
#
# ===19일 째===
# RSI         : 48.05755101733048
# balance     : 78.7649040222168
# QLD 현재가 : 63.685001373291016
# qty         : 160.0
# 총 자산     : 10268.36512374878
#
# ===20일 째===
# RSI         : 38.232271044276814
# balance     : 78.7649040222168
# QLD 현재가 : 60.3849983215332
# qty         : 160.0
# 총 자산     : 9740.36463546753
#
# ===21일 째===
# RSI         : 37.299053867020675
# balance     : 78.7649040222168
# QLD 현재가 : 60.0099983215332
# qty         : 160.0
# 총 자산     : 9680.36463546753
#
# ===22일 째===
# RSI         : 41.32950238630105
# balance     : 78.7649040222168
# QLD 현재가 : 60.9900016784668
# qty         : 160.0
# 총 자산     : 9837.165172576904
#
# ===23일 째===
# RSI         : 31.666355404096706
# balance     : 78.7649040222168
# QLD 현재가 : 56.66999816894531
# qty         : 160.0
# 총 자산     : 9145.964611053467
#
# ===24일 째===
# RSI         : 33.97532478331868
# balance     : 78.7649040222168
# QLD 현재가 : 57.27000045776367
# qty         : 160.0
# 총 자산     : 9241.964977264404
#
# ===25일 째===
# RSI         : 45.2210512631796
# balance     : 78.7649040222168
# QLD 현재가 : 60.654998779296875
# qty         : 160.0
# 총 자산     : 9783.564708709717
#
# ===26일 째===
# RSI         : 40.86927109179794
# balance     : 78.7649040222168
# QLD 현재가 : 58.689998626708984
# qty         : 160.0
# 총 자산     : 9469.164684295654
#
# ===27일 째===
# RSI         : 34.685991913452526
# balance     : 78.7649040222168
# QLD 현재가 : 55.310001373291016
# qty         : 160.0
# 총 자산     : 8928.36512374878
#
# ===28일 째===
# RSI         : 31.838956123244202
# balance     : 78.7649040222168
# QLD 현재가 : 53.45500183105469
# qty         : 160.0
# 총 자산     : 8631.565196990967
#
# ===29일 째===
# RSI         : 36.779568974175724
# balance     : 78.7649040222168
# QLD 현재가 : 55.095001220703125
# qty         : 160.0
# 총 자산     : 8893.965099334717
#
# ===30일 째===
# RSI         : 32.00397542376513
# balance     : 78.7649040222168
# QLD 현재가 : 51.959999084472656
# qty         : 160.0
# 총 자산     : 8392.364757537842
#
# ===31일 째===
# RSI         : 42.537915156469445
# balance     : 78.7649040222168
# QLD 현재가 : 56.06999969482422
# qty         : 160.0
# 총 자산     : 9049.964855194092
#
# ===32일 째===
# RSI         : 41.967220338174265
# balance     : 78.7649040222168
# QLD 현재가 : 55.73500061035156
# qty         : 160.0
# 총 자산     : 8996.365001678467
#
# ===33일 째===
# RSI         : 47.788221336304716
# balance     : 78.7649040222168
# QLD 현재가 : 58.31999969482422
# qty         : 160.0
# 총 자산     : 9409.964855194092
#
# ===34일 째===
# RSI         : 45.917410343016776
# balance     : 78.7649040222168
# QLD 현재가 : 57.345001220703125
# qty         : 160.0
# 총 자산     : 9253.965099334717
#
# ===35일 째===
# RSI         : 48.66964223074921
# balance     : 78.7649040222168
# QLD 현재가 : 58.584999084472656
# qty         : 160.0
# 총 자산     : 9452.364757537842
#
# ===36일 째===
# RSI         : 50.08163098187034
# balance     : 78.7649040222168
# QLD 현재가 : 59.224998474121094
# qty         : 160.0
# 총 자산     : 9554.764659881592
#
# ===37일 째===
# RSI         : 51.1444874717633
# balance     : 78.7649040222168
# QLD 현재가 : 59.69499969482422
# qty         : 160.0
# 총 자산     : 9629.964855194092
#
# ===38일 째===
# RSI         : 43.359892969697434
# balance     : 78.7649040222168
# QLD 현재가 : 56.01499938964844
# qty         : 160.0
# 총 자산     : 9041.164806365967
#
# ===39일 째===
# RSI         : 44.60592611689459
# balance     : 78.7649040222168
# QLD 현재가 : 56.52000045776367
# qty         : 160.0
# 총 자산     : 9121.964977264404
#
# ===40일 째===
# RSI         : 49.42262988106767
# balance     : 78.7649040222168
# QLD 현재가 : 58.54999923706055
# qty         : 160.0
# 총 자산     : 9446.764781951904
#
# ===41일 째===
# RSI         : 48.080785541411274
# balance     : 78.7649040222168
# QLD 현재가 : 57.94499969482422
# qty         : 160.0
# 총 자산     : 9349.964855194092
#
# ===42일 째===
# RSI         : 43.998145329170946
# balance     : 78.7649040222168
# QLD 현재가 : 56.025001525878906
# qty         : 160.0
# 총 자산     : 9042.765148162842
#
# ===43일 째===
# RSI         : 43.66540116591525
# balance     : 78.7649040222168
# QLD 현재가 : 55.8650016784668
# qty         : 160.0
# 총 자산     : 9017.165172576904
#
# ===44일 째===
# RSI         : 48.06688438776415
# balance     : 78.7649040222168
# QLD 현재가 : 57.529998779296875
# qty         : 160.0
# 총 자산     : 9283.564708709717
#
# ===45일 째===
# RSI         : 47.94573856692403
# balance     : 78.7649040222168
# QLD 현재가 : 57.47999954223633
# qty         : 160.0
# 총 자산     : 9275.56483078003
#
# ===46일 째===
# RSI         : 46.531192660413225
# balance     : 78.7649040222168
# QLD 현재가 : 56.91999816894531
# qty         : 160.0
# 총 자산     : 9185.964611053467
#
# ===47일 째===
# RSI         : 51.171547463834536
# balance     : 78.7649040222168
# QLD 현재가 : 58.595001220703125
# qty         : 160.0
# 총 자산     : 9453.965099334717
#
# ===48일 째===
# RSI         : 56.19451276314479
# balance     : 78.7649040222168
# QLD 현재가 : 60.650001525878906
# qty         : 160.0
# 총 자산     : 9782.765148162842
#
# ===49일 째===
# RSI         : 61.268306667351744
# balance     : 5125.165050506592
# QLD 현재가 : 63.08000183105469
# qty         : 80.0
# 총 자산     : 10171.565196990967
#
# ===50일 째===
# RSI         : 60.846649032270264
# balance     : 7642.965038299561
# QLD 현재가 : 62.94499969482422
# qty         : 40.0
# 총 자산     : 10160.76502609253
#
# ===51일 째===
# RSI         : 61.501845670974284
# balance     : 8908.065059661865
# QLD 현재가 : 63.255001068115234
# qty         : 20.0
# 총 자산     : 10173.16508102417
#
# ===52일 째===
# RSI         : 64.2647840147695
# balance     : 9553.915050506592
# QLD 현재가 : 64.58499908447266
# qty         : 10.0
# 총 자산     : 10199.765041351318
#
# ===53일 째===
# RSI         : 65.83332297865243
# balance     : 9880.790050506592
# QLD 현재가 : 65.375
# qty         : 5.0
# 총 자산     : 10207.665050506592
#
# ===54일 째===
# RSI         : 65.09328946276224
# balance     : 10076.345043182373
# QLD 현재가 : 65.18499755859375
# qty         : 3.0
# 총 자산     : 10271.900035858154
#
# ===55일 째===
# RSI         : 68.1753396106399
# balance     : 10209.755046844482
# QLD 현재가 : 66.70500183105469
# qty         : 2.0
# 총 자산     : 10343.165050506592
#
# ===56일 째===
# RSI         : 61.95488466580382
# balance     : 10274.855045318604
# QLD 현재가 : 65.0999984741211
# qty         : 1.0
# 총 자산     : 10339.955043792725
#
# ===57일 째===
# RSI         : 66.02168276862852
# balance     : 10341.91004562378
# QLD 현재가 : 67.05500030517578
# qty         : 1.0
# 총 자산     : 10408.965045928955
#
# ===58일 째===
# RSI         : 66.37804155451995
# balance     : 10409.14504623413
# QLD 현재가 : 67.23500061035156
# qty         : 1.0
# 총 자산     : 10476.380046844482
#
# ===59일 째===
# RSI         : 61.58621083620296
# balance     : 10475.140048980713
# QLD 현재가 : 65.99500274658203
# qty         : 1.0
# 총 자산     : 10541.135051727295
#
# ===60일 째===
# RSI         : 57.93568760529803
# balance     : 10475.140048980713
# QLD 현재가 : 64.98999786376953
# qty         : 1.0
# 총 자산     : 10540.130046844482
#
# ===61일 째===
# RSI         : 60.79909199802517
# balance     : 10541.280048370361
# QLD 현재가 : 66.13999938964844
# qty         : 1.0
# 총 자산     : 10607.42004776001
#
# ===62일 째===
# RSI         : 55.203829225427924
# balance     : 10541.280048370361
# QLD 현재가 : 64.55000305175781
# qty         : 1.0
# 총 자산     : 10605.83005142212
#
# ===63일 째===
# RSI         : 59.31237387433553
# balance     : 10541.280048370361
# QLD 현재가 : 66.16999816894531
# qty         : 1.0
# 총 자산     : 10607.450046539307
#
# ===64일 째===
# RSI         : 61.32832015272378
# balance     : 10608.30504989624
# QLD 현재가 : 67.0250015258789
# qty         : 1.0
# 총 자산     : 10675.33005142212
#
# ===65일 째===
# RSI         : 59.06152774209423
# balance     : 10608.30504989624
# QLD 현재가 : 66.41000366210938
# qty         : 1.0
# 총 자산     : 10674.71505355835
#
# ===66일 째===
# RSI         : 57.120575294664135
# balance     : 10608.30504989624
# QLD 현재가 : 65.88500213623047
# qty         : 1.0
# 총 자산     : 10674.19005203247
#
# ===67일 째===
# RSI         : 58.6535385963724
# balance     : 10608.30504989624
# QLD 현재가 : 66.43499755859375
# qty         : 1.0
# 총 자산     : 10674.740047454834
#
# ===68일 째===
# RSI         : 55.17730866703571
# balance     : 10608.30504989624
# QLD 현재가 : 65.53500366210938
# qty         : 1.0
# 총 자산     : 10673.84005355835
#
# ===69일 째===
# RSI         : 52.67444097922716
# balance     : 10608.30504989624
# QLD 현재가 : 64.86499786376953
# qty         : 1.0
# 총 자산     : 10673.17004776001
#
# ===70일 째===
# RSI         : 44.98350557094137
# balance     : 4293.785003662109
# QLD 현재가 : 62.52000045776367
# qty         : 102.0
# 총 자산     : 10670.825050354004
#
# ===71일 째===
# RSI         : 43.665924181433326
# balance     : 1748.9150161743164
# QLD 현재가 : 62.06999969482422
# qty         : 143.0
# 총 자산     : 10624.92497253418
#
# ===72일 째===
# RSI         : 47.25242061548865
# balance     : 740.2750015258789
# QLD 현재가 : 63.040000915527344
# qty         : 159.0
# 총 자산     : 10763.635147094727
#
# ===73일 째===
# RSI         : 50.7020671550727
# balance     : 740.2750015258789
# QLD 현재가 : 64.02999877929688
# qty         : 159.0
# 총 자산     : 10921.044807434082
#
# ===74일 째===
# RSI         : 41.168807826862626
# balance     : 314.84999084472656
# QLD 현재가 : 60.775001525878906
# qty         : 166.0
# 총 자산     : 10403.500244140625
#
# ===75일 째===
# RSI         : 40.87637484684786
# balance     : 132.86999130249023
# QLD 현재가 : 60.65999984741211
# qty         : 169.0
# 총 자산     : 10384.409965515137
#
# ===76일 째===
# RSI         : 33.813812868913786
# balance     : 75.34999084472656
# QLD 현재가 : 57.52000045776367
# qty         : 170.0
# 총 자산     : 9853.75006866455
#
# ===77일 째===
# RSI         : 37.129558728730906
# balance     : 75.34999084472656
# QLD 현재가 : 58.40999984741211
# qty         : 170.0
# 총 자산     : 10005.049964904785
#
# ===78일 째===
# RSI         : 45.54684245128575
# balance     : 75.34999084472656
# QLD 현재가 : 60.959999084472656
# qty         : 170.0
# 총 자산     : 10438.549835205078
#
# ===79일 째===
# RSI         : 43.729517956329644
# balance     : 75.34999084472656
# QLD 현재가 : 60.224998474121094
# qty         : 170.0
# 총 자산     : 10313.599731445312
#
# ===80일 째===
# RSI         : 41.70582348846795
# balance     : 75.34999084472656
# QLD 현재가 : 59.39500045776367
# qty         : 170.0
# 총 자산     : 10172.50006866455
#
# ===81일 째===
# RSI         : 42.19177580219015
# balance     : 75.34999084472656
# QLD 현재가 : 59.53499984741211
# qty         : 170.0
# 총 자산     : 10196.299964904785
#
# ===82일 째===
# RSI         : 49.63598180831146
# balance     : 75.34999084472656
# QLD 현재가 : 61.84000015258789
# qty         : 170.0
# 총 자산     : 10588.150016784668
#
# ===83일 째===
# RSI         : 47.63002413242526
# balance     : 75.34999084472656
# QLD 현재가 : 61.13999938964844
# qty         : 170.0
# 총 자산     : 10469.149887084961
#
# ===84일 째===
# RSI         : 53.61432549149704
# balance     : 75.34999084472656
# QLD 현재가 : 63.21500015258789
# qty         : 170.0
# 총 자산     : 10821.900016784668
#
# ===85일 째===
# RSI         : 54.06383470360786
# balance     : 75.34999084472656
# QLD 현재가 : 63.380001068115234
# qty         : 170.0
# 총 자산     : 10849.950172424316
#
# ===86일 째===
# RSI         : 55.25252570210601
# balance     : 75.34999084472656
# QLD 현재가 : 63.79999923706055
# qty         : 170.0
# 총 자산     : 10921.34986114502
#
# ===87일 째===
# RSI         : 53.61607287577497
# balance     : 75.34999084472656
# QLD 현재가 : 63.34000015258789
# qty         : 170.0
# 총 자산     : 10843.150016784668
#
# ===88일 째===
# RSI         : 54.71507584796406
# balance     : 75.34999084472656
# QLD 현재가 : 63.689998626708984
# qty         : 170.0
# 총 자산     : 10902.649757385254
#
# ===89일 째===
# RSI         : 53.20240283711422
# balance     : 75.34999084472656
# QLD 현재가 : 63.29999923706055
# qty         : 170.0
# 총 자산     : 10836.34986114502
#
# ===90일 째===
# RSI         : 54.04440171388587
# balance     : 75.34999084472656
# QLD 현재가 : 63.540000915527344
# qty         : 170.0
# 총 자산     : 10877.150146484375
#
# ===91일 째===
# RSI         : 48.662070904556515
# balance     : 75.34999084472656
# QLD 현재가 : 62.16999816894531
# qty         : 170.0
# 총 자산     : 10644.24967956543
#
# ===92일 째===
# RSI         : 56.17559297528711
# balance     : 75.34999084472656
# QLD 현재가 : 64.36000061035156
# qty         : 170.0
# 총 자산     : 11016.550094604492
#
# ===93일 째===
# RSI         : 57.192271930215625
# balance     : 75.34999084472656
# QLD 현재가 : 64.69000244140625
# qty         : 170.0
# 총 자산     : 11072.650405883789
#
# ===94일 째===
# RSI         : 57.35368839689379
# balance     : 75.34999084472656
# QLD 현재가 : 64.73999786376953
# qty         : 170.0
# 총 자산     : 11081.149627685547
#
# ===95일 째===
# RSI         : 57.56053045327437
# balance     : 75.34999084472656
# QLD 현재가 : 64.80000305175781
# qty         : 170.0
# 총 자산     : 11091.350509643555
#
# ===96일 째===
# RSI         : 62.05285814004844
# balance     : 5698.950302124023
# QLD 현재가 : 66.16000366210938
# qty         : 85.0
# 총 자산     : 11322.55061340332
#
# ===97일 째===
# RSI         : 63.04410172124339
# balance     : 8557.590446472168
# QLD 현재가 : 66.4800033569336
# qty         : 43.0
# 총 자산     : 11416.230590820312
#
# ===98일 째===
# RSI         : 66.755663386869
# balance     : 10048.090446472168
# QLD 현재가 : 67.75
# qty         : 22.0
# 총 자산     : 11538.590446472168
#
# ===99일 째===
# RSI         : 62.003265069041184
# balance     : 10783.4404296875
# QLD 현재가 : 66.8499984741211
# qty         : 11.0
# 총 자산     : 11518.790412902832
#
# ===100일 째===
# RSI         : 59.56762122029053
# balance     : 10783.4404296875
# QLD 현재가 : 66.37000274658203
# qty         : 11.0
# 총 자산     : 11513.510459899902
#
# ===101일 째===
# RSI         : 64.78218835155434
# balance     : 11191.740447998047
# QLD 현재가 : 68.05000305175781
# qty         : 6.0
# 총 자산     : 11600.040466308594
#
# ===102일 째===
# RSI         : 59.56249306461207
# balance     : 11191.740447998047
# QLD 현재가 : 66.98999786376953
# qty         : 6.0
# 총 자산     : 11593.680435180664
#
# ===103일 째===
# RSI         : 62.07702105430153
# balance     : 11395.14045715332
# QLD 현재가 : 67.80000305175781
# qty         : 3.0
# 총 자산     : 11598.540466308594
#
# ===104일 째===
# RSI         : 65.68042882122839
# balance     : 11533.280456542969
# QLD 현재가 : 69.06999969482422
# qty         : 2.0
# 총 자산     : 11671.420455932617
#
# ===105일 째===
# RSI         : 65.81814507904733
# balance     : 11602.40045928955
# QLD 현재가 : 69.12000274658203
# qty         : 1.0
# 총 자산     : 11671.520462036133
#
# ===106일 째===
# RSI         : 68.18292406186593
# balance     : 11672.380462646484
# QLD 현재가 : 69.9800033569336
# qty         : 1.0
# 총 자산     : 11742.360466003418
#
# ===107일 째===
# RSI         : 67.30825281839057
# balance     : 11742.210464477539
# QLD 현재가 : 69.83000183105469
# qty         : 1.0
# 총 자산     : 11812.040466308594
#
# ===108일 째===
# RSI         : 71.68877823885882
# balance     : 11813.72046661377
# QLD 현재가 : 71.51000213623047
# qty         : 1.0
# 총 자산     : 11885.23046875
#
# ===109일 째===
# RSI         : 72.87691905220171
# balance     : 11885.740463256836
# QLD 현재가 : 72.0199966430664
# qty         : 1.0
# 총 자산     : 11957.760459899902
#
# ===110일 째===
# RSI         : 71.54545953387354
# balance     : 11957.55046081543
# QLD 현재가 : 71.80999755859375
# qty         : 1.0
# 총 자산     : 12029.360458374023
#
# ===111일 째===
# RSI         : 71.67814502916012
# balance     : 12029.410461425781
# QLD 현재가 : 71.86000061035156
# qty         : 1.0
# 총 자산     : 12101.270462036133
#
# ===112일 째===
# RSI         : 75.64121248162495
# balance     : 12102.890464782715
# QLD 현재가 : 73.4800033569336
# qty         : 1.0
# 총 자산     : 12176.370468139648
#
# ===113일 째===
# RSI         : 76.969437096283
# balance     : 12176.990463256836
# QLD 현재가 : 74.0999984741211
# qty         : 1.0
# 총 자산     : 12251.090461730957
#
# ===114일 째===
# RSI         : 77.52295093233495
# balance     : 12251.350463867188
# QLD 현재가 : 74.36000061035156
# qty         : 1.0
# 총 자산     : 12325.710464477539
#
# ===115일 째===
# RSI         : 71.80454143400574
# balance     : 12324.910461425781
# QLD 현재가 : 73.55999755859375
# qty         : 1.0
# 총 자산     : 12398.470458984375
#
# ===116일 째===
# RSI         : 74.09397712752754
# balance     : 12399.360458374023
# QLD 현재가 : 74.44999694824219
# qty         : 1.0
# 총 자산     : 12473.810455322266
#
# ===117일 째===
# RSI         : 75.46787380995718
# balance     : 12474.38045501709
# QLD 현재가 : 75.0199966430664
# qty         : 1.0
# 총 자산     : 12549.400451660156
#
# ===118일 째===
# RSI         : 75.24170869227397
# balance     : 12549.37045288086
# QLD 현재가 : 74.98999786376953
# qty         : 1.0
# 총 자산     : 12624.360450744629
#
# ===119일 째===
# RSI         : 75.91540002861231
# balance     : 12624.62045288086
# QLD 현재가 : 75.25
# qty         : 1.0
# 총 자산     : 12699.87045288086
#
# ===120일 째===
# RSI         : 67.81379652540112
# balance     : 12698.810455322266
# QLD 현재가 : 74.19000244140625
# qty         : 1.0
# 총 자산     : 12773.000457763672
#
# ===121일 째===
# RSI         : 60.064115036592085
# balance     : 12771.810455322266
# QLD 현재가 : 73.0
# qty         : 1.0
# 총 자산     : 12844.810455322266
#
# ===122일 째===
# RSI         : 53.432921715508144
# balance     : 12771.810455322266
# QLD 현재가 : 71.80000305175781
# qty         : 1.0
# 총 자산     : 12843.610458374023
#
# ===123일 째===
# RSI         : 60.044089443424056
# balance     : 12845.280456542969
# QLD 현재가 : 73.47000122070312
# qty         : 1.0
# 총 자산     : 12918.750457763672
#
# ===124일 째===
# RSI         : 63.63930203898133
# balance     : 12919.830459594727
# QLD 현재가 : 74.55000305175781
# qty         : 1.0
# 총 자산     : 12994.380462646484
#
# ===125일 째===
# RSI         : 66.74259404834484
# balance     : 12995.420455932617
# QLD 현재가 : 75.58999633789062
# qty         : 1.0
# 총 자산     : 13071.010452270508
#
# ===126일 째===
# RSI         : 71.1309849135798
# balance     : 13072.730453491211
# QLD 현재가 : 77.30999755859375
# qty         : 1.0
# 총 자산     : 13150.040451049805
#
# ===127일 째===
# RSI         : 71.53084782776247
# balance     : 13150.210456848145
# QLD 현재가 : 77.4800033569336
# qty         : 1.0
# 총 자산     : 13227.690460205078
#
# ===128일 째===
# RSI         : 62.24624450047977
# balance     : 13225.990455627441
# QLD 현재가 : 75.77999877929688
# qty         : 1.0
# 총 자산     : 13301.770454406738
#
# ===129일 째===
# RSI         : 63.851306013769474
# balance     : 13302.310455322266
# QLD 현재가 : 76.31999969482422
# qty         : 1.0
# 총 자산     : 13378.63045501709
#
# ===130일 째===
# RSI         : 64.74797359620763
# balance     : 13378.930458068848
# QLD 현재가 : 76.62000274658203
# qty         : 1.0
# 총 자산     : 13455.55046081543
#
# ===131일 째===
# RSI         : 60.342100509160964
# balance     : 13454.730461120605
# QLD 현재가 : 75.80000305175781
# qty         : 1.0
# 총 자산     : 13530.530464172363
#
# ===132일 째===
# RSI         : 60.288211281564955
# balance     : 13530.520462036133
# QLD 현재가 : 75.79000091552734
# qty         : 1.0
# 총 자산     : 13606.31046295166
#
# ===133일 째===
# RSI         : 63.51571161467691
# balance     : 13607.230461120605
# QLD 현재가 : 76.70999908447266
# qty         : 1.0
# 총 자산     : 13683.940460205078
#
# ===134일 째===
# RSI         : 64.36329439511857
# balance     : 13684.190460205078
# QLD 현재가 : 76.95999908447266
# qty         : 1.0
# 총 자산     : 13761.15045928955
#
# ===135일 째===
# RSI         : 67.51652467067247
# balance     : 13762.120460510254
# QLD 현재가 : 77.93000030517578
# qty         : 1.0
# 총 자산     : 13840.05046081543
#
# ===136일 째===
# RSI         : 63.11445259040251
# balance     : 13839.340461730957
# QLD 현재가 : 77.22000122070312
# qty         : 1.0
# 총 자산     : 13916.56046295166
#
# ===137일 째===
# RSI         : 64.10830984599731
# balance     : 13916.840461730957
# QLD 현재가 : 77.5
# qty         : 1.0
# 총 자산     : 13994.340461730957
#
# ===138일 째===
# RSI         : 59.31378180300842
# balance     : 13916.840461730957
# QLD 현재가 : 76.72000122070312
# qty         : 1.0
# 총 자산     : 13993.56046295166
#
# ===139일 째===
# RSI         : 57.82116226515665
# balance     : 13916.840461730957
# QLD 현재가 : 76.47000122070312
# qty         : 1.0
# 총 자산     : 13993.31046295166
#
# ===140일 째===
# RSI         : 60.15365940847782
# balance     : 13993.850463867188
# QLD 현재가 : 77.01000213623047
# qty         : 1.0
# 총 자산     : 14070.860466003418
#
# ===141일 째===
# RSI         : 62.236058747024536
# balance     : 14071.360466003418
# QLD 현재가 : 77.51000213623047
# qty         : 1.0
# 총 자산     : 14148.870468139648
#
# ===142일 째===
# RSI         : 62.489383735266394
# balance     : 14148.930465698242
# QLD 현재가 : 77.56999969482422
# qty         : 1.0
# 총 자산     : 14226.500465393066
#
# ===143일 째===
# RSI         : 53.69640302539583
# balance     : 14148.930465698242
# QLD 현재가 : 76.20999908447266
# qty         : 1.0
# 총 자산     : 14225.140464782715
#
# ===144일 째===
# RSI         : 46.09506039501737
# balance     : 5704.440086364746
# QLD 현재가 : 74.7300033569336
# qty         : 114.0
# 총 자산     : 14223.660469055176
#
# ===145일 째===
# RSI         : 49.91296543082364
# balance     : 2308.2900314331055
# QLD 현재가 : 75.47000122070312
# qty         : 159.0
# 총 자산     : 14308.020225524902
#
# ===146일 째===
# RSI         : 56.88941223971277
# balance     : 2308.2900314331055
# QLD 현재가 : 77.04000091552734
# qty         : 159.0
# 총 자산     : 14557.650177001953
#
# ===147일 째===
# RSI         : 64.60064841244002
# balance     : 8653.890007019043
# QLD 현재가 : 79.31999969482422
# qty         : 80.0
# 총 자산     : 14999.48998260498
#
# ===148일 째===
# RSI         : 66.007870641779
# balance     : 11846.289909362793
# QLD 현재가 : 79.80999755859375
# qty         : 40.0
# 총 자산     : 15038.689811706543
#
# ===149일 째===
# RSI         : 66.27308446404523
# balance     : 13444.289939880371
# QLD 현재가 : 79.9000015258789
# qty         : 20.0
# 총 자산     : 15042.28997039795
#
# ===150일 째===
# RSI         : 60.9788504033577
# balance     : 14233.989952087402
# QLD 현재가 : 78.97000122070312
# qty         : 10.0
# 총 자산     : 15023.689964294434
#
# ===151일 째===
# RSI         : 65.87220010339229
# balance     : 14636.589935302734
# QLD 현재가 : 80.5199966430664
# qty         : 5.0
# 총 자산     : 15039.189918518066
#
# ===152일 째===
# RSI         : 70.52111257607233
# balance     : 14883.579940795898
# QLD 현재가 : 82.33000183105469
# qty         : 3.0
# 총 자산     : 15130.569946289062
#
# ===153일 째===
# RSI         : 69.56266492681553
# balance     : 15047.899948120117
# QLD 현재가 : 82.16000366210938
# qty         : 2.0
# 총 자산     : 15212.219955444336
#
# ===154일 째===
# RSI         : 70.30410164918281
# balance     : 15130.34994506836
# QLD 현재가 : 82.44999694824219
# qty         : 1.0
# 총 자산     : 15212.799942016602
#
# ===155일 째===
# RSI         : 69.67383072989887
# balance     : 15212.69994354248
# QLD 현재가 : 82.3499984741211
# qty         : 1.0
# 총 자산     : 15295.049942016602
#
# ===156일 째===
# RSI         : 71.12356499495445
# balance     : 15295.569946289062
# QLD 현재가 : 82.87000274658203
# qty         : 1.0
# 총 자산     : 15378.439949035645
#
# ===157일 째===
# RSI         : 71.68422609555522
# balance     : 15378.639945983887
# QLD 현재가 : 83.06999969482422
# qty         : 1.0
# 총 자산     : 15461.709945678711
#
# ===158일 째===
# RSI         : 67.85346815255733
# balance     : 15461.169944763184
# QLD 현재가 : 82.52999877929688
# qty         : 1.0
# 총 자산     : 15543.69994354248
#
# ===159일 째===
# RSI         : 63.45755590581781
# balance     : 15543.049942016602
# QLD 현재가 : 81.87999725341797
# qty         : 1.0
# 총 자산     : 15624.92993927002
#
# ===160일 째===
# RSI         : 56.10996724039583
# balance     : 15543.049942016602
# QLD 현재가 : 80.66000366210938
# qty         : 1.0
# 총 자산     : 15623.709945678711
#
# ===161일 째===
# RSI         : 55.48613445769933
# balance     : 15543.049942016602
# QLD 현재가 : 80.55000305175781
# qty         : 1.0
# 총 자산     : 15623.59994506836
#
# ===162일 째===
# RSI         : 52.78570356796325
# balance     : 15543.049942016602
# QLD 현재가 : 80.08000183105469
# qty         : 1.0
# 총 자산     : 15623.129943847656
#
# ===163일 째===
# RSI         : 58.27607325990471
# balance     : 15543.049942016602
# QLD 현재가 : 81.26000213623047
# qty         : 1.0
# 총 자산     : 15624.309944152832
#
# ===164일 째===
# RSI         : 58.92988427535469
# balance     : 15543.049942016602
# QLD 현재가 : 81.41000366210938
# qty         : 1.0
# 총 자산     : 15624.459945678711
#
# ===165일 째===
# RSI         : 48.417210102948275
# balance     : 6243.889549255371
# QLD 현재가 : 79.4800033569336
# qty         : 118.0
# 총 자산     : 15622.529945373535
#
# ===166일 째===
# RSI         : 36.418061723918235
# balance     : 2511.559638977051
# QLD 현재가 : 76.16999816894531
# qty         : 167.0
# 총 자산     : 15231.949333190918
#
# ===167일 째===
# RSI         : 37.17788899100746
# balance     : 1061.4796447753906
# QLD 현재가 : 76.31999969482422
# qty         : 186.0
# 총 자산     : 15256.999588012695
#
# ===168일 째===
# RSI         : 44.17117355036398
# balance     : 439.2396545410156
# QLD 현재가 : 77.77999877929688
# qty         : 194.0
# 총 자산     : 15528.55941772461
#
# ===169일 째===
# RSI         : 50.00093088265248
# balance     : 439.2396545410156
# QLD 현재가 : 79.19999694824219
# qty         : 194.0
# 총 자산     : 15804.0390625
#
# ===170일 째===
# RSI         : 50.51045181497318
# balance     : 439.2396545410156
# QLD 현재가 : 79.33000183105469
# qty         : 194.0
# 총 자산     : 15829.260009765625
#
# ===171일 째===
# RSI         : 45.75918213596086
# balance     : 204.93965911865234
# QLD 현재가 : 78.0999984741211
# qty         : 197.0
# 총 자산     : 15590.639358520508
#
# ===172일 째===
# RSI         : 33.46639177823958
# balance     : 131.2996597290039
# QLD 현재가 : 73.63999938964844
# qty         : 198.0
# 총 자산     : 14712.019538879395
#
# ===173일 째===
# RSI         : 33.080146836074704
# balance     : 57.83966064453125
# QLD 현재가 : 73.45999908447266
# qty         : 198.0
# 총 자산     : 14602.919479370117
#
# ===174일 째===
# RSI         : 31.5757260364677
# balance     : 57.83966064453125
# QLD 현재가 : 72.7699966430664
# qty         : 198.0
# 총 자산     : 14466.29899597168
#
# ===175일 째===
# RSI         : 36.025811058326276
# balance     : 57.83966064453125
# QLD 현재가 : 73.75
# qty         : 198.0
# 총 자산     : 14660.339660644531
#
# 57.83966064453125
# ===176일 째===
# RSI         : 29.561004941163077
# balance     : 57.83966064453125
# QLD 현재가 : 70.69000244140625
# qty         : 198.0
# 총 자산     : 14054.460144042969
#
# ===177일 째===
# RSI         : 37.072207933277525
# balance     : 57.83966064453125
# QLD 현재가 : 72.58000183105469
# qty         : 198.0
# 총 자산     : 14428.68002319336
#
# ===178일 째===
# RSI         : 40.3692834483159
# balance     : 57.83966064453125
# QLD 현재가 : 73.48999786376953
# qty         : 198.0
# 총 자산     : 14608.859237670898
#
# ===179일 째===
# RSI         : 44.97527114312271
# balance     : 57.83966064453125
# QLD 현재가 : 74.83999633789062
# qty         : 198.0
# 총 자산     : 14876.158935546875
#
# ===180일 째===
# RSI         : 42.96334209120905
# balance     : 57.83966064453125
# QLD 현재가 : 74.08000183105469
# qty         : 198.0
# 총 자산     : 14725.68002319336

# %%
print(min(total_yield) ,"," , max(total_yield))
# Out:
# 8392.364757537842 , 15829.260009765625

# %%
# ticker = data.DataReader('tqqq','yahoo','2010-02-01','2021-10-01')

# delta = ticker['Close'].diff()
# up = delta.clip(lower=0)
# down = -1*delta.clip(upper=0)
# ema_up = up.ewm(com=13, adjust=False).mean()
# ema_down = down.ewm(com=13, adjust=False).mean()
# rs = ema_up/ema_down

# ticker['RSI'] = 100 - (100/(1 + rs))

# # Skip first 14 days to have real values
# ticker = ticker.iloc[14:]

# print(ticker)
# fig, (ax1, ax2) = plt.subplots(2)
# ax1.get_xaxis().set_visible(False)
# fig.suptitle('Twitter')

# ticker['Close'].plot(ax=ax1)
# ax1.set_ylabel('Price ($)')
# ticker['RSI'].plot(ax=ax2)
# ax2.set_ylim(0,100)
# ax2.axhline(30, color='r', linestyle='--')
# ax2.axhline(70, color='r', linestyle='--')
# ax2.set_ylabel('RSI')

# plt.show()
