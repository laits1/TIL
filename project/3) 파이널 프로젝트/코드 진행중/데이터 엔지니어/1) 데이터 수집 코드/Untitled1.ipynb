# %%
import pandas as pd

# %%
movie = pd.read_csv("./수집 완성된 csv파일/Movies.csv")

# %%
movie
# Out:
#        imdb_movie_Id                               title  \
# 0             114709                    Toy Story (1995)
# 1             113497                      Jumanji (1995)
# 2             113228             Grumpier Old Men (1995)
# 3             114885            Waiting to Exhale (1995)
# 4             113041  Father of the Bride Part II (1995)
# ...              ...                                 ...
# 63528        1284502                     South of Heaven
# 63529        2861508                    Survive the Game
# 63530        7099280               Needle in a Timestack
# 63531        1151336          Broadcast Signal Intrusion
# 63532         925852                   A Mouthful of Air
#
#                                                   genres  \
# 0            Adventure|Animation|Children|Comedy|Fantasy
# 1                             Adventure|Children|Fantasy
# 2                                         Comedy|Romance
# ...

# %%
a = movie.loc[movie["imdb_movie_Id"] == 114709, "title"]

# %%
a[0]
# Out:
# 'Toy Story (1995)'
