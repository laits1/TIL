# %%
from requests import get
from bs4 import BeautifulSoup as Soup
import pandas as pd
import time

# %%
Name = []
Year = []
Rating = []
Meta_score = []
Votes = []
Genre = []
Movie_No = []
Director = []
Star = []
Actor_list = []

# %%
for n in range (10) :
    url = get('https://www.imdb.com/search/title/?title_type=feature,tv_movie,short&release_date=2000-01-01,&count=100&start=' + str(n*100+1) + '&ref_=adv_nxt')
    request = url.text
    soup_data = Soup(request, 'html.parser')
    movies = soup_data.findAll('div', {'class' : 'lister-item mode-advanced'})
    for i in movies:
        Name.append(i.h3.a.text)
        Year.append(i.find('span', {'class' : 'lister-item-year text-muted unbold'}).text[-5:-1])
        try :    
            Rating.append(i.find('div', {'class' : 'inline-block ratings-imdb-rating'})['data-value'])
        except:
            Rating.append('0')
        Genre.append(i.find('span', {'class' : 'genre'}).text[1:-1])
        Director.append(i.select("div.lister-item-content> p:nth-of-type(3) a")[0].text)
        Movie_No.append(i.h3.a.get('href').split('/')[2][2:])
        Actor_list.append(i.select("div.lister-item-content> p:nth-of-type(3) a")[1:])
        try :    
            Votes.append(i.find('span', {'name' : 'nv'})['data-value'])
        except :
            Votes.append(0)
        try :
            Meta_score.append(i.find('div', {'class' : 'inline-block ratings-metascore'}).span.text.strip())
        except :
            Meta_score.append(0)

for k in range(len(Actor_list)):
    for j in range(len(Actor_list[k])):
        Actor_list[k][j] = Actor_list[k][j].text
            
            
print(len(Name))
print(len(Rating))
print(len(Actor_list))
# Out:
# 1000
# 1000
# 1000

# %%
data = list(zip(Name, Year, Genre, Rating, Meta_score, Votes, Movie_No, Director, Actor_list))

# %%
df = pd.DataFrame(data, columns = ['Name', 'Year','Genre', 'Rating', 'Metascore',  'Votes', 'Movie_No', 'Director', 'Actor_list'])
df.index = df.index+1

# %%
df.tail(100)
# Out:
#                                       Name  Year  \
# 901   Mission: Impossible - Ghost Protocol  2011
# 902                        Spring Breakers  2012
# 903                             Magic Mike  2012
# 904                       Jeepers Creepers  2001
# 905                     Terminator Genisys  2015
# ...                                    ...   ...
# 996                      Shaun of the Dead  2004
# 997                            John Carter  2012
# 998                                Snowden  2016
# 999                        Five Feet Apart  2019
# 1000                 Live Free or Die Hard  2007
#
#                                        Genre Rating Metascore   Votes  \
# 901   Action, Adventure, Thriller               7.4        73  470707
# 902                  Crime, Drama               5.3        63  139145
# 903                 Comedy, Drama               6.1        72  134897
# 904               Horror, Mystery               6.2        49  119244
# 905     Action, Adventure, Sci-Fi               6.3        38  268042
# ...                                      ...    ...       ...     ...
# 996                Comedy, Horror               7.9        76  531803
# 997     Action, Adventure, Sci-Fi               6.6        51  263112
# 998       Biography, Crime, Drama               7.3        58  145871
# 999                Drama, Romance               7.2        53   55155
# 1000             Action, Thriller               7.1        69  396967
#
#      Movie_No           Director  \
# 901   1229238          Brad Bird
# 902   2101441     Harmony Korine
# 903   1915581  Steven Soderbergh
# 904   0263488       Victor Salva
# 905   1340138        Alan Taylor
# ...       ...                ...
# 996   0365748       Edgar Wright
# 997   0401729     Andrew Stanton
# 998   3774114       Oliver Stone
# 999   6472976     Justin Baldoni
# 1000  0337978        Len Wiseman
#
#                                              Actor_list
# 901   [Tom Cruise, Jeremy Renner, Simon Pegg, Paula ...
# 902   [Vanessa Hudgens, Selena Gomez, Ashley Benson,...
# 903   [Channing Tatum, Alex Pettyfer, Olivia Munn, M...
# 904   [Gina Philips, Justin Long, Jonathan Breck, Pa...
# 905   [Arnold Schwarzenegger, Jason Clarke, Emilia C...
# ...                                                 ...
# 996   [Simon Pegg, Nick Frost, Kate Ashfield, Lucy D...
# 997   [Taylor Kitsch, Lynn Collins, Willem Dafoe, Sa...
# 998   [Joseph Gordon-Levitt, Shailene Woodley, Melis...
# 999   [Haley Lu Richardson, Cole Sprouse, Moises Ari...
# 1000  [Bruce Willis, Justin Long, Timothy Olyphant, ...
#
# [100 rows x 9 columns]
