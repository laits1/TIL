# %%
import pandas as pd

# %%
movies = pd.read_csv('./after_csv/movies.csv')

# %%
movies.loc['10993'] = [11465692, 'C.I.Ape', '["Comedy","Faimly"]', 'Ali Zamani', 'Stephen Johnston']

# %%
movies.to_csv('./after_csv/movies.csv')

# %%
movies
# Out:
#       imdb_movie_Id                                    title  \
# 0            114709                         Toy Story (1995)
# 1            113497                           Jumanji (1995)
# 2            113228                  Grumpier Old Men (1995)
# 3            114885                 Waiting to Exhale (1995)
# 4            113041       Father of the Bride Part II (1995)
# ...             ...                                      ...
# 10989       4033502                                  배드 럭 뱅잉
# 10990       1271038                           Licorice Pizza
# 10991       6920084   Resident Evil: Welcome to Raccoon City
# 10992       4547524                       National Champions
# 10993      11465692                                  C.I.Ape
#
#                                             genres         Director_name  \
# 0      Adventure|Animation|Children|Comedy|Fantasy                   NaN
# 1                       Adventure|Children|Fantasy                   NaN
# ...

# %%
ratings = pd.read_csv('./after_csv/ratings.csv')

# %%
ratings
# Out:
#        Unnamed: 0  imdb_movie_Id                                    title  \
# 0               0         114709                         Toy Story (1995)
# 1               1         113497                           Jumanji (1995)
# 2               2         113228                  Grumpier Old Men (1995)
# 3               3         114885                 Waiting to Exhale (1995)
# 4               4         113041       Father of the Bride Part II (1995)
# ...           ...            ...                                      ...
# 10989       10989        4033502                                  배드 럭 뱅잉
# 10990       10990        1271038                           Licorice Pizza
# 10991       10991        6920084   Resident Evil: Welcome to Raccoon City
# 10992       10992        4547524                       National Champions
# 10993       10993       11465692                                  C.I.Ape
#
#                                             genres         Director_name  \
# ...
