# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

from selenium.webdriver.chrome.options import Options 
from selenium import webdriver

import pandas as pd
import urllib.request
import requests
import string
from bs4 import BeautifulSoup
from nltk.corpus import stopwords #kick the words out such as 'the', 'a'
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %matplotlib inline
from tqdm import tqdm

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SDG\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords #kick the words out such as 'the', 'a'

# %%
# Load the Loughran and McDonald dictionnary
lm = pd.read_excel('./LoughranMcDonald_MasterDictionary_2020.xlsx')

# get the lists of positive/negative words
lmpos = list(lm[lm.Positive!=0]['Word'])
lmneg = list(lm[lm.Negative!=0]['Word'])

# %%
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

def get_article_body(article_url):
    
    # 셀레니움을 이용한 크롤링
    
    driver = webdriver.Chrome(executable_path='./driver/chromedriver.exe') ################## 드라이버 경로는 각자 컴퓨터에 맞게!!!
    
    page = driver.get(article_url)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    html_text = soup.find('div',{'class':'caas-body'})    
    div = soup.find('div',{'class':'caas-attr-time-style'})   # 기사 내용이 div class='caas-body'에 들어있음 (하이퍼링크내용 제거는 차후 코딩...)
    date = div.text                                           # text화 시켜 하나의 내용으로 변경
    
    driver.close()
    
    stripped_text = []
    for t in html_text:
        t = strip_tags(str(t))
        stripped_text.append(t)
    
    return " ".join(stripped_text)

# %%
cciv = pd.read_excel('PFIZER.xlsx') # 엑셀파일이름과 동일하게

# %%
cciv = cciv.rename(columns=cciv.iloc[0])
cciv
# Out:
#      2019 8월                                               None
# 0    2019 8월                                               None
# 1    2019 9월                                               None
# 2   2019 10월  https://finance.yahoo.com/news/closer-look-pfi...
# 3   2019 11월                                               None
# 4   2019 12월  https://finance.yahoo.com/news/pfizer-pfe-sees...
# 5        NaN  https://finance.yahoo.com/news/pfizer-pfe-stoc...
# 6    2020 1월                                               None
# 7    2020 2월                                               None
# 8    2020 3월  https://finance.yahoo.com/news/pfizer-stock-fa...
# 9    2020 4월                                               None
# 10   2020 5월  https://finance.yahoo.com/news/pfizer-loses-6-...
# 11   2020 6월  https://finance.yahoo.com/news/top-research-re...
# 12   2020 7월  https://finance.yahoo.com/news/coronavirus-upd...
# 13       NaN  https://finance.yahoo.com/news/pfizer-inc-nyse...
# 14   2020 8월                                               None
# 15   2020 9월  https://finance.yahoo.com/news/pfizer-stock-bu...
# 16       NaN  https://finance.yahoo.com/news/covid-19-corona...
# 17       NaN  https://finance.yahoo.com/news/pfizer-inc-nyse...
# 18       NaN  https://finance.yahoo.com/news/why-pfizer-seri...
# 19  2020 10월  https://finance.yahoo.com/news/pfizers-pfe-onc...
# 20  2020 11월  https://finance.yahoo.com/news/value-investors...
# 21       NaN  https://finance.yahoo.com/news/pfizer-pfe-good...
# 22       NaN  https://finance.yahoo.com/news/might-not-great...
# 23       NaN  https://finance.yahoo.com/news/sales-pfizers-c...
# 24  2020 12월  https://finance.yahoo.com/news/pfizer-pfe-dips...
# 25   2021 1월  https://finance.yahoo.com/news/might-not-great...
# 30  https://finance.yahoo.com/news/pfizer-pfe-outp...
# 31  https://finance.yahoo.com/news/pfizer-pfe-stoc...
# 32  https://finance.yahoo.com/news/pfizer-stock-es...
# 33  https://finance.yahoo.com/news/1-korea-signs-p...
# 34  https://finance.yahoo.com/news/pfizer-pfe-gain...
# 35  https://finance.yahoo.com/news/pfizer-ceo-our-...
# 36  https://finance.yahoo.com/news/smart-money-pfi...
# 37  https://finance.yahoo.com/news/why-pfizer-top-...
# 38  https://finance.yahoo.com/news/pfizer-covid-va...
# 39  https://finance.yahoo.com/news/pfizer-pfe-outp...
# 40  https://finance.yahoo.com/news/pfizer-inc-pfe-...
# 41  https://finance.yahoo.com/news/1-pfizer-raises...
# 42  https://finance.yahoo.com/news/pfizer-pfe-stoc...
# 43  https://finance.yahoo.com/news/pfizer-q2-resul...
# 44  https://finance.yahoo.com/news/pfizer-pfe-q2-e...
# 45  https://finance.yahoo.com/news/were-hedge-fund...
# 46  https://finance.yahoo.com/news/pfizer-shares-h...
# 47  https://finance.yahoo.com/news/pfizer-inc-52-w...
# 48                                               None

# %%
cciv_list = cciv['None'].to_list() #### 위 DF 의 Facebook(열 이름) 과 같아야함

# %%
nwords = []
nneg = []
npos = []
# c_date=[]

# in this block of code, we extract informations from each article to fill up
# the lists above
# for i in range(len(cciv_list)):
for i in tqdm(cciv_list):  ########################### NONE값 0점 확인을 위해 cciv_list[4:6]로 함 ###########################
    if i == 'NONE':
        nwords.append(0)
        npos.append(0)
        nneg.append(0)
#         c_date.append('NONE')
    else:
        # let's use the helper function to provide us with the article body
        # New York Times wraps their body in the <p> HTML element. The website you use might be different
        article_body = get_article_body(i)

        # convert all words to lower case
        article_body = article_body.lower()

        # remove non-letters (i.e., $ %)
        natural_lang_data = ''.join([x for x in article_body if x in string.ascii_letters + '\'- '])

        # before processing the natural language data, we need to remove stop words.
        # stop words are words like: about, that, this, and, or, etc...
        natural_lang_data = [x for x in natural_lang_data.split() if x not in stopwords.words('english')]

        # finally, we store the following data: 
        nwords.append(len(natural_lang_data)) # number of words
        npos.append(len([i for i in natural_lang_data if i.upper() in lmpos]))  # number of positive words
        nneg.append(len([i for i in natural_lang_data if i.upper() in lmneg]))  # number of negative words
#         c_date.append(date)
# Out:
#   0%|                                                                                           | 0/48 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# <ipython-input-47-c27372aeda89> in <module>
#      16         # let's use the helper function to provide us with the article body
#      17         # New York Times wraps their body in the <p> HTML element. The website you use might be different
# ---> 18         article_body = get_article_body(i)
#      19
#      20         # convert all words to lower case
#
# <ipython-input-39-ba038c1ad485> in get_article_body(article_url)
#      23     driver = webdriver.Chrome(executable_path='./driver/chromedriver.exe') ################## 드라이버 경로는 각자 컴퓨터에 맞게!!!
#      24
# ---> 25     page = driver.get(article_url)
#      26     html = driver.page_source
#      27     soup = BeautifulSoup(html, 'html.parser')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: chrome=93.0.4577.63)

# %%
cciv_data = pd.DataFrame(data={'nwords':nwords, 'npos':npos, 'nneg':nneg})
cciv_data

# %%
cciv_data.to_csv('Spotify_score.csv')
