# %%
import yfinance as yf
from pandas_datareader import data
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# pip install yfinance
# pip install pandas-datareader

# 주가 데이터는 2019-08-01 ~ 2021-08-31

# %%
stock = data.DataReader(['TSLA', 'MSFT', 'AMZN', 'SPOT', 'PFE', 'AMD', 'WMT', 'MO', 'KO', 'NKE', 'FB'],'yahoo','2019-08-02','2021-08-31')
stock['Adj Close'].plot(figsize=(16, 9))
stock['Adj Close'].to_csv('./stock_price_2y.csv')

# %%
# yf.download('AAPL',start = '2016-07-04')
stock.index.name = 'Date1'
stock[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2019-08-01 00:00:00, 2019-08-02 00:00:00, 2019-08-05 00:00:00, 2019-08-06 00:00:00, 2019-08-07 00:00:00, 2019-08-08 00:00:00, 2019-08-09 00:00:00, 2019-08-12 00:00:00, 2019-08-13 00:00:00, 2019-08-14 00:00:00, 2019-08-15 00:00:00, 2019-08-16 00:00:00, 2019-08-19 00:00:00, 2019-08-20 00:00:00, 2019-08-21 00:00:00, 2019-08-22 00:00:00, 2019-08-23 00:00:00, 2019-08-26 00:00:00, 2019-08-27 00:00:00, 2019-08-28 00:00:00, 2019-08-29 00:00:00, 2019-08-30 00:00:00, 2019-09-03 00:00:00, 2019-09-04 00:00:00, 2019-09-05 00:00:00, 2019-09-06 00:00:00, 2019-09-09 00:00:00, 2019-09-10 00:00:00, 2019-09-11 00:00:00, 2019-09-12 00:00:00, 2019-09-13 00:00:00, 2019-09-16 00:00:00, 2019-09-17 00:00:00, 2019-09-18 00:00:00, 2019-09-19 00:00:00, 2019-09-20 00:00:00, 2019-09-23 00:00:00, 2019-09-24 00:00:00, 2019-09-25 00:00:00, 2019-09-26 00:00:00, 2019-09-27 00:00:00, 2019-09-30 00:00:00, 2019-10-01 00:00:00, 2019-10-02 00:00:00, 2019-10-03 00:00:00, 2019-10-04 00:00:00, 2019-10-07 00:00:00, 2019-10-08 00:00:00, 2019-10-09 00:00:00, 2019-10-10 00:00:00, 2019-10-11 00:00:00, 2019-10-14 00:00:00, 2019-10-15 00:00:00, 2019-10-16 00:00:00, 2019-10-17 00:00:00, 2019-10-18 00:00:00, 2019-10-21 00:00:00, 2019-10-22 00:00:00, 2019-10-23 00:00:00, 2019-10-24 00:00:00, 2019-10-25 00:00:00, 2019-10-28 00:00:00, 2019-10-29 00:00:00, 2019-10-30 00:00:00, 2019-10-31 00:00:00, 2019-11-01 00:00:00, 2019-11-04 00:00:00, 2019-11-05 00:00:00, 2019-11-06 00:00:00, 2019-11-07 00:00:00, 2019-11-08 00:00:00, 2019-11-11 00:00:00, 2019-11-12 00:00:00, 2019-11-13 00:00:00, 2019-11-14 00:00:00, 2019-11-15 00:00:00, 2019-11-18 00:00:00, 2019-11-19 00:00:00, 2019-11-20 00:00:00, 2019-11-21 00:00:00, 2019-11-22 00:00:00, 2019-11-25 00:00:00, 2019-11-26 00:00:00, 2019-11-27 00:00:00, 2019-11-29 00:00:00, 2019-12-02 00:00:00, 2019-12-03 00:00:00, 2019-12-04 00:00:00, 2019-12-05 00:00:00, 2019-12-06 00:00:00, 2019-12-09 00:00:00, 2019-12-10 00:00:00, 2019-12-11 00:00:00, 2019-12-12 00:00:00, 2019-12-13 00:00:00, 2019-12-16 00:00:00, 2019-12-17 00:00:00, 2019-12-18 00:00:00, 2019-12-19 00:00:00, 2019-12-20 00:00:00, ...]
#
# [526 rows x 0 columns]

# %%
# 산업별 ETF 
ETF = data.DataReader(['IYK','IXN','IBUY','PBS','PJP','SOXX','RTH','MJ','FTXG', 'IYK', 'XLC'],'yahoo','2019-08-02','2021-08-31')

ETF['Adj Close'].plot(figsize=(16, 9))
ETF['Adj Close'].to_csv('./ETF_price_2y.csv')

# %%
stock['Adj Close']
# stock['Adj Close'].to_csv('./stock_price_2y.csv')
# Out:
# Symbols           TSLA        MSFT         AMZN        SPOT        PFE  \
# Date
# 2019-08-01   46.770000  134.815811  1855.319946  155.610001  33.523739
# 2019-08-02   46.868000  133.683090  1823.239990  153.470001  33.304634
# 2019-08-05   45.664001  129.103287  1765.130005  150.000000  32.393139
# 2019-08-06   46.150002  131.525024  1787.829956  151.440002  32.384373
# 2019-08-07   46.683998  132.101120  1793.400024  151.779999  32.060089
# ...                ...         ...          ...         ...        ...
# 2021-08-25  711.200012  302.010010  3299.179932  226.899994  47.509998
# 2021-08-26  701.159973  299.089996  3316.000000  224.619995  47.380001
# 2021-08-27  711.919983  299.720001  3349.629883  226.020004  46.599998
# 2021-08-30  730.909973  303.589996  3421.570068  233.119995  46.759998
# 2021-08-31  735.719971  301.880005  3470.790039  234.339996  46.070000
#
# Symbols            AMD         WMT         MO         KO         NKE  \
# Date
# 2019-08-01   29.860001  105.333084  40.839588  48.796074   81.444290
# 2019-08-02   29.440001  105.352348  40.882233  49.077435   79.504196
# 2019-08-05   27.990000  101.904808  39.790451  48.439697   77.377945
# 2019-08-06   28.860001  103.301147  39.372498  49.021164   79.660957
# 2019-08-07   29.190001  104.196747  39.432201  49.874607   79.641373
# ...                ...         ...        ...        ...         ...
# 2021-08-25  108.300003  148.960007  48.650002  56.070000  169.560196
# 2021-08-26  107.269997  147.350006  48.750000  55.540001  166.645004
# 2021-08-27  111.400002  146.520004  49.529999  55.650002  167.580002
# 2021-08-30  111.320000  147.699997  49.700001  56.180000  168.029999
# 2021-08-31  110.720001  148.100006  50.230000  56.310001  164.740005
#
# Symbols             FB
# Date
# 2019-08-01  192.729996
# 2019-08-02  189.020004
# 2019-08-05  181.729996
# 2019-08-06  184.509995
# 2019-08-07  185.149994
# ...                ...
# 2021-08-25  368.390015
# 2021-08-26  364.380005
# 2021-08-27  372.630005
# 2021-08-30  380.660004
# 2021-08-31  379.380005
#
# [526 rows x 11 columns]

# %%
TSLA = pd.read_csv('./stock_price_2y.csv', 
                         index_col = 'Date',
                        usecols=['Date','TSLA'])

MSFT = pd.read_csv('./stock_price_2y.csv', 
                         index_col = 'Date',
                        usecols=['Date','MSFT'])

AMZN = pd.read_csv('./stock_price_2y.csv', 
                         index_col = 'Date',
                        usecols=['Date','AMZN'])

# %%
ETF_ = pd.read_csv('./ETF_price_2y.csv', 
                         index_col = 'Date',
                        )

# %%
TSLA['IYK'] = ETF_['IYK']
MSFT['IXN'] = ETF_['IXN']
AMZN['IBUY'] = ETF_['IBUY']
TSLA.plot(figsize=(12,9))
MSFT.plot(figsize=(12,9))
AMZN.plot(figsize=(12,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
TSLA['Date'] = TSLA.index
TSLA['Date']
# Out:
# Date
# 2019-08-01    2019-08-01
# 2019-08-02    2019-08-02
# 2019-08-05    2019-08-05
# 2019-08-06    2019-08-06
# 2019-08-07    2019-08-07
#                  ...
# 2021-08-25    2021-08-25
# 2021-08-26    2021-08-26
# 2021-08-27    2021-08-27
# 2021-08-30    2021-08-30
# 2021-08-31    2021-08-31
# Name: Date, Length: 526, dtype: object

# %%
sns.set(rc = {'figure.figsize':(15,8)})
fig, axe1 = plt.subplots()
axe2 = axe1.twinx()
c1 = sns.lineplot(ax = axe1, data = TSLA, x = TSLA['Date'], y = 'TSLA', color = 'red')
c2 = sns.lineplot(ax = axe2, data = TSLA, x = TSLA['Date'], y = 'IYK', color = 'blue')

axe1.legend(['TSLA', 'IYK'])

axe1.set_ylabel('TSLA')
axe2.set_ylabel('IYK')


# fig
# Out:
# Text(0, 0.5, 'IYK')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
fig, axe1 = plt.subplots()
axe2 = axe1.twinx()
c1 = sns.lineplot(ax = axe1, data = AMZN, x = 'Date', y = 'AMZN', color = 'red')
c2 = sns.lineplot(ax = axe2, data = AMZN, x = 'Date', y = 'IBUY', color = 'blue')

axe1.legend(['a', 'b'])

axe1.set_ylabel('a')
axe2.set_ylabel('b')
# Out:
# Text(0, 0.5, 'b')
