# %%
from pandas_datareader import data
# pip install pandas-datareader

# 주가 데이터는 2019-08-01 ~ 2021-08-31

# %%
stock = data.DataReader(['TSLA', 'MSFT', 'AMZN', 'SPOT', 'PFE', 'AMD', 'WMT', 'MO', 'KO', 'NKE', 'FB'],'yahoo','2019-08-02','2021-08-31')

# %%
stock
# stock['Adj Close'].to_csv('./stock_price_2y.csv')
# Out:
# Attributes   Adj Close                                                  \
# Symbols           TSLA        MSFT         AMZN        SPOT        PFE
# Date
# 2019-08-01   46.770000  134.815811  1855.319946  155.610001  33.523739
# 2019-08-02   46.868000  133.683090  1823.239990  153.470001  33.304634
# 2019-08-05   45.664001  129.103287  1765.130005  150.000000  32.393139
# 2019-08-06   46.150002  131.525024  1787.829956  151.440002  32.384373
# 2019-08-07   46.683998  132.101120  1793.400024  151.779999  32.060089
# ...                ...         ...          ...         ...        ...
# 2021-08-25  711.200012  302.010010  3299.179932  226.899994  47.509998
# 2021-08-26  701.159973  299.089996  3316.000000  224.619995  47.380001
# 2021-08-27  711.919983  299.720001  3349.629883  226.020004  46.599998
# 2021-08-30  730.909973  303.589996  3421.570068  233.119995  46.759998
# 2021-08-31  735.719971  301.880005  3470.790039  234.339996  46.070000
#
# ...

# %%
a = data.DataReader(['MSFT'],'yahoo','2019-08-02','2021-08-31')
# a.to_csv('./TSLA_price_2y.csv')

# %%
a.head(526)
# Out:
# Attributes   Adj Close       Close        High         Low        Open  \
# Symbols           MSFT        MSFT        MSFT        MSFT        MSFT
# Date
# 2019-08-01  134.815811  138.059998  140.940002  136.929993  137.000000
# 2019-08-02  133.683090  136.899994  138.320007  135.259995  138.089996
# 2019-08-05  129.103287  132.210007  133.929993  130.779999  133.300003
# 2019-08-06  131.525024  134.690002  135.679993  133.210007  133.800003
# 2019-08-07  132.101120  135.279999  135.649994  131.830002  133.789993
# ...                ...         ...         ...         ...         ...
# 2021-08-25  302.010010  302.010010  304.589996  300.420013  304.299988
# 2021-08-26  299.089996  299.089996  302.429993  298.950012  300.989990
# 2021-08-27  299.720001  299.720001  300.869995  296.829987  298.989990
# 2021-08-30  303.589996  303.589996  304.220001  301.059998  301.119995
# 2021-08-31  301.880005  301.880005  304.500000  301.500000  304.420013
#
# Attributes      Volume
# ...

# %%
(int(a['Adj Close'].loc['2019-08-30']) - int(a['Adj Close'].loc['2019-08-01'])) / int(a['Adj Close'].loc['2019-08-01']) * 100
# Out:
# 0.7462686567164178

# %%
(int(a['Adj Close'].loc['2019-09-30']) - int(a['Adj Close'].loc['2019-09-03'])) / int(a['Adj Close'].loc['2019-09-03']) * 100
# Out:
# 2.2556390977443606

# %%
# 20년 1월
(int(a['Adj Close'].loc['2020-01-31']) - int(a['Adj Close'].loc['2020-01-02'])) / int(a['Adj Close'].loc['2020-01-02']) * 100
# Out:
# 6.369426751592357

# %%
# 20년 2월
(int(a['Adj Close'].loc['2020-02-28']) - int(a['Adj Close'].loc['2020-02-03'])) / int(a['Adj Close'].loc['2020-02-03']) * 100
# Out:
# -7.017543859649122

# %%
# 20년 3월
(int(a['Adj Close'].loc['2020-03-30']) - int(a['Adj Close'].loc['2020-03-02'])) / int(a['Adj Close'].loc['2020-03-02']) * 100
# Out:
# -7.647058823529412

# %%
# 20년 1~3월
# 20년 3월
(int(a['Adj Close'].loc['2020-03-30']) - int(a['Adj Close'].loc['2020-01-02'])) / int(a['Adj Close'].loc['2020-01-02']) * 100
# Out:
# 0.0

# %%
int(a['Adj Close'].loc['2020-03-30'])
# Out:
# 157

# %%
int(a['Adj Close'].loc['2020-01-02'])
# Out:
# 157
