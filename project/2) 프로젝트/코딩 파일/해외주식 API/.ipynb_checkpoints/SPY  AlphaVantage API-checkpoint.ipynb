# %% [markdown]
# # Alphavantage Intraday
# * API for "real time" stock data
# * Freeium model - sign up fro free account to get API key
# * Can make API calls directly or install the helper library:
# pip install alpha_vantage from the command line
#
# #### https://alphavantage.co

# %% [markdown]
# ### 1. Set up Environment

# %%
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %% [markdown]
# ### 2. Store API Key

# %%
# replace with your own API key
key = 'B48ELPKMWRBUJCMP'

# %% [markdown]
# ### 3. Create TimeSeries Object and Make API Call

# %%
ts = TimeSeries(key, output_format='pandas')
# data, meta = ts.get_intraday('TSLA', interval='1min', outputsize='full')
data, meta = ts.get_daily_adjusted(symbol = "SPY", outputsize = 'full')

# %% [markdown]
# ### 4. Examine Data

# %%
meta
# Out:
# {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#  '2. Symbol': 'SPY',
#  '3. Last Refreshed': '2021-09-16',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5505 entries, 2021-09-16 to 1999-11-01
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   1. open               5505 non-null   float64
#  1   2. high               5505 non-null   float64
#  2   3. low                5505 non-null   float64
#  3   4. close              5505 non-null   float64
#  4   5. adjusted close     5505 non-null   float64
#  5   6. volume             5505 non-null   float64
#  6   7. dividend amount    5505 non-null   float64
#  7   8. split coefficient  5505 non-null   float64
# dtypes: float64(8)
# memory usage: 387.1 KB

# %%
data = data[data.index >= '2019-08-01']
data = data[data.index <= '2021-08-31']
data
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  \
# date
# 2021-08-31   452.13  452.490  450.92    451.56         451.560000
# 2021-08-30   450.97  453.070  450.71    452.23         452.230000
# 2021-08-27   447.12  450.650  447.06    450.25         450.250000
# 2021-08-26   448.61  448.860  446.16    446.26         446.260000
# 2021-08-25   448.17  449.457  447.77    448.91         448.910000
# ...             ...      ...     ...       ...                ...
# 2019-08-07   284.40  288.820  282.04    287.97         278.079028
# 2019-08-06   285.91  288.040  284.28    287.80         277.914867
# 2019-08-05   288.09  288.210  281.72    283.82         274.071569
# 2019-08-02   293.85  294.120  290.90    292.62         282.569314
# 2019-08-01   297.60  300.870  293.96    294.84         284.713063
#
#               6. volume  7. dividend amount  8. split coefficient
# date
# 2021-08-31   59300213.0                 0.0                   1.0
# 2021-08-30   48357355.0                 0.0                   1.0
# 2021-08-27   77235113.0                 0.0                   1.0
# 2021-08-26   57829572.0                 0.0                   1.0
# 2021-08-25   40529711.0                 0.0                   1.0
# ...                 ...                 ...                   ...
# 2019-08-07  140572265.0                 0.0                   1.0
# 2019-08-06  120711682.0                 0.0                   1.0
# 2019-08-05  178745449.0                 0.0                   1.0
# 2019-08-02  116749695.0                 0.0                   1.0
# 2019-08-01  142646576.0                 0.0                   1.0
#
# [526 rows x 8 columns]

# %%
plt.plot(data['4. close'])

# %%
data = data.drop(columns=['7. dividend amount', '8. split coefficient'], axis=1)

# %%
data
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close    6. volume
# date
# 2021-08-31   452.13  452.490  450.92    451.56         451.560000   59300213.0
# 2021-08-30   450.97  453.070  450.71    452.23         452.230000   48357355.0
# 2021-08-27   447.12  450.650  447.06    450.25         450.250000   77235113.0
# 2021-08-26   448.61  448.860  446.16    446.26         446.260000   57829572.0
# 2021-08-25   448.17  449.457  447.77    448.91         448.910000   40529711.0
# ...             ...      ...     ...       ...                ...          ...
# 2019-08-07   284.40  288.820  282.04    287.97         278.079028  140572265.0
# 2019-08-06   285.91  288.040  284.28    287.80         277.914867  120711682.0
# 2019-08-05   288.09  288.210  281.72    283.82         274.071569  178745449.0
# 2019-08-02   293.85  294.120  290.90    292.62         282.569314  116749695.0
# 2019-08-01   297.60  300.870  293.96    294.84         284.713063  142646576.0
#
# [526 rows x 6 columns]

# %% [markdown]
# ### 5. Rename Columns and Add Separate Date and Time Columns

# %%
columns = ['Open', 'High', 'Low', 'Close', 'Adj Close','Volume']
data.columns = columns
data = data[['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']]
# ([('Adj Close', 'TSLA'),
#             (    'Close', 'TSLA'),
#             (     'High', 'TSLA'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'TSLA')],

# %%
data
# Out:
#              Adj Close   Close     High     Low    Open       Volume
# date
# 2021-08-31  451.560000  451.56  452.490  450.92  452.13   59300213.0
# 2021-08-30  452.230000  452.23  453.070  450.71  450.97   48357355.0
# 2021-08-27  450.250000  450.25  450.650  447.06  447.12   77235113.0
# 2021-08-26  446.260000  446.26  448.860  446.16  448.61   57829572.0
# 2021-08-25  448.910000  448.91  449.457  447.77  448.17   40529711.0
# ...                ...     ...      ...     ...     ...          ...
# 2019-08-07  278.079028  287.97  288.820  282.04  284.40  140572265.0
# 2019-08-06  277.914867  287.80  288.040  284.28  285.91  120711682.0
# 2019-08-05  274.071569  283.82  288.210  281.72  288.09  178745449.0
# 2019-08-02  282.569314  292.62  294.120  290.90  293.85  116749695.0
# 2019-08-01  284.713063  294.84  300.870  293.96  297.60  142646576.0
#
# [526 rows x 6 columns]

# %%
data.to_csv('./SPY.csv')
