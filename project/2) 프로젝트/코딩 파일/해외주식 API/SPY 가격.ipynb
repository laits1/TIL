# %%
import yfinance as yf
from pandas_datareader import data
import pandas as pd

# %%
SPY = data.DataReader(['SPY'],'yahoo','2019-08-02','2021-08-31')
SPY['Adj Close'].plot(figsize=(16, 9))
SPY['Adj Close'].to_csv('./SPY_price_2y.csv')

# %%
SPY['Adj Close']
# Out:
# Symbols            SPY
# Date
# 2019-08-01  284.827087
# 2019-08-02  282.682526
# 2019-08-05  274.181305
# 2019-08-06  278.026184
# 2019-08-07  278.190399
# ...                ...
# 2021-08-25  448.910004
# 2021-08-26  446.260010
# 2021-08-27  450.250000
# 2021-08-30  452.230011
# 2021-08-31  451.559998
#
# [526 rows x 1 columns]
