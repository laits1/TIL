# %%
import numpy as np
import pandas as pd

# %% [markdown]
#     서울시 고령자 통계현황
#     데이터 출처 : https://data.seoul.go.kr/dataList/10020/S/2/datasetView.do

# %% [markdown]
# ### read_csv 하는데 필요한 파일 목록
#
# - ./data/서울시_고령자현황(동별)통계(2017).txt
# - ./data/서울시_고령자현황(동별)통계(2018).txt
# - ./data/서울시_고령자현황(동별)통계(2019).txt
# - ./data/서울시_고령자현황(동별)통계(2020).txt

# %% [markdown]
# ### 파일 저장 이름
#
# - ./fin_data/서울시_고령자현황(구별)통계(2017).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2018).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2019).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2020).csv

# %%
Elder3 = pd.read_csv("./data/서울시_고령자현황(동별)통계(2019).txt",delimiter = '\t')

# %%
Elder3.head()

# %%
Elder3.rename(columns={
        '전체인구' : '전체인구(계)',
        '전체인구.1' : '전체인구(남)',
        '전체인구.2' : '전체인구(여)',
        '65세이상 인구' : '65세이상 인구(계)',
        '65세이상 인구.1' : '65세이상 인구(남)',
        '65세이상 인구.2' : '65세이상 인구(여)',
}, inplace=True)

# %%
Elder3.head()
# Out:
#      기간  자치구    동     전체인구(계)    전체인구(남)    전체인구(여) 65세이상 인구(계) 65세이상 인구(남)  \
# 0    기간  자치구    동        전체인구       전체인구       전체인구          합계          합계
# 1    기간  자치구    동           계         남자         여자           계          남자
# 2  2019   합계   합계  10,010,983  4,877,725  5,133,258   1,485,272     656,595
# 3  2019  종로구   소계     161,869     78,215     83,654      27,519      12,162
# 4  2019  종로구  사직동       9,815      4,455      5,360       1,778         759
#
#   65세이상 인구(여) 65세이상 인구.3 65세이상 인구.4 65세이상 인구.5 65세이상 인구.6 65세이상 인구.7  \
# 0          합계        내국인        내국인        내국인        외국인        외국인
# 1          여자          계         남자         여자          계         남자
# 2     828,677  1,478,664    653,108    825,556      6,608      3,487
# 3      15,357     27,318     12,049     15,269        201        113
# 4       1,019      1,767        753      1,014         11          6
#
#   65세이상 인구.8
# 0        외국인
# 1         여자
# 2      3,121
# 3         88
# 4          5

# %%
Elder3_1=Elder3.loc[:,['기간','자치구','동','전체인구(계)','전체인구(남)','전체인구(여)','65세이상 인구(계)','65세이상 인구(남)','65세이상 인구(여)']]

# %%
Elder3_1.drop([0,1],inplace = True)

# %%
Elder3_1.reset_index(inplace=True, drop=True)

# %%
Elder3_2 = Elder3_1[Elder3_1['동'] == '소계']
Elder3_2.reset_index(inplace=True, drop=True)

# %%
Elder3_3 =Elder3_2.drop(['동'],axis=1)

# %%
Elder3_3.to_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv", index = False)

# %%
el = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv")
el.head()

# %%
Elder3_4 = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv",thousands=',')

# %%
Elder3_4.head()
# Out:
#      기간  자치구  전체인구(계)  전체인구(남)  전체인구(여)  65세이상 인구(계)  65세이상 인구(남)  65세이상 인구(여)
# 0  2019  종로구   161869    78215    83654        27519        12162        15357
# 1  2019   중구   136488    66823    69665        23275        10247        13028
# 2  2019  용산구   245185   119599   125586        38791        16466        22325
# 3  2019  성동구   308979   150861   158118        43947        19181        24766
# 4  2019  광진구   366972   176917   190055        47902        21360        26542

# %%
# 노인 비율과 여성 노인 비율, 남성 노인 비율을 구하였다.
#2017년
Elder1_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder1_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder1_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
#2018년
Elder2_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder2_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder2_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
#2019년
Elder3_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
#2020년
Elder4_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder4_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder4_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f4b88ce55a70> in <module>
#       1 #2019년
# ----> 2 Elder3_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
#       3 Elder3_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
#       4 Elder3_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
#
# NameError: name 'Elder1_4' is not defined

# %%
#2019년
Elder3_4["노인 비율%(계)"]= round(Elder3_4["65세이상 인구(계)"]/ Elder3_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(남)"]= round(Elder3_4["65세이상 인구(남)"]/ Elder3_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(여)"]= round(Elder3_4["65세이상 인구(여)"]/ Elder3_4["전체인구(계)"] * 100,2)

# %%
Elder3_4.sort_values(by="노인 비율%(계)", ascending=True)
# Out:
#       기간   자치구  전체인구(계)  전체인구(남)  전체인구(여)  65세이상 인구(계)  65세이상 인구(남)  \
# 23  2019   송파구   682741   330412   352329        87334        40350
# 22  2019   강남구   550209   263345   286864        71025        31935
# 4   2019   광진구   366972   176917   190055        47902        21360
# 21  2019   서초구   435107   208181   226926        57136        25886
# 14  2019   양천구   462285   227019   235266        61264        27446
# 13  2019   마포구   385925   181303   204622        52429        21954
# 15  2019   강서구   598273   289691   308582        84077        37157
# 3   2019   성동구   308979   150861   158118        43947        19181
# 24  2019   강동구   440390   217338   223052        63452        28968
# 18  2019  영등포구   400986   200986   200000        57872        26142
# 20  2019   관악구   517334   259194   258140        75194        33591
# 17  2019   금천구   251820   128954   122866        37660        17184
# 16  2019   구로구   439371   219602   219769        65779        30089
# 10  2019   노원구   537303   259810   277493        80923        34024
# 19  2019   동작구   408912   197706   211206        62226        27087
# 7   2019   성북구   454744   219099   235645        70850        30498
# 2   2019   용산구   245185   119599   125586        38791        16466
# 12  2019  서대문구   323171   153215   169956        52074        22030
# 6   2019   중랑구   402024   199006   203018        65164        29136
# 5   2019  동대문구   363023   178490   184533        59350        26397
# 11  2019   은평구   484546   233360   251186        80738        34987
# 0   2019   종로구   161869    78215    83654        27519        12162
# 1   2019    중구   136488    66823    69665        23275        10247
# 9   2019   도봉구   335631   163961   171670        58714        26286
# 8   2019   강북구   317695   154638   163057        60577        26032
#
#     65세이상 인구(여)  노인 비율%(계)  노인 비율%(남)  노인 비율%(여)
# 23        46984      12.79       5.91       6.88
# 22        39090      12.91       5.80       7.10
# 4         26542      13.05       5.82       7.23
# 21        31250      13.13       5.95       7.18
# 14        33818      13.25       5.94       7.32
# 13        30475      13.59       5.69       7.90
# 15        46920      14.05       6.21       7.84
# 3         24766      14.22       6.21       8.02
# 24        34484      14.41       6.58       7.83
# 18        31730      14.43       6.52       7.91
# 20        41603      14.53       6.49       8.04
# 17        20476      14.96       6.82       8.13
# 16        35690      14.97       6.85       8.12
# 10        46899      15.06       6.33       8.73
# 19        35139      15.22       6.62       8.59
# 7         40352      15.58       6.71       8.87
# 2         22325      15.82       6.72       9.11
# 12        30044      16.11       6.82       9.30
# 6         36028      16.21       7.25       8.96
# 5         32953      16.35       7.27       9.08
# 11        45751      16.66       7.22       9.44
# 0         15357      17.00       7.51       9.49
# 1         13028      17.05       7.51       9.55
# 9         32428      17.49       7.83       9.66
# 8         34545      19.07       8.19      10.87

# %%
Elder1_5=Elder1_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder2_5=Elder2_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder3_5=Elder3_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder4_5=Elder4_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]

# %%
Elder1_6=Elder1_5.sort_values(by='자치구', ascending = True)
Elder2_6=Elder2_5.sort_values(by='자치구', ascending = True)
Elder3_6=Elder3_5.sort_values(by='자치구', ascending = True)
Elder4_6=Elder4_5.sort_values(by='자치구', ascending = True)

# %%
Elder1_6.head()

# %%
#비율 넣은것 반영하여 저장
Elder1_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv", index = False)
Elder2_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2018).csv", index = False)
Elder3_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv", index = False)
Elder4_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2020).csv", index = False)
