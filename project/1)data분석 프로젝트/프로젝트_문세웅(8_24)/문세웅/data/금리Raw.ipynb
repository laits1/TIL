# %%
import pandas as pd
df = pd.read_excel('금리.xls')
print(df.head(10))
# Out:
#          통계표명:                  시장금리 추이 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          단위:              기간중 평균금리, %        NaN        NaN        NaN
# 1          NaN                  201701월    201702월    201703월    201704월
# 2   국고채 3년(평균)                     1.64       1.67       1.71       1.68
# 3   국고채 5년(평균)                     1.82       1.86       1.91       1.86
# 4  국고채 10년(평균)                     2.11       2.16       2.22       2.18
# 5   회사채 3년(평균)                     2.10       2.13       2.21       2.20
# 6   CD 91물(평균)                     1.50       1.49       1.48       1.43
# 7  콜금리(1일물,평균)                     1.24       1.23       1.23       1.23
# 8         기준금리                     1.25       1.25       1.25       1.25
# 9          출처:  한국은행 경제통계시스템 &gt; 4. 금리        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 39  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# ...

# %%
df1 = df.iloc[8:9]
df1
# Out:
#   통계표명: 시장금리 추이 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8  기준금리    1.25       1.25       1.25       1.25       1.25       1.25
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 8       1.25       1.25       1.25  ...        0.75        0.75        0.50
#
#   Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47  \
# 8        0.50        0.50        0.50        0.50        0.50        0.50
#
#   Unnamed: 48
# 8        0.50
#
# [1 rows x 49 columns]

# %%
df1.rename(columns = {'통계표명:': '년월'} , inplace = True)
# Out:
# /Users/sewoongmoon/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df1
# Out:
#      년월 시장금리 추이 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8  기준금리    1.25       1.25       1.25       1.25       1.25       1.25
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 8       1.25       1.25       1.25  ...        0.75        0.75        0.50
#
#   Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47  \
# 8        0.50        0.50        0.50        0.50        0.50        0.50
#
#   Unnamed: 48
# 8        0.50
#
# [1 rows x 49 columns]

# %%
df1.columns = ['년월','2017년 01월',
 '2017년 02월',
 '2017년 03월',
 '2017년 04월',
 '2017년 05월',
 '2017년 06월',
 '2017년 07월',
 '2017년 08월',
 '2017년 09월',
 '2017년 10월',
 '2017년 11월',
 '2017년 12월',
 '2018년 01월',
 '2018년 02월',
 '2018년 03월',
 '2018년 04월',
 '2018년 05월',
 '2018년 06월',
 '2018년 07월',
 '2018년 08월',
 '2018년 09월',
 '2018년 10월',
 '2018년 11월',
 '2018년 12월',
 '2019년 01월',
 '2019년 02월',
 '2019년 03월',
 '2019년 04월',
 '2019년 05월',
 '2019년 06월',
 '2019년 07월',
 '2019년 08월',
 '2019년 09월',
 '2019년 10월',
 '2019년 11월',
 '2019년 12월',
 '2020년 01월',
 '2020년 02월',
 '2020년 03월',
 '2020년 04월',
 '2020년 05월',
 '2020년 06월',
 '2020년 07월',
 '2020년 08월',
 '2020년 09월',
 '2020년 10월',
 '2020년 11월',
 '2020년 12월']

# %%
df1
# Out:
#      년월 시장금리 추이 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8  기준금리    1.25       1.25       1.25       1.25       1.25       1.25
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 8       1.25       1.25       1.25  ...        0.75        0.75        0.50
#
#   Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47  \
# 8        0.50        0.50        0.50        0.50        0.50        0.50
#
#   Unnamed: 48
# 8        0.50
#
# [1 rows x 49 columns]

# %%
df1.to_csv(r'./fin_data/월별금리.csv', index = False, header = True)
