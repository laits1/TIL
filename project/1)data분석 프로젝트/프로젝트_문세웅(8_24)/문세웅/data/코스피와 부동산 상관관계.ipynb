# %%
import pandas as pd

# %%
df = pd.read_csv('경제지표정리&부동산데이터.csv', index_col= 'Unnamed: 0')

df
# Out:
#                환율    코스피지수  기준금리  가계대출(10억원)  주택대출(10억원)  거래금액(만원)/전용면적(㎡)
# 2017년 01월  1157.8  2061.73  1.25    262293.2    167698.8        693.758417
# 2017년 02월  1132.1  2082.80  1.25    262727.2    167852.0        707.802216
# 2017년 03월  1116.1  2136.17  1.25    263208.1    168377.3        715.644826
# 2017년 04월  1130.1  2160.18  1.25    264498.4    169036.1        748.518192
# 2017년 05월  1123.9  2301.89  1.25    266384.9    169838.4        782.537756
# 2017년 06월  1139.6  2372.20  1.25    268358.5    171044.5        724.001342
# 2017년 07월  1119.1  2412.90  1.25    271009.2    172570.4        769.445083
# 2017년 08월  1122.8  2372.18  1.25    274899.9    174607.2        711.428585
# 2017년 09월  1146.7  2371.84  1.25    276197.3    174828.7        798.817388
# 2017년 10월  1125.0  2482.87  1.25    278568.7    175427.9        805.141879
# 2017년 11월  1082.4  2533.51  1.50    281452.2    176351.5        867.701066
# ...

# %%
from sklearn.preprocessing import MinMaxScaler



scaler = MinMaxScaler()

df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df_scaled
# Out:
#           환율     코스피지수  기준금리  가계대출(10억원)  주택대출(10억원)  거래금액(만원)/전용면적(㎡)
# 0   0.528051  0.283771   0.6    0.000000    0.000000          0.000000
# 1   0.379410  0.305515   0.6    0.004275    0.003248          0.021479
# 2   0.286871  0.360591   0.6    0.009012    0.014385          0.033473
# 3   0.367843  0.385369   0.6    0.021721    0.028353          0.083750
# 4   0.331984  0.531609   0.6    0.040303    0.045362          0.135779
# 5   0.422788  0.604167   0.6    0.059743    0.070933          0.046254
# 6   0.304222  0.646168   0.6    0.085852    0.103284          0.115755
# 7   0.325622  0.604146   0.6    0.124175    0.146467          0.027025
# 8   0.463852  0.603796   0.6    0.136954    0.151163          0.160677
# 9   0.338346  0.718375   0.6    0.160312    0.163867          0.170350
# 10  0.091961  0.770634   0.8    0.188714    0.183449          0.266028
# 11  0.028340  0.702751   0.8    0.198431    0.197007          0.268126
# ...

# %%
df17= df.iloc[0:1]
df17
# Out:
#                환율    코스피지수  기준금리  가계대출(10억원)  주택대출(10억원)  거래금액(만원)/전용면적(㎡)
# 2017년 01월  1157.8  2061.73  1.25    262293.2    167698.8        693.758417

# %%
df18 = df.iloc[12:13]
df19 = df.iloc[24:25]
df20 = df.iloc[36:37]
df1 = pd.concat([df17,df18,df19,df20],ignore_index=False)
df1
# Out:
#                환율    코스피지수  기준금리  가계대출(10억원)  주택대출(10억원)  거래금액(만원)/전용면적(㎡)
# 2017년 01월  1157.8  2061.73  1.25    262293.2    167698.8        693.758417
# 2018년 01월  1071.5  2520.94  1.50    283669.8    177280.4        852.312235
# 2019년 01월  1117.2  2101.98  1.75    301208.6    183577.9        831.876131
# 2020년 01월  1183.5  2203.44  1.25    323866.6    195176.2        904.365578

# %%
df2 = df1.corr(method='pearson')
df2
# Out:
#                         환율     코스피지수      기준금리  가계대출(10억원)  주택대출(10억원)  \
# 환율                1.000000 -0.700217 -0.651146    0.323081    0.338975
# 코스피지수            -0.700217  1.000000  0.098472    0.035199    0.062211
# 기준금리             -0.651146  0.098472  1.000000    0.103999    0.049436
# 가계대출(10억원)        0.323081  0.035199  0.103999    1.000000    0.997978
# 주택대출(10억원)        0.338975  0.062211  0.049436    0.997978    1.000000
# 거래금액(만원)/전용면적(㎡) -0.079051  0.479598  0.210438    0.890528    0.896511
#
#                   거래금액(만원)/전용면적(㎡)
# 환율                       -0.079051
# 코스피지수                     0.479598
# 기준금리                      0.210438
# 가계대출(10억원)                0.890528
# 주택대출(10억원)                0.896511
# 거래금액(만원)/전용면적(㎡)          1.000000

# %%
df3 = pd.DataFrame({'경제지표':['1개월단위 코스피', '1년단위 코스피', '주택대출'],
                   '부동산가격과의 상관계수':[-0.018602,0.7381,0.896511]})
df3
# Out:
#         경제지표  부동산가격과의 상관계수
# 0  1개월단위 코스피     -0.018602
# 1   1년단위 코스피      0.738100
# 2       주택대출      0.896511

# %%
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' #한글폰트 깨짐 방지

# %%
plt.rcParams['font.family'] = 'AppleGothic'

plt.rc("axes", unicode_minus = False)

# %%
df3.plot.bar(x="경제지표", y="부동산가격과의 상관계수", rot=0, fontsize=10)
# Out:
# <AxesSubplot:xlabel='경제지표'>
