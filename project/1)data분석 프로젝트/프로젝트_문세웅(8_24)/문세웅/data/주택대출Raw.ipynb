# %%
##데이터 출처 https://www.r-one.co.kr/rone/resis/statistics/statisticsViewer.do?menuId=SNI_72100.

# %%
import pandas as pd
df = pd.read_excel('주택대출.xlsx')
print(df.head(15))
# Out:
#       * 통계표명 :                   주택대출 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     * 수록기간 :  2007년 12월 ~ 2021년 05월        NaN        NaN        NaN
# 1     * 조회기간 :  2017년 01월 ~ 2020년 12월        NaN        NaN        NaN
# 2       * 출처 :                   한국은행        NaN        NaN        NaN
# 3   * 자료다운일자 :    2021.08.18 14:48:01        NaN        NaN        NaN
# 4       * 단위 :                    십억원        NaN        NaN        NaN
# 5          NaN                    NaN        NaN        NaN        NaN
# 6          NaN                    NaN        NaN        NaN        NaN
# 7          NaN                    NaN        NaN        NaN        NaN
# 8          NaN                    NaN        NaN        NaN        NaN
# 9          지 역              2017년 01월  2017년 02월  2017년 03월  2017년 04월
# 10          전국               545880.7     547746   550692.5   553204.1
# 11          서울               167698.8     167852   168377.3   169036.1
# ...

# %%
df1 = df.iloc[9:12, 1:] # 필요없는 행과 열 슬라이싱
df2 = df1.drop(10)      # 10번행('전국') 삭제
df2.rename(index = {9: '년월', 11: '주택대출(10억원)'} , inplace = True) # 인덱스 이름 변경
df2.to_csv(r'./fin_data/주택대출.csv', index = True, header = False)  # 데이터 저장
# Out:
#       * 통계표명 :                   주택대출 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     * 수록기간 :  2007년 12월 ~ 2021년 05월        NaN        NaN        NaN
# 1     * 조회기간 :  2017년 01월 ~ 2020년 12월        NaN        NaN        NaN
# 2       * 출처 :                   한국은행        NaN        NaN        NaN
# 3   * 자료다운일자 :    2021.08.18 14:48:01        NaN        NaN        NaN
# 4       * 단위 :                    십억원        NaN        NaN        NaN
# 5          NaN                    NaN        NaN        NaN        NaN
# 6          NaN                    NaN        NaN        NaN        NaN
# 7          NaN                    NaN        NaN        NaN        NaN
# 8          NaN                    NaN        NaN        NaN        NaN
# 9          지 역              2017년 01월  2017년 02월  2017년 03월  2017년 04월
# 10          전국               545880.7     547746   550692.5   553204.1
# 11          서울               167698.8     167852   168377.3   169036.1
# ...

# %%
df2 = df1.drop(10)
df2
# Out:
#          주택대출 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 9   2017년 01월  2017년 02월  2017년 03월  2017년 04월  2017년 05월  2017년 06월
# 11   167698.8     167852   168377.3   169036.1   169838.4   171044.5
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 39 Unnamed: 40  \
# 9   2017년 07월  2017년 08월  2017년 09월   2017년 10월  ...   2020년 03월   2020년 04월
# 11   172570.4   174607.2   174828.7    175427.9  ...    198287.6      200025
#
#    Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46  \
# 9    2020년 05월   2020년 06월   2020년 07월   2020년 08월   2020년 09월   2020년 10월
# 11    201328.2    202582.3      203613    205553.4    208142.8    210849.5
#
#    Unnamed: 47 Unnamed: 48
# 9    2020년 11월   2020년 12월
# 11    212534.2    214865.7
#
# [2 rows x 48 columns]

# %%
df2.rename(index = {9: '년월', 11: '주택대출(10억원)'} , inplace = True)

# %%
df2.to_csv(r'./fin_data/주택대출.csv', index = True, header = False)
