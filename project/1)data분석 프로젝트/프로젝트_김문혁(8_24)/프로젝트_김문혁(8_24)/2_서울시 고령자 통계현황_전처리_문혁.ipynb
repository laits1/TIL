# %%
import numpy as np
import pandas as pd

# %% [markdown]
#     서울시 고령자 통계현황
#     데이터 출처 : https://data.seoul.go.kr/dataList/10020/S/2/datasetView.do

# %% [markdown]
# ### read_csv 하는데 필요한 파일 목록
#
# - ./data/서울시_고령자현황(동별)통계(2017).txt
# - ./data/서울시_고령자현황(동별)통계(2018).txt
# - ./data/서울시_고령자현황(동별)통계(2019).txt
# - ./data/서울시_고령자현황(동별)통계(2020).txt

# %% [markdown]
# ### 파일 저장 이름
#
# - ./fin_data/서울시_고령자현황(구별)통계(2017).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2018).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2019).csv
# - ./fin_data/서울시_고령자현황(구별)통계(2020).csv

# %%
Elder1 = pd.read_csv("./data/서울시_고령자현황(동별)통계(2017).txt",delimiter = '\t')
Elder2 = pd.read_csv("./data/서울시_고령자현황(동별)통계(2018).txt",delimiter = '\t')
Elder3 = pd.read_csv("./data/서울시_고령자현황(동별)통계(2019).txt",delimiter = '\t')
Elder4 = pd.read_csv("./data/서울시_고령자현황(동별)통계(2020).txt",delimiter = '\t')

# %%
Elder1.head()
# Out:
#      기간  자치구    동        전체인구     전체인구.1     전체인구.2   65세이상 인구 65세이상 인구.1  \
# 0    기간  자치구    동        전체인구       전체인구       전체인구         합계         합계
# 1    기간  자치구    동           계         남자         여자          계         남자
# 2  2017   합계   합계  10,124,579  4,957,857  5,166,722  1,365,126    602,107
# 3  2017  종로구   소계     164,257     80,094     84,163     26,182     11,441
# 4  2017  종로구  사직동       9,717      4,467      5,250      1,708        734
#
#   65세이상 인구.2 65세이상 인구.3 65세이상 인구.4 65세이상 인구.5 65세이상 인구.6 65세이상 인구.7 65세이상 인구.8
# 0         합계        내국인        내국인        내국인        외국인        외국인        외국인
# 1         여자          계         남자         여자          계         남자         여자
# 2    763,019  1,359,901    599,378    760,523      5,225      2,729      2,496
# 3     14,741     26,030     11,356     14,674        152         85         67
# 4        974      1,698        729        969         10          5          5

# %%
Elder1.rename(columns={'전체인구' : '전체인구(계)',}, inplace=True) # 열변경
Elder1_1=Elder1.loc[:,['기간',]] # 필요한 열만 저장
Elder1_1.drop([0,1],inplace = True) # 필요없는 행 삭제
Elder1_1.reset_index(inplace=True, drop=True) # 인덱스 리셋
Elder1_2 = Elder1_1[Elder1_1['동'] == '소계'] # 구 단위로 필터링
Elder1_2["노인 비율%(계)"]= round(Elder1_2["65세이상 인구(계)"]/ Elder1_2["전체인구(계)"] * 100,2)
# 필요한 열 생성
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '동'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f749085b2f70> in <module>
#       3 Elder1_1.drop([0,1],inplace = True) # 필요없는 행 삭제
#       4 Elder1_1.reset_index(inplace=True, drop=True) # 인덱스 리셋
# ----> 5 Elder1_2 = Elder1_1[Elder1_1['동'] == '소계'] # 구 단위로 필터링
#       6 Elder1_2["노인 비율%(계)"]= round(Elder1_2["65세이상 인구(계)"]/ Elder1_2["전체인구(계)"] * 100,2)
#       7 # 필요한 열 생성
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '동'

# %%
# 외국인 데이터는 내국인과 구별해서 쓰지 않으므로 삭제
# 데이터 정리를 위하여 열 이름 변경
Elder1.rename(columns={
        '전체인구' : '전체인구(계)',
        '전체인구.1' : '전체인구(남)',
        '전체인구.2' : '전체인구(여)',
        '65세이상 인구' : '65세이상 인구(계)',
        '65세이상 인구.1' : '65세이상 인구(남)',
        '65세이상 인구.2' : '65세이상 인구(여)',
}, inplace=True) # inplace=True -> 원본 반영

Elder2.rename(columns={
        '전체인구' : '전체인구(계)',
        '전체인구.1' : '전체인구(남)',
        '전체인구.2' : '전체인구(여)',
        '65세이상 인구' : '65세이상 인구(계)',
        '65세이상 인구.1' : '65세이상 인구(남)',
        '65세이상 인구.2' : '65세이상 인구(여)',
}, inplace=True)

Elder3.rename(columns={
        '전체인구' : '전체인구(계)',
        '전체인구.1' : '전체인구(남)',
        '전체인구.2' : '전체인구(여)',
        '65세이상 인구' : '65세이상 인구(계)',
        '65세이상 인구.1' : '65세이상 인구(남)',
        '65세이상 인구.2' : '65세이상 인구(여)',
}, inplace=True)

Elder4.rename(columns={
        '전체인구' : '전체인구(계)',
        '전체인구.1' : '전체인구(남)',
        '전체인구.2' : '전체인구(여)',
        '65세이상 인구' : '65세이상 인구(계)',
        '65세이상 인구.1' : '65세이상 인구(남)',
        '65세이상 인구.2' : '65세이상 인구(여)',
}, inplace=True)

# %%
Elder1.head()
# Out:
#      기간  자치구    동     전체인구(계)    전체인구(남)    전체인구(여) 65세이상 인구(계) 65세이상 인구(남)  \
# 0    기간  자치구    동        전체인구       전체인구       전체인구          합계          합계
# 1    기간  자치구    동           계         남자         여자           계          남자
# 2  2017   합계   합계  10,124,579  4,957,857  5,166,722   1,365,126     602,107
# 3  2017  종로구   소계     164,257     80,094     84,163      26,182      11,441
# 4  2017  종로구  사직동       9,717      4,467      5,250       1,708         734
#
#   65세이상 인구(여) 65세이상 인구.3 65세이상 인구.4 65세이상 인구.5 65세이상 인구.6 65세이상 인구.7  \
# 0          합계        내국인        내국인        내국인        외국인        외국인
# 1          여자          계         남자         여자          계         남자
# 2     763,019  1,359,901    599,378    760,523      5,225      2,729
# 3      14,741     26,030     11,356     14,674        152         85
# 4         974      1,698        729        969         10          5
#
#   65세이상 인구.8
# 0        외국인
# 1         여자
# 2      2,496
# 3         67
# 4          5

# %%
# 삭제하지 않는 데이터만 저장
Elder1_1=Elder1.loc[:,['기간','자치구','동','전체인구(계)','전체인구(남)','전체인구(여)','65세이상 인구(계)','65세이상 인구(남)','65세이상 인구(여)']]
Elder2_1=Elder2.loc[:,['기간','자치구','동','전체인구(계)','전체인구(남)','전체인구(여)','65세이상 인구(계)','65세이상 인구(남)','65세이상 인구(여)']]
Elder3_1=Elder3.loc[:,['기간','자치구','동','전체인구(계)','전체인구(남)','전체인구(여)','65세이상 인구(계)','65세이상 인구(남)','65세이상 인구(여)']]
Elder4_1=Elder4.loc[:,['기간','자치구','동','전체인구(계)','전체인구(남)','전체인구(여)','65세이상 인구(계)','65세이상 인구(남)','65세이상 인구(여)']]

# %%
# 0번행과 1번행은 필요 없으므로 삭제
Elder1_1.drop([0,1],inplace = True)
Elder2_1.drop([0,1],inplace = True)
Elder3_1.drop([0,1],inplace = True)
Elder4_1.drop([0,1],inplace = True)

# %%
# 앞번의 행이 사라졌으므로 인덱스 리셋하기
Elder1_1.reset_index(inplace=True, drop=True)
Elder2_1.reset_index(inplace=True, drop=True)
Elder3_1.reset_index(inplace=True, drop=True)
Elder4_1.reset_index(inplace=True, drop=True)

# %%
# 구단위로 인구수를 구하기 위해 합계인 데이터만 필터링 후 인덱스 초기화
Elder1_2 = Elder1_1[Elder1_1['동'] == '소계']
Elder1_2.reset_index(inplace=True, drop=True)

Elder2_2 = Elder2_1[Elder2_1['동'] == '소계']
Elder2_2.reset_index(inplace=True, drop=True)

Elder3_2 = Elder3_1[Elder3_1['동'] == '소계']
Elder3_2.reset_index(inplace=True, drop=True)

Elder4_2 = Elder4_1[Elder4_1['동'] == '소계']
Elder4_2.reset_index(inplace=True, drop=True)

# %%
# 동단위는 필요 없으므로 열 삭제
Elder1_3 =Elder1_2.drop(['동'],axis=1)
Elder2_3 =Elder2_2.drop(['동'],axis=1)
Elder3_3 =Elder3_2.drop(['동'],axis=1)
Elder4_3 =Elder4_2.drop(['동'],axis=1)

# %%
Elder1_3.head()
# Out:
#      기간  자치구  전체인구(계)  전체인구(남)  전체인구(여) 65세이상 인구(계) 65세이상 인구(남) 65세이상 인구(여)
# 0  2017  종로구  164,257   80,094   84,163      26,182      11,441      14,741
# 1  2017   중구  134,593   66,337   68,256      21,384       9,332      12,052
# 2  2017  용산구  244,444  119,423  125,021      36,882      15,489      21,393
# 3  2017  성동구  312,711  154,077  158,634      41,273      17,972      23,301
# 4  2017  광진구  372,298  180,645  191,653      43,953      19,565      24,388

# %%
#데이터를 csv로 저장하고 중복을 피하기 위해 인덱스 삭제
Elder1_3.to_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv", index = False)
Elder2_3.to_csv("./fin_data/서울시_고령자현황(구별)통계(2018).csv", index = False)
Elder3_3.to_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv", index = False)
Elder4_3.to_csv("./fin_data/서울시_고령자현황(구별)통계(2020).csv", index = False)

# %%
# 잘 저장됐는지 확인
el = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv")
el.head()
# Out:
#      기간  자치구  전체인구(계)  전체인구(남)  전체인구(여) 65세이상 인구(계) 65세이상 인구(남) 65세이상 인구(여)
# 0  2017  종로구  164,257   80,094   84,163      26,182      11,441      14,741
# 1  2017   중구  134,593   66,337   68,256      21,384       9,332      12,052
# 2  2017  용산구  244,444  119,423  125,021      36,882      15,489      21,393
# 3  2017  성동구  312,711  154,077  158,634      41,273      17,972      23,301
# 4  2017  광진구  372,298  180,645  191,653      43,953      19,565      24,388

# %%
Elder1_4 = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv",thousands=',')
Elder2_4 = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2018).csv",thousands=',')
Elder3_4 = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv",thousands=',')
Elder4_4 = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2020).csv",thousands=',')

# %%
Elder1_4.head()
# Out:
#      기간  자치구  전체인구(계)  전체인구(남)  전체인구(여)  65세이상 인구(계)  65세이상 인구(남)  65세이상 인구(여)
# 0  2017  종로구   164257    80094    84163        26182        11441        14741
# 1  2017   중구   134593    66337    68256        21384         9332        12052
# 2  2017  용산구   244444   119423   125021        36882        15489        21393
# 3  2017  성동구   312711   154077   158634        41273        17972        23301
# 4  2017  광진구   372298   180645   191653        43953        19565        24388

# %%
# 노인 비율과 여성 노인 비율, 남성 노인 비율을 구하였다.
#2017년
Elder1_4["노인 비율%(계)"]= round(Elder1_4["65세이상 인구(계)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder1_4["노인 비율%(남)"]= round(Elder1_4["65세이상 인구(남)"]/ Elder1_4["전체인구(계)"] * 100,2)
Elder1_4["노인 비율%(여)"]= round(Elder1_4["65세이상 인구(여)"]/ Elder1_4["전체인구(계)"] * 100,2)
#2018년
Elder2_4["노인 비율%(계)"]= round(Elder2_4["65세이상 인구(계)"]/ Elder2_4["전체인구(계)"] * 100,2)
Elder2_4["노인 비율%(남)"]= round(Elder2_4["65세이상 인구(남)"]/ Elder2_4["전체인구(계)"] * 100,2)
Elder2_4["노인 비율%(여)"]= round(Elder2_4["65세이상 인구(여)"]/ Elder2_4["전체인구(계)"] * 100,2)
#2019년
Elder3_4["노인 비율%(계)"]= round(Elder3_4["65세이상 인구(계)"]/ Elder3_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(남)"]= round(Elder3_4["65세이상 인구(남)"]/ Elder3_4["전체인구(계)"] * 100,2)
Elder3_4["노인 비율%(여)"]= round(Elder3_4["65세이상 인구(여)"]/ Elder3_4["전체인구(계)"] * 100,2)
#2020년
Elder4_4["노인 비율%(계)"]= round(Elder4_4["65세이상 인구(계)"]/ Elder4_4["전체인구(계)"] * 100,2)
Elder4_4["노인 비율%(남)"]= round(Elder4_4["65세이상 인구(남)"]/ Elder4_4["전체인구(계)"] * 100,2)
Elder4_4["노인 비율%(여)"]= round(Elder4_4["65세이상 인구(여)"]/ Elder4_4["전체인구(계)"] * 100,2)

# %%
Elder2_4.head()
# Out:
#      기간  자치구  전체인구(계)  전체인구(남)  전체인구(여)  65세이상 인구(계)  65세이상 인구(남)  \
# 0  2018  종로구   163026    79156    83870        26742        11779
# 1  2018   중구   135633    66674    68959        22005         9635
# 2  2018  용산구   245090   119766   125324        37640        15892
# 3  2018  성동구   316463   155091   161372        42767        18612
# 4  2018  광진구   371063   179527   191536        45619        20291
#
#    65세이상 인구(여)  노인 비율%(계)  노인 비율%(남)  노인 비율%(여)
# 0        14963      16.40       7.23       9.18
# 1        12370      16.22       7.10       9.12
# 2        21748      15.36       6.48       8.87
# 3        24155      13.51       5.88       7.63
# 4        25328      12.29       5.47       6.83

# %%
Elder1_5=Elder1_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder2_5=Elder2_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder3_5=Elder3_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]
Elder4_5=Elder4_4.loc[:,['기간','자치구','노인 비율%(계)','노인 비율%(남)','노인 비율%(여)']]

# %%
Elder1_6=Elder1_5.sort_values(by='자치구', ascending = True)
Elder2_6=Elder2_5.sort_values(by='자치구', ascending = True)
Elder3_6=Elder3_5.sort_values(by='자치구', ascending = True)
Elder4_6=Elder4_5.sort_values(by='자치구', ascending = True)

# %%
Elder1_6.head()
# Out:
#      기간  자치구  노인 비율%(계)  노인 비율%(남)  노인 비율%(여)
# 0  2017  강남구      11.60       5.23       6.37
# 1  2017  강동구      12.75       5.80       6.95
# 2  2017  강북구      17.23       7.41       9.82
# 3  2017  강서구      12.50       5.51       6.99
# 4  2017  관악구      13.45       6.05       7.40

# %%
#비율 넣은것 반영하여 저장
Elder1_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv", index = False)
Elder2_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2018).csv", index = False)
Elder3_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2019).csv", index = False)
Elder4_6.to_csv("./fin_data/서울시_고령자현황(구별)통계(2020).csv", index = False)

# %%
Eld = pd.read_csv("./fin_data/서울시_고령자현황(구별)통계(2017).csv")
