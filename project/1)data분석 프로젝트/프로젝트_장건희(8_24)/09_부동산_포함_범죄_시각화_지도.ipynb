# %%
# 관련 모듈 import 하기
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt #그래프 패키지 모듈 등록
# %matplotlib inline 
#그래프는 show()함수를 통해서 독립창에서 실행되는 것이 원칙
#그래프를 콘솔에서 바로 작동되록 하는 설정

# %%
#한글문제 발생
#matplotlib의 기본폰트에서 한글지원 폰트가 없음
#패키지의 폰트를 추가하고 사용
#윈도우 7 용
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import bs4

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ### 구글맵스 geocode 및 FOLIUM 사용

# %%
import googlemaps

# %%
# goolemaps의 클라이언트객체 생성 - Client(key='api key')
gmapsKey = 'AIzaSyDzhTT-kyiz4DL0-oJCoHGsIvo02cCZymA'
gmaps = googlemaps.Client(key = gmapsKey)
gmaps

# %%
apart_17= pd.read_csv("./data/2017년도_서울시_아파트_평균금액.csv",thousands = ',')
apart_18= pd.read_csv("./data/2018년도_서울시_아파트_평균금액.csv",thousands = ',')
apart_19= pd.read_csv("./data/2019년도_서울시_아파트_평균금액.csv",thousands = ',')
apart_20= pd.read_csv("./data/2020년도_서울시_아파트_평균금액.csv",thousands = ',')

# %%
crime_17 = pd.read_csv("./fin_data/서울시_5대_범죄_발생건수(2017)_10만명당_추가_최종.csv",thousands = ',')
crime_18 = pd.read_csv("./fin_data/서울시_5대_범죄_발생건수(2018)_10만명당_추가_최종.csv",thousands = ',')
crime_19 = pd.read_csv("./fin_data/서울시_5대_범죄_발생건수(2019)_10만명당_추가_최종.csv",thousands = ',')

# %%
apart_17.head(2)
crime_17.head(2)
# Out:
#      구    년도  거래금액(만원)/전용면적(㎡)  거래금액(만원)/1평  거래금액(만원)/국민평수(32평)
# 0  강남구  2017       1466.082319  4846.552940       155089.694095
# 1  강동구  2017        746.577889  2468.025987        78976.831588
#      기간  자치구  범죄_발생_합계  10만명 당 범죄 발생 건수
# 0  2017  강남구      7720      1388.079775
# 1  2017  강동구      4261       976.793979

# %%
# 빈 리스트 3개를 만든다 (주소, 위도, 경도)
gu_address=[]
gu_lat=[]
gu_lng=[]

# %%
gu_name = list(crime_17['자치구'])

# %%
gu_name
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
for name in gu_name :
    tmp = gmaps.geocode(name,language='ko') # geocode(고유명칭, 언어방식)
    gu_address.append(tmp[0].get('formatted_address')) # 구 주소를 저장 : dict.get(key) -> key에 대한 value 반환
    
    # 위/경도 추출
    tmp_loc = tmp[0].get('geometry')
    
    gu_lat.append(tmp_loc['location']['lat']) # latitude 속성이 위도를, 
    gu_lng.append(tmp_loc['location']['lng']) # longitude 속성이 경도를  나타낸다! / 여러 번 실행하면 계속 추가되므로 한번만!
    
    print(name + '------->' + tmp[0].get('formatted_address'))
# Out:
# 강남구------->대한민국 서울특별시 강남구
# 강동구------->대한민국 서울특별시 강동구
# 강북구------->대한민국 서울특별시 강북구
# 강서구------->대한민국 서울특별시 강서구
# 관악구------->대한민국 서울특별시 관악구
# 광진구------->대한민국 서울특별시 광진구
# 구로구------->대한민국 서울특별시 구로구
# 금천구------->대한민국 서울특별시 금천구
# 노원구------->대한민국 서울특별시 노원구
# 도봉구------->대한민국 서울특별시 도봉구
# 동대문구------->대한민국 서울특별시 동대문구
# 동작구------->대한민국 서울특별시 동작구
# 마포구------->대한민국 서울특별시 마포구
# 서대문구------->대한민국 서울특별시 서대문구
# 서초구------->대한민국 서울특별시 서초구
# 성동구------->대한민국 서울특별시 성동구
# 성북구------->대한민국 서울특별시 성북구
# 송파구------->대한민국 서울특별시 송파구
# 양천구------->대한민국 서울특별시 양천구
# 영등포구------->대한민국 서울특별시 영등포구
# 용산구------->대한민국 서울특별시 용산구
# 은평구------->대한민국 서울특별시 은평구
# 종로구------->대한민국 서울특별시 종로구
# 중구------->대한민국 서울특별시 중구
# 중랑구------->대한민국 서울특별시 중랑구

# %%
len(gu_name)
len(gu_address)
len(gu_lat)
len(gu_lng)
# Out:
# 25
# 25
# 25
# 25

# %%
cols = {"구 명" : gu_name,   # 25
        "주소": gu_address,   # 25
        "lat": gu_lat,        # 25
        "lng": gu_lng}        # 25

df_gu = pd.DataFrame(cols, index=range(1,(len(gu_name)+1)))

# %%
df_gu.head()
# Out:
#    구 명              주소        lat         lng
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762
# 3  강북구  대한민국 서울특별시 강북구  37.639610  127.025657
# 4  강서구  대한민국 서울특별시 강서구  37.550979  126.849538
# 5  관악구  대한민국 서울특별시 관악구  37.478406  126.951613

# %% [markdown]
# ### FOLIUM 패키지
# - 지도 이용해 data 시각화 도구 : 아나콘다 프롬프트에서 설치
# - pip install folium
# - open street map과 같은 지도 데이터에 Leaflet.js를 이용해서 위치정보를 시각화 하기 위한 라이브러리
# - 마커 형태로 위치정보를 지도상에 표현 할 수 있다.

# %%
import folium
folium.__version__
# Out:
# '0.12.1'

# %%
import json
geo_path = './서울시 지도.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

# %% [markdown]
# ## 아파트 매매 가격을 지도 배경에 넣기

# %% [markdown]
# # 먼저 데이터프레임을 만들어준다!!

# %%
# 만들어 놓은 df_gu(구와 위도 경도가 있는 데이터 프레임을)
# 새로 만든 df_crime_**에다가 복사! (원본을 넣으면 안된다!!!!!)
df_crime_17 = df_gu.copy()
df_crime_18 = df_gu.copy()
df_crime_19 = df_gu.copy()

# %%
# 우리가 지도에 표시할 범죄_발생_합계 열만 따로 뽑아서 리스트를 만든다
list(crime_17['범죄_발생_합계'])
list(crime_18['범죄_발생_합계'])
list(crime_19['범죄_발생_합계'])
# Out:
# [7720,
#  4261,
#  3393,
#  5135,
#  5525,
#  4646,
#  4895,
#  3265,
#  4209,
#  1999,
#  3975,
#  3330,
#  5278,
#  3113,
#  4708,
#  2767,
#  3434,
#  5576,
#  3882,
#  5969,
#  4060,
#  3883,
#  4057,
#  4184,
#  4571]
# [7513,
#  3919,
#  3437,
#  4629,
#  5026,
#  3915,
#  4810,
#  3293,
#  4007,
#  2249,
#  3680,
#  3100,
#  5172,
#  2802,
#  4726,
#  2457,
#  3042,
#  5807,
#  3515,
#  5840,
#  3411,
#  3590,
#  3690,
#  4030,
#  4288]
# [7304,
#  4014,
#  3838,
#  4924,
#  5328,
#  4011,
#  4707,
#  3105,
#  4153,
#  2110,
#  3692,
#  3400,
#  4842,
#  2943,
#  5542,
#  2512,
#  2877,
#  5698,
#  3214,
#  5820,
#  3313,
#  3880,
#  3846,
#  4327,
#  4268]

# %%
# 만든 리스트를 df_gu에 열로 추가

# %%
df_crime_17['17년_5대범죄_건수'] = list(crime_17['범죄_발생_합계'])
df_crime_18['18년_5대범죄_건수'] = list(crime_18['범죄_발생_합계'])
df_crime_19['19년_5대범죄_건수'] = list(crime_19['범죄_발생_합계'])

# %%
df_crime_17.head(2)
df_crime_18.head(2)
df_crime_19.head(2)
# Out:
#    구 명              주소        lat         lng  17년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7720
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         4261
#    구 명              주소        lat         lng  18년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7513
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         3919
#    구 명              주소        lat         lng  19년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7304
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         4014

# %%
# 범죄 건수가 가장 낮은거 2개, 가장 높은거 2개를 표시해야하므로, 범죄건수를 기준으로 오름차순 정렬을 해준다

df_crime_17.sort_values(by="17년_5대범죄_건수", ascending=True, inplace=True)
df_crime_17.reset_index(drop=True,inplace=True)

df_crime_18.sort_values(by="18년_5대범죄_건수", ascending=True, inplace=True)
df_crime_18.reset_index(drop=True,inplace=True)

df_crime_19.sort_values(by="19년_5대범죄_건수", ascending=True, inplace=True)
df_crime_19.reset_index(drop=True,inplace=True)

# %%
df_crime_17.head(2)
df_crime_18.head(2)
df_crime_19.head(2)
# Out:
#    구 명              주소        lat         lng  17년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         1999
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2767
#    구 명              주소        lat         lng  18년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2249
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2457
#    구 명              주소        lat         lng  19년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2110
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2512

# %% [markdown]
# ### 데이터 프레임 준비 완료!!

# %% [markdown]
# # 2017년도 아파트 매매 가격(apart_2017)

# %%
apart_17.head(2)
# Out:
#      구    년도  거래금액(만원)/전용면적(㎡)  거래금액(만원)/1평  거래금액(만원)/국민평수(32평)
# 0  강남구  2017       1466.082319  4846.552940       155089.694095
# 1  강동구  2017        746.577889  2468.025987        78976.831588

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map17 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=apart_17, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('구', '거래금액(만원)/전용면적(㎡)'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Set1', # 시각화에 쓰일 색상
    legend_name='2017년 거래금액(만원)/전용면적(㎡)', # 범주 이름

).add_to(map17)

# %%
# map17

# %% [markdown]
# ## 2017 아파트 매매가격 지도 위에다 범죄건수 상위 3개, 하위 3개를 덮어 씌우기!

# %%
df_crime_17.head(2)
df_crime_17.tail(2)
# Out:
#    구 명              주소        lat         lng  17년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         1999
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2767
#      구 명               주소        lat         lng  17년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5969
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7720

# %%
# 2017년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_17['lat'][0],df_crime_17['lng'][0]],popup="1999건의 5대 범죄 발생", tooltip=df_crime_17['구 명'][0]).add_to(map17)
folium.Marker([df_crime_17['lat'][1],df_crime_17['lng'][1]],popup="2767건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][1]).add_to(map17)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_17['lat'][23],df_crime_17['lng'][23]],popup="5969건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][23]).add_to(map17)
folium.Marker([df_crime_17['lat'][24],df_crime_17['lng'][24]],popup="7720건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][24]).add_to(map17)

# %%
map17
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4bcfacf532744845bfd51e65aa9ebc2c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4bcfacf532744845bfd51e65aa9ebc2c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4bcfacf532744845bfd51e65aa9ebc2c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4bcfacf532744845bfd51e65aa9ebc2c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # 2018년도 아파트 매매 가격(apart_2018)

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map18 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=apart_18, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('구', '거래금액(만원)/전용면적(㎡)'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Set1', # 시각화에 쓰일 색상
    legend_name='2018년 거래금액(만원)/전용면적(㎡)', # 범주 이름

).add_to(map18)

# %%
# map18

# %%
df_crime_18.head(2)
df_crime_18.tail(2)
# Out:
#    구 명              주소        lat         lng  18년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2249
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2457
#      구 명               주소        lat         lng  18년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5840
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7513

# %% [markdown]
# ## 2018 아파트 매매가격 지도 위에다 범죄건수 상위 2개, 하위 2개를 덮어 씌우기!

# %%
# 2018년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_18['lat'][0],df_crime_18['lng'][0]],popup="2249건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][0]).add_to(map18)
folium.Marker([df_crime_18['lat'][1],df_crime_18['lng'][1]],popup="2457건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][1]).add_to(map18)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_18['lat'][23],df_crime_18['lng'][23]],popup="5840건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][23]).add_to(map18)
folium.Marker([df_crime_18['lat'][24],df_crime_18['lng'][24]],popup="7513건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][24]).add_to(map18)

# %%
map18
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7049fa007c7a4aa5ad5f79e86aec2481%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7049fa007c7a4aa5ad5f79e86aec2481%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7049fa007c7a4aa5ad5f79e86aec2481%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7049fa007c7a4aa5ad5f79e86aec2481%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # 2019년도 아파트 매매 가격(apart_2019)

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map19 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=apart_19, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('구', '거래금액(만원)/전용면적(㎡)'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Set1', # 시각화에 쓰일 색상
    legend_name='2019년 거래금액(만원)/전용면적(㎡)', # 범주 이름

).add_to(map19)

# %%
# map19

# %%
df_crime_19.head(2)
df_crime_19.tail(2)
# Out:
#    구 명              주소        lat         lng  19년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2110
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2512
#      구 명               주소        lat         lng  19년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5820
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7304

# %%
# 2019년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_19['lat'][0],df_crime_19['lng'][0]],popup="2110건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][0]).add_to(map19)
folium.Marker([df_crime_19['lat'][1],df_crime_19['lng'][1]],popup="2512건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][1]).add_to(map19)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_19['lat'][23],df_crime_19['lng'][23]],popup="5820건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][23]).add_to(map19)
folium.Marker([df_crime_19['lat'][24],df_crime_19['lng'][24]],popup="7304건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][24]).add_to(map19)

# %%
map19
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f1b4c7ce05f04d6490c97730323c0443%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f1b4c7ce05f04d6490c97730323c0443%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f1b4c7ce05f04d6490c97730323c0443%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f1b4c7ce05f04d6490c97730323c0443%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # 2020년도 아파트 매매 가격(apart_2020)

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map20 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=apart_17, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('구', '거래금액(만원)/전용면적(㎡)'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Set1', # 시각화에 쓰일 색상
    legend_name='2020년 거래금액(만원)/전용면적(㎡)', # 범주 이름

).add_to(map20)

# %% [markdown]
# ## 범죄 데이터가 19년도 까지 밖에 없어서 2020년은 표시하지 않았다!!!
#
# ## 2020년 데이터가 있는 사람은 본인이 직접 추가하길 바람!

# %%
map20
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e48ca4eadf15440798792656b7553819%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e48ca4eadf15440798792656b7553819%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e48ca4eadf15440798792656b7553819%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e48ca4eadf15440798792656b7553819%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # 만들어 놓은 지도 저장 코드!!

# %%
# 색깔은 이 중에서 본인이 원하는 색 선택 (각각 다르게 하는거 시각화에 좋을 거 같기도하고...)
# fill_color='Set1', # 시각화에 쓰일 색상 -> 여기에 변경하면 됨


# 'Accent': 'Qualitative',
# 'Dark2': 'Qualitative',
# 'Paired': 'Qualitative',
# 'Pastel1': 'Qualitative',
# 'Pastel2': 'Qualitative',
# 'Set1': 'Qualitative',
# 'Set2': 'Qualitative',
# 'Set3': 'Qualitative'

# %%
## 본인 시스템에 맞게 주소와 제목 설정!!

map17.save('C:\DataScience\프로젝트1(8_24)/map_crime_price_relation_17.html')
map18.save('C:\DataScience\프로젝트1(8_24)/map_crime_price_relation_18.html')
map19.save('C:\DataScience\프로젝트1(8_24)/map_crime_price_relation_19.html')
# map20.save('C:\DataScience\프로젝트1(8_24)/map_crime_19.html')
