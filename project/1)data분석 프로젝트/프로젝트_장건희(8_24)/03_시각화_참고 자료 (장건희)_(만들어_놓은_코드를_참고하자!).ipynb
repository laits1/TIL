# %% [markdown]
# ### 03_구글맵스 geocode 및 FOLIUM 사용 -> 서울시_5대_범죄_발생건수(2017)_10만명당_최종(2017, 2018, 2019)

# %%
# 패키지 임포트
import pandas as pd

# %%
# 콘솔에서 모든 출력 허용하기
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ### 시각화가 잘되는지 확인하기 위해 불러옴 (fin_data 폴더에 있다)
# ### crime = pd.read_csv('./fin_data/서울시_5대_범죄_발생건수(2017)_최종.csv',thousands=',')

# %%
#사용 데이터 읽어오기!
crime17 = pd.read_csv('./fin_data/서울시_5대_범죄_발생건수(2017)_10만명당_추가_최종.csv',thousands=',')
crime18 = pd.read_csv('./fin_data/서울시_5대_범죄_발생건수(2018)_10만명당_추가_최종.csv',thousands=',')
crime19 = pd.read_csv('./fin_data/서울시_5대_범죄_발생건수(2019)_10만명당_추가_최종.csv',thousands=',')

# %%
crime17.info()
crime17.info()
crime17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기간               25 non-null     int64
#  1   자치구              25 non-null     object
#  2   범죄_발생_합계         25 non-null     int64
#  3   10만명 당 범죄 발생 건수  25 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 928.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기간               25 non-null     int64
#  1   자치구              25 non-null     object
#  2   범죄_발생_합계         25 non-null     int64
#  3   10만명 당 범죄 발생 건수  25 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 928.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# ...

# %% [markdown]
# ### 구글맵스 패키지 : 서드파티 패키지 (install 해서 사용해야 함)
# - pip install googlemaps - 아나콘다 프롬프트에서 작업
# - 운영체제 cmd 창에서 진행할 경우 path 등록되어있어야 함
# - 관리자 권한으로 실행해야 함-(TLSSSL 에러 발생할 수 있음)

# %%
import googlemaps

# %%
# goolemaps의 클라이언트객체 생성 - Client(key='api key')
gmapsKey = '본인 구글 맵 키'
gmaps = googlemaps.Client(key='AIzaSyDzhTT-kyiz4DL0-oJCoHGsIvo02cCZymA')
gmaps

# %%
tmp = gmaps.geocode('종로구',language='ko')
type(tmp)
# Out:
# list

# %%
tmp[0]
# Out:
# {'address_components': [{'long_name': '종로구',
#    'short_name': '종로구',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': '서울특별시',
#    'short_name': '서울특별시',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국',
#    'short_name': 'KR',
#    'types': ['country', 'political']}],
#  'formatted_address': '대한민국 서울특별시 종로구',
#  'geometry': {'bounds': {'northeast': {'lat': 37.63633859999999,
#     'lng': 127.0234666},
#    'southwest': {'lat': 37.5654828, 'lng': 126.9436969}},
#   'location': {'lat': 37.5729503, 'lng': 126.9793579},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 37.63633859999999, 'lng': 127.0234666},
#    'southwest': {'lat': 37.5654828, 'lng': 126.9436969}}},
#  'place_id': 'ChIJS5wn3S-9fDUR5ly4ei6px1A',
#  'types': ['political', 'sublocality', 'sublocality_level_1']}

# %%
tmp[0]['formatted_address'] # 주소
tmp[0]['geometry']['location']['lat'] # lat -> 위도
tmp[0]['geometry']['location']['lng'] # lng -> 경도
# Out:
# '대한민국 서울특별시 종로구'
# 37.5729503
# 126.9793579

# %%
gu_name = list(crime17['자치구'])

# %% [markdown]
# - geocoder
#     - 고유명칭(주소, 산, 호수의 이름 등)을 가지고 위도(lat)와 경도(lng)의 좌표 값 등 정보를 얻어오는 기능
#     - geocode(고유명칭, 언어방식)

# %%
# 빈 리스트 3개를 만든다 (주소, 위도, 경도)
gu_address=[]
gu_lat=[]
gu_lng=[]

# %%
for name in gu_name :
    tmp = gmaps.geocode(name,language='ko') # geocode(고유명칭, 언어방식)
    gu_address.append(tmp[0].get('formatted_address')) # 구 주소를 저장 : dict.get(key) -> key에 대한 value 반환
    
    # 위/경도 추출
    tmp_loc = tmp[0].get('geometry')
    
    gu_lat.append(tmp_loc['location']['lat']) # latitude 속성이 위도를, 
    gu_lng.append(tmp_loc['location']['lng']) # longitude 속성이 경도를  나타낸다! / 여러 번 실행하면 계속 추가되므로 한번만!
    
    print(name + '------->' + tmp[0].get('formatted_address'))
# Out:
# 강남구------->대한민국 서울특별시 강남구
# 강동구------->대한민국 서울특별시 강동구
# 강북구------->대한민국 서울특별시 강북구
# 강서구------->대한민국 서울특별시 강서구
# 관악구------->대한민국 서울특별시 관악구
# 광진구------->대한민국 서울특별시 광진구
# 구로구------->대한민국 서울특별시 구로구
# 금천구------->대한민국 서울특별시 금천구
# 노원구------->대한민국 서울특별시 노원구
# 도봉구------->대한민국 서울특별시 도봉구
# 동대문구------->대한민국 서울특별시 동대문구
# 동작구------->대한민국 서울특별시 동작구
# 마포구------->대한민국 서울특별시 마포구
# 서대문구------->대한민국 서울특별시 서대문구
# 서초구------->대한민국 서울특별시 서초구
# 성동구------->대한민국 서울특별시 성동구
# 성북구------->대한민국 서울특별시 성북구
# 송파구------->대한민국 서울특별시 송파구
# 양천구------->대한민국 서울특별시 양천구
# 영등포구------->대한민국 서울특별시 영등포구
# 용산구------->대한민국 서울특별시 용산구
# 은평구------->대한민국 서울특별시 은평구
# 종로구------->대한민국 서울특별시 종로구
# 중구------->대한민국 서울특별시 중구
# 중랑구------->대한민국 서울특별시 중랑구

# %%
gu_address
# Out:
# ['대한민국 서울특별시 강남구',
#  '대한민국 서울특별시 강동구',
#  '대한민국 서울특별시 강북구',
#  '대한민국 서울특별시 강서구',
#  '대한민국 서울특별시 관악구',
#  '대한민국 서울특별시 광진구',
#  '대한민국 서울특별시 구로구',
#  '대한민국 서울특별시 금천구',
#  '대한민국 서울특별시 노원구',
#  '대한민국 서울특별시 도봉구',
#  '대한민국 서울특별시 동대문구',
#  '대한민국 서울특별시 동작구',
#  '대한민국 서울특별시 마포구',
#  '대한민국 서울특별시 서대문구',
#  '대한민국 서울특별시 서초구',
#  '대한민국 서울특별시 성동구',
#  '대한민국 서울특별시 성북구',
#  '대한민국 서울특별시 송파구',
#  '대한민국 서울특별시 양천구',
#  '대한민국 서울특별시 영등포구',
#  '대한민국 서울특별시 용산구',
#  '대한민국 서울특별시 은평구',
#  '대한민국 서울특별시 종로구',
#  '대한민국 서울특별시 중구',
#  '대한민국 서울특별시 중랑구']

# %%
len(gu_name)
len(gu_address)
len(gu_lat)
len(gu_lng)
# Out:
# 25
# 25
# 25
# 25

# %%
cols = {"구 명" : gu_name,   # 25
        "주소": gu_address,   # 25
        "lat": gu_lat,        # 25
        "lng": gu_lng}        # 25

df_gu = pd.DataFrame(cols, index=range(1,(len(gu_name)+1)))

# %%
df_gu.head()
# Out:
#    구 명              주소        lat         lng
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762
# 3  강북구  대한민국 서울특별시 강북구  37.639610  127.025657
# 4  강서구  대한민국 서울특별시 강서구  37.550979  126.849538
# 5  관악구  대한민국 서울특별시 관악구  37.478406  126.951613

# %% [markdown]
# ### 지도에 출력하기

# %% [markdown]
# ### FOLIUM 패키지
# - 지도 이용해 data 시각화 도구 : 아나콘다 프롬프트에서 설치
# - pip install folium
# - open street map과 같은 지도 데이터에 Leaflet.js를 이용해서 위치정보를 시각화 하기 위한 라이브러리
# - 마커 형태로 위치정보를 지도상에 표현 할 수 있다.

# %%
import folium
folium.__version__
# Out:
# '0.12.1'

# %%
# 내가 만든 데이터프레임
crime17.head(2)
crime18.head(2)
crime19.head(2)
# Out:
#      기간  자치구  범죄_발생_합계  10만명 당 범죄 발생 건수
# 0  2017  강남구      7720      1388.079775
# 1  2017  강동구      4261       976.793979
#      기간  자치구  범죄_발생_합계  10만명 당 범죄 발생 건수
# 0  2018  강남구      7513      1423.398308
# 1  2018  강동구      3919       996.554974
#      기간  자치구  범죄_발생_합계  10만명 당 범죄 발생 건수
# 0  2019  강남구      7304      1416.074648
# 1  2019  강동구      4014       977.143421

# %%
# 위도, 경도 모아놓은 데이터프레임
df_gu.head()
# Out:
#    구 명              주소        lat         lng
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762
# 3  강북구  대한민국 서울특별시 강북구  37.639610  127.025657
# 4  강서구  대한민국 서울특별시 강서구  37.550979  126.849538
# 5  관악구  대한민국 서울특별시 관악구  37.478406  126.951613

# %%
import json

# %%
geo_path = './서울시 지도.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

# %%
df_gu['lat'][1], df_gu['lng'][1]
# Out:
# (37.5172363, 127.0473248)

# %% [markdown]
# ## 2017년도 시각화

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map17 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=crime17, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('자치구', '범죄_발생_합계'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Paired', # 시각화에 쓰일 색상 (Paired)
    legend_name='서울시 5대 범죄 발생현황(2017)', # 범주 이름

).add_to(map17)

# 맵 map을 출력합니다.
map17
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 2018년도 시각화

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map18 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=crime18, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('자치구', '범죄_발생_합계'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Paired', # 시각화에 쓰일 색상
    legend_name='서울시 5대 범죄 발생현황(2018)', # 범주 이름

).add_to(map18)

# 맵 map을 출력합니다.
map18
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
## 2019년도 시각화

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
map19 = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# Choropleth 레이어를 만들고, 맵에 추가합니다.
folium.Choropleth(
    geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
    data=crime19, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
    columns=('자치구', '범죄_발생_합계'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
    key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
    fill_color='Paired', # 시각화에 쓰일 색상
    legend_name='서울시 5대 범죄 발생현황(2019)', # 범주 이름

).add_to(map19)

# 맵 map을 출력합니다.
map19
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 먼저 인구를 구 단위로 묶습니다.
# df_adm = df.groupby(['구'])['인구'].sum().to_frame().reset_index() -> 구 단위로 데이터를 매핑 (참고)

# %%
# 'BuGn': 'Sequential',
# 'BuPu': 'Sequential',
# 'GnBu': 'Sequential',
# 'OrRd': 'Sequential',
# 'PuBu': 'Sequential',
# 'PuBuGn': 'Sequential',
# 'PuRd': 'Sequential',
# 'RdPu': 'Sequential',
# 'YlGn': 'Sequential',
# 'YlGnBu': 'Sequential',
# 'YlOrBr': 'Sequential',
# 'YlOrRd': 'Sequential',
# 'BrBg': 'Diverging',
# 'PiYG': 'Diverging',
# 'PRGn': 'Diverging',
# 'PuOr': 'Diverging',
# 'RdBu': 'Diverging',
# 'RdGy': 'Diverging',
# 'RdYlBu': 'Diverging',
# 'RdYlGn': 'Diverging',
# 'Spectral': 'Diverging',
# 'Accent': 'Qualitative',
# 'Dark2': 'Qualitative',
# 'Paired': 'Qualitative', -> 한눈에 보기 좋다!
# 'Pastel1': 'Qualitative',
# 'Pastel2': 'Qualitative',
# 'Set1': 'Qualitative',
# 'Set2': 'Qualitative',
# 'Set3': 'Qualitative'

# %%
df_gu.head()
# Out:
#    구 명              주소        lat         lng
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762
# 3  강북구  대한민국 서울특별시 강북구  37.639610  127.025657
# 4  강서구  대한민국 서울특별시 강서구  37.550979  126.849538
# 5  관악구  대한민국 서울특별시 관악구  37.478406  126.951613

# %%
gu_lat
gu_lng
# Out:
# [37.5172363,
#  37.5301251,
#  37.6396099,
#  37.5509786,
#  37.4784063,
#  37.5384843,
#  37.4954031,
#  37.4518527,
#  37.6541917,
#  37.6687738,
#  37.57436819999999,
#  37.512402,
#  37.5637561,
#  37.5791158,
#  37.4837121,
#  37.5633415,
#  37.589116,
#  37.5145437,
#  37.5168721,
#  37.5263715,
#  37.5384272,
#  37.6026957,
#  37.5729503,
#  37.5640907,
#  37.6065602]
# [127.0473248,
#  127.123762,
#  127.0256575,
#  126.8495382,
#  126.9516133,
#  127.0822938,
#  126.887369,
#  126.9020358,
#  127.056793,
#  127.0470706,
#  127.0400189,
#  126.9392525,
#  126.9084211,
#  126.9367789,
#  127.0324112,
#  127.0371025,
#  127.0182146,
#  127.1065971,
#  126.8663985,
#  126.8962283,
#  126.9654442,
#  126.9291119,
#  126.9793579,
#  126.9979403,
#  127.0926519]

# %%
# 딕셔너리로 만들어서
data = {
    "위도": gu_lat, # 위도
    "경도": gu_lng, # 경도
}

# %%
columns = ['위도', '경도']
index = gu_name

# %%
# 데이터프레임을 만든다
df = pd.DataFrame(data, index=index, columns=columns)
df.head()
# Out:
#             위도          경도
# 강남구  37.517236  127.047325
# 강동구  37.530125  127.123762
# 강북구  37.639610  127.025657
# 강서구  37.550979  126.849538
# 관악구  37.478406  126.951613

# %%
list(df.iloc[0]) # 추출할 때는 for문
# Out:
# [37.5172363, 127.0473248]

# %% [markdown]
# ### 다른 방법으로 시도

# %%
# # 서울시 중심부의 위도, 경도 입니다.
# center = [37.541, 126.986]

# # 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵을 만듭니다.
# map = folium.Map(location=center,tiles='cartodbpositron',  zoom_start=11)

# # Choropleth 레이어를 만들고, 맵에 추가합니다.
# folium.Choropleth(
#     geo_data=geo_data, # 지도 데이터 파일 경로 (.geojson, geopandas.DataFrame)
#     data=crime, # 시각화 하고자 하는 데이터파일 (pandas.DataFrame)
#     columns=('자치구', '합계_발생'), # (지도 데이터와 매핑할 값, 시각화 하고자하는 변수)
#     key_on='feature.properties.name', #  feature.데이터 파일과 매핑할 값
#     fill_color='Paired', # 시각화에 쓰일 색상
#     legend_name='서울시 5대 범죄 발생현황(2017)', # 범주 이름

# ).add_to(map)

# # 맵 map을 출력합니다.
# map

# %%
df_gu.head()
# Out:
#    구 명              주소        lat         lng
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762
# 3  강북구  대한민국 서울특별시 강북구  37.639610  127.025657
# 4  강서구  대한민국 서울특별시 강서구  37.550979  126.849538
# 5  관악구  대한민국 서울특별시 관악구  37.478406  126.951613

# %%
df_crime_17 = df_gu.copy()
df_crime_18 = df_gu.copy()
df_crime_19 = df_gu.copy()

# %%
list(crime17['범죄_발생_합계'])
list(crime18['범죄_발생_합계'])
list(crime19['범죄_발생_합계'])
# Out:
# [7720,
#  4261,
#  3393,
#  5135,
#  5525,
#  4646,
#  4895,
#  3265,
#  4209,
#  1999,
#  3975,
#  3330,
#  5278,
#  3113,
#  4708,
#  2767,
#  3434,
#  5576,
#  3882,
#  5969,
#  4060,
#  3883,
#  4057,
#  4184,
#  4571]
# [7513,
#  3919,
#  3437,
#  4629,
#  5026,
#  3915,
#  4810,
#  3293,
#  4007,
#  2249,
#  3680,
#  3100,
#  5172,
#  2802,
#  4726,
#  2457,
#  3042,
#  5807,
#  3515,
#  5840,
#  3411,
#  3590,
#  3690,
#  4030,
#  4288]
# [7304,
#  4014,
#  3838,
#  4924,
#  5328,
#  4011,
#  4707,
#  3105,
#  4153,
#  2110,
#  3692,
#  3400,
#  4842,
#  2943,
#  5542,
#  2512,
#  2877,
#  5698,
#  3214,
#  5820,
#  3313,
#  3880,
#  3846,
#  4327,
#  4268]

# %%
df_crime_17['17년_5대범죄_건수'] = list(crime17['범죄_발생_합계'])
df_crime_18['18년_5대범죄_건수'] = list(crime18['범죄_발생_합계'])
df_crime_19['19년_5대범죄_건수'] = list(crime19['범죄_발생_합계'])

# %%
df_crime_17.head(2)
df_crime_18.head(2)
df_crime_19.head(2)
# Out:
#    구 명              주소        lat         lng  17년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7720
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         4261
#    구 명              주소        lat         lng  18년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7513
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         3919
#    구 명              주소        lat         lng  19년_5대범죄_건수
# 1  강남구  대한민국 서울특별시 강남구  37.517236  127.047325         7304
# 2  강동구  대한민국 서울특별시 강동구  37.530125  127.123762         4014

# %%
df_crime_17.sort_values(by="17년_5대범죄_건수", ascending=True, inplace=True)
df_crime_17.reset_index(drop=True,inplace=True)

df_crime_18.sort_values(by="18년_5대범죄_건수", ascending=True, inplace=True)
df_crime_18.reset_index(drop=True,inplace=True)

df_crime_19.sort_values(by="19년_5대범죄_건수", ascending=True, inplace=True)
df_crime_19.reset_index(drop=True,inplace=True)

# %%
df_crime_17.head(2)
df_crime_18.head(2)
df_crime_19.head(2)
# Out:
#    구 명              주소        lat         lng  17년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         1999
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2767
#    구 명              주소        lat         lng  18년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2249
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2457
#    구 명              주소        lat         lng  19년_5대범죄_건수
# 0  도봉구  대한민국 서울특별시 도봉구  37.668774  127.047071         2110
# 1  성동구  대한민국 서울특별시 성동구  37.563341  127.037103         2512

# %%
# 2017년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_17['lat'][0],df_crime_17['lng'][0]],popup="1999건의 5대 범죄 발생", tooltip=df_crime_17['구 명'][0]).add_to(map17)
folium.Marker([df_crime_17['lat'][1],df_crime_17['lng'][1]],popup="2767건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][1]).add_to(map17)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_17['lat'][23],df_crime_17['lng'][23]],popup="5969건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][23]).add_to(map17)
folium.Marker([df_crime_17['lat'][24],df_crime_17['lng'][24]],popup="7720건의 5대 범죄 발생",tooltip=df_crime_17['구 명'][24]).add_to(map17)

# %%
# 2018년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_18['lat'][0],df_crime_18['lng'][0]],popup="2249건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][0]).add_to(map18)
folium.Marker([df_crime_18['lat'][1],df_crime_18['lng'][1]],popup="2457건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][1]).add_to(map18)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_18['lat'][23],df_crime_18['lng'][23]],popup="5840건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][23]).add_to(map18)
folium.Marker([df_crime_18['lat'][24],df_crime_18['lng'][24]],popup="7513건의 5대 범죄 발생",tooltip=df_crime_18['구 명'][24]).add_to(map18)

# %%
# 2019년
# 범죄건수가 낮은 구 두개
folium.Marker([df_crime_19['lat'][0],df_crime_19['lng'][0]],popup="2110건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][0]).add_to(map19)
folium.Marker([df_crime_19['lat'][1],df_crime_19['lng'][1]],popup="2512건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][1]).add_to(map19)

# 범죄건수가 높은 구 두개
folium.Marker([df_crime_19['lat'][23],df_crime_19['lng'][23]],popup="5820건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][23]).add_to(map19)
folium.Marker([df_crime_19['lat'][24],df_crime_19['lng'][24]],popup="7304건의 5대 범죄 발생",tooltip=df_crime_19['구 명'][24]).add_to(map19)

# %%
df_crime_17.tail(2)
df_crime_18.tail(2)
df_crime_19.tail(2)
# Out:
#      구 명               주소        lat         lng  17년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5969
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7720
#      구 명               주소        lat         lng  18년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5840
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7513
#      구 명               주소        lat         lng  19년_5대범죄_건수
# 23  영등포구  대한민국 서울특별시 영등포구  37.526372  126.896228         5820
# 24   강남구   대한민국 서울특별시 강남구  37.517236  127.047325         7304

# %%
# for n in df_gu_17_inc :
#     folium.Marker([df_gu['lat'][n],df_gu['lng'][n]],
#                   popup=df_gu['구 명'][n]).add_to(map17)
#     
    
# for n in df_gu.index :
#     folium.Marker([df_gu['lat'][n],df_gu['lng'][n]],
#                   popup=df_gu['구 명'][n]).add_to(map18)
    
# for n in df_gu.index :
#     folium.Marker([df_gu['lat'][n],df_gu['lng'][n]],
#                   popup=df_gu['구 명'][n]).add_to(map19)

# %%
map17
map18
map19
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 만들어 놓은 MAP 저장 HTML 파일로 저장!!

# %%
map17.save('C:\DataScience\프로젝트1(8_24)/map_crime_17.html')
map18.save('C:\DataScience\프로젝트1(8_24)/map_crime_18.html')
map19.save('C:\DataScience\프로젝트1(8_24)/map_crime_19.html')
