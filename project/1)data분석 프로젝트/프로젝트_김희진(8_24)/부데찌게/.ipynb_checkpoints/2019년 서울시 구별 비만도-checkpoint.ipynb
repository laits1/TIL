# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## read_csv 하는데 필요한 파일 목록
#   - ./data/비만도.txt

# %% [markdown]
#  2919년 서울시 구별 비만도
#     데이터 출처 :https://data.seoul.go.kr/dataList/23/A/2/datasetView.do

# %%
obesity = pd.read_csv('./data/2019비만도.txt',delimiter = '\t')
obesity.head(10)
# Out:
#      기간   자치구  비만(BMI≥25) 저체중(BMI<18.5) 정상(18.5≤BMI＜25) 체질량지수(BMI)(평균)
# 0  2019   서울시        31.8             -               -              -
# 1  2019   종로구        34.2           5.3            60.5           23.8
# 2  2019    중구        29.1           5.3            65.5           23.4
# 3  2019   용산구        26.5           3.8            69.7           23.5
# 4  2019   성동구        32.4           6.7            60.8           23.6
# 5  2019   광진구        28.9           6.5            64.6           23.4
# 6  2019  동대문구        36.1           2.7            61.2             24
# 7  2019   중랑구        36.2           3.7              60           24.1
# 8  2019   성북구        32.6           4.8            62.6           23.7
# 9  2019   강북구        30.3           5.7              64           23.6

# %%
obesity_seoul=obesity.iloc[1:,1:3]

# %%
obesity_seoul.sort_values(by="자치구", ascending=True, inplace=True)
obesity_seoul.reset_index(drop=True,inplace=True)

# %%
obesity_seoul.to_csv("./fin_data/2020년_서울시_비만도",header=True,index=False)

# %%
obesity_seoul
# Out:
#      자치구  비만(BMI≥25)
# 0    강남구        28.6
# 1    강동구        31.3
# 2    강북구        30.3
# 3    강서구        30.7
# 4    관악구        35.1
# 5    광진구        28.9
# 6    구로구        33.0
# 7    금천구        35.2
# 8    노원구        34.7
# 9    도봉구        36.6
# 10  동대문구        36.1
# 11   동작구        30.0
# 12   마포구        29.0
# 13  서대문구        31.6
# 14   서초구        25.1
# 15   성동구        32.4
# 16   성북구        32.6
# 17   송파구        27.9
# 18   양천구        34.2
# 19  영등포구        34.3
# 20   용산구        26.5
# 21   은평구        33.0
# 22   종로구        34.2
# 23    중구        29.1
# 24   중랑구        36.2
