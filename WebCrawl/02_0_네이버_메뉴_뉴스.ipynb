# %% [markdown]
# ### 네이버 메뉴 추출
# - 방법 : 크롬 개발자 도구 이용
# - 전체 소스 코드에서 위치 찾아(화면 해당 컨텐츠에서 단축메뉴 검사 이용)
# - 태그 확인하고 태그 추출
# - 동일 태그가 여러개인 경우 class 속성 이용해서 추출

# %%
from urllib.request import urlopen
import bs4

# %%
url = "https://www.naver.com"

#url에 접속
html = urlopen(url)
type(html)
# html.read() 생략하고 response 객체를 바로 파서기에 적용해도 됨
html

# %%
# 파서에 등록해 obj로 변환
bs_obj = bs4.BeautifulSoup(html, "html.parser")

# %%
# 첫번째 메뉴 블럭 파싱 (ul class : list_nav type_fix)
ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# print(ul)

## 위에서 추출한 ul 객체는 bs4.element.Tag 임
### 집합적 자료의 속성을 갖고 있기 때문에 반복 요소로 사용 가능

for li in ul :
    print(li)
# Out:
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
#
#
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
#
#
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
#
#
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
#
#
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
#
#
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
#
#
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
#
#
# <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>

# %%
# findAll 함수 사용해서 ul 안의 모든 li 추출
lis = ul.findAll("li")
print(lis)
# Out:
# [<li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>, <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>, <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>, <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>, <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>, <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>, <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>, <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>]

# %%
# 각 li 태그 내부의 a 태그 접근 후 text 출력 
for li in lis :
    a_tag = li.find("a")
    print(a_tag.text, end=",")
# Out:
# 메일,카페,블로그,지식iN,쇼핑,쇼핑LIVE,Pay,TV,

# %%
ul1 = bs_obj.find("ul", {"class" : "list_nav NM_FAVORITE_LIST"})
# ul1
lis = ul1.findAll("li")
for li in lis :
    a_tag = li.find("a")
    print(a_tag.text, end=",")
# Out:
# 사전,뉴스,증권,부동산,지도,VIBE,책,웹툰,

# %% [markdown]
# ### 네이버 뉴스 크롤링

# %%
url = "https://news.naver.com"
# html = urlopen(url)

# %% [markdown]
# - 위 코드 처럼 자동화 봇으로 보고 연결을 끊는 경우에는 데이터 전송시 추가되는 header를 구성해 bot이 아님을 증명해야 함
#     - header에는 브라우저를 통한 접속이라는 정보를 포함시킨다
#     - 크롬 개발자도구 => NetWork => news.naver.com 선택한 후 오른쪽에 새로나타나는 창에서 heaer 선택
#     - requests headers 목록에서 user-agent 확인
# - https://developers.whatismybrowser.com/useragents/explore/software_name/chrome/

# %%
# header 전송은 보통 requests 객체를 사용함
import requests

headers = {"User-Agent" : 
          "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}

url = "https://news.naver.com"
res = requests.get(url, headers=headers)
html = res.text
html[:100]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\t\n\t\t\n\t\n\t\n\n\n<!DOCTYPE HTML>\n<html lang="ko">\n<head>\n<meta charset="euc-kr">\n<meta http-equ'

# %%
# bs4 객체 변환
bs_obj = bs4.BeautifulSoup(html, "html.parser")
bs_obj
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <title>네이버 뉴스</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='home';
# var _MAIN_NEWS_SECTION_ID='100';
# var ccsrv='cc.naver.com';
# var g_ssc='news.home';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Fri Aug 06 20:22:54 KST 2021";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.service.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body class="chrome">
# <div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(ST A.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com">뉴스스탠드</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.tokyo)" href="https://m.sports.naver.com/tokyo2020/index"><img alt="TOKYO 2020" height="14" src="https://ssl.pstatic.net/static.news/image/news/2021/06/21/tokyo2020.png" style="margin: 3px 0 0 0;" width="87"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li class="lnb_menu_home on"><a class="nclicks(LNB.home)" href="/main/home.naver"><span class="tx">뉴스홈</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li><a class="nclicks(LNB.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.naver?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="home_timelate">
# <div class="ht_head">
# <ul class="ht_tabmnu">
# <li id="ht_tabmnu_0">
# <a href="#" title="신문 헤드라인">신문 헤드라인<span class="ht_ico"></span></a>
# </li>
# <li id="ht_tabmnu_1">
# <a href="#" title="저녁 방송 뉴스">저녁 방송 뉴스<span class="ht_ico"></span></a>
# </li>
# </ul>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.naver" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://media.naver.com/channel/settings.nhn  " target="_blank" title="언론사 설정">언론사 설정
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# </ul>
# </div>
# <div class="ht_comp ht_paperheadline" id="paperHeadlineRolling" style="display: none;">
# <h3 class="blind">신문 헤드라인</h3>
# <ul class="ht_ph_lst" style="display: none;">
# <!-- 헤드라인 데이터 동적삽입 <li> -->
# </ul>
# <div class="ht_nodata_all" style="display: none;">발행된 종이신문이 없거나 신문게재 정보가 입력되지 않았습니다.</div>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev)" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <div class="ht_comp ht_eveningnews" id="eveningNewsRolling" style="display: none;">
# <h3 class="blind">저녁 방송 뉴스</h3>
# <ul class="ht_ph_lst">
# <!-- 저녁방송뉴스 동적삽입 <li> -->
# </ul>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev);" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <script type="text/javascript">
# _oTopComponentData = {
# "open" : "Y",
# "target" : "liveTvList",
# "headlineList" : [
# {
# "officeId" : "030",
# "officeName" : "전자신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/030/2017/01/05/logo_030_1_20170105110505.gif' width='206' height='30' alt='전자신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/030/2021/08/05/2961649.jpg?type=nf80_54",
# "title" : "\'라방\' 중소 가전업계 신유통채널로 부상…매출·수익성↑",
# "summary" : "\'라이브 커머스 방송\'(라방)이 중소 가전업계의 새로운 유통 채널로 떠올랐다. 주력 소비 계층으로 부상한 MZ세대(밀레니얼+Z세대)가 선호하는 비대면 소비 트렌드와 맞아떨어지면서 라방을 통한 판매가 늘고 있다. 홈쇼",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "032",
# "officeName" : "경향신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/032/2017/01/05/logo_032_1_20170105110505.gif' width='206' height='30' alt='경향신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/032/2021/08/06/3090235.jpg?type=nf80_54",
# "title" : "상장사 성별 노동자 대비 임원 ‘남 2.6%, 여 0.4%’ [유리천장 박살 프로젝트]",
# "summary" : "[경향신문] 1년 후 한국 상장기업의 이사회 풍경이 바뀐다. ‘자본시장법 임팩트’다. 내년 8월부터 자산총액 2조원 이상 상장사는 이사회의 등기이사를 특정 성으로만 선임할 수 없도록 하는 개정 ‘자본시장과 금융투자업",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "011",
# "officeName" : "서울경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/011/2017/01/05/logo_011_1_20170105110505.gif' width='206' height='30' alt='서울경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/011/2021/08/05/3946576.jpg?type=nf80_54",
# "title" : "탈원전 폭주···태양광·풍력에 전력 71% 맡긴다",
# "summary" : "[서울경제] 정부가 오는 2050년까지 전력 부문에서 재생에너지 비중을 70.8%까지 늘린다. 이를 위해 탈(脫)원전·탈석탄에 이어 액화천연가스(LNG)까지 발전 시장에서 사실상 퇴출된다. 태양광·풍력 등 재생에너지",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "353",
# "officeName" : "중앙SUNDAY",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/03/17/logo_353_1_20180317103917.png' width='206' height='30' alt='중앙SUNDAY' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "277",
# "officeName" : "아시아경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/277/2017/01/05/logo_277_1_20170105110505.gif' width='206' height='30' alt='아시아경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/277/2021/08/06/4949902.jpg?type=nf80_54",
# "title" : "[금요스토리] 원룸값도 들썩…반지하로 몰려나는 청춘",
# "summary" : "#반지하 인테리어, #반지하 후기. 1억1000만원짜리 원룸 빌라에 전세로 살고 있는 A씨(33)가 요즘 자주 쓰는 검색어다. 전세계약 만료를 앞두고 집주인은 얼마전 부동산중개인을 통해 보증금 1500만원 인상을 요",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "014",
# "officeName" : "파이낸셜뉴스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/014/2017/01/05/logo_014_1_20170105110505.gif' width='206' height='30' alt='파이낸셜뉴스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/014/2021/08/05/4687714.jpg?type=nf80_54",
# "title" : "안먹힌 정부 엄포… 서울 집값 20개월래 최대 상승",
# "summary" : "정부의 잇단 집값 고점 경고와 무르익는 금리인상 분위기에도 서울 아파트 가격이 1년8개월여 만에 최고 상승폭을 찍었다. 경기도 아파트 값도 역대 최대폭으로 오르면서 수도권 아파트 값은 9년 만에 최대 상승률을 기록했",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "015",
# "officeName" : "한국경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/015/2017/01/05/logo_015_1_20170105110505.gif' width='206' height='30' alt='한국경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/015/2021/08/05/4588182.jpg?type=nf80_54",
# "title" : "밥값도 선물값도 전셋값도…정부가 多 결정해주는 나라",
# "summary" : "정부가 부정청탁 및 금품 등 수수의 금지에 관한 법률, 일명 ‘김영란법’을 민간에 적용하는 방안을 추진하면서 개인의 자유와 국가의 역할에 대한 논란이 불거지고 있다. 민간 영역의 불합리한 관행을 해소하기 위해 정부가",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "016",
# "officeName" : "헤럴드경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/016/2017/01/05/logo_016_1_20170105110505.gif' width='206' height='30' alt='헤럴드경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/016/2021/08/06/1871583.jpg?type=nf80_54",
# "title" : "최고치 솟구친 수도권 집값...“더 오른다”",
# "summary" : "홍남기 경제부총리가 “집값이 최고 수준에 근접했다”며 “추격 매수에 신중해야 한다”고 경고한 직후 조사한 수도권 아파트값이 역대 최고 상승률을 기록했다. 주택 매수심리, 수요와 공급 동향 등 각종 부동산 지표는 앞으",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "018",
# "officeName" : "이데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/018/2017/01/05/logo_018_1_20170105110505.gif' width='206' height='30' alt='이데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/018/2021/08/06/5004330.jpg?type=nf80_54",
# "title" : "[스태그플레이션 논쟁]심상찮은 물가…`S`의 불안 수면 위",
# "summary" : "[이데일리 최정희 기자 김정남 뉴욕특파원] “경기 회복속도가 둔화해도 회복세는 유지하고 있습니다. 앞으로 경기가 꺾인다면 물가 상승세도 함께 꺾일 겁니다.”(김소영 서울대 경제학부 교수) “대면서비스 회복이 덜 돼 ",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "081",
# "officeName" : "서울신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/081/2017/01/05/logo_081_1_20170105110505.gif' width='206' height='30' alt='서울신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/081/2021/08/06/3207082.jpg?type=nf80_54",
# "title" : "한미훈련 커지는 갈등 결단 못 내리는 청와대",
# "summary" : "권한 없는 통일부·국정원 가세로 일 커져 靑, 의견 취합한 뒤 이번 주말쯤 입장 정리 전문가 “연기 안 돼… 유연한 조정 바람직” 정치권과 정부 일각에서 한미 연합훈련 연기론에 불을 지피면서 훈련을 하기도 전에 ‘아",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "082",
# "officeName" : "부산일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/082/2021/01/15/logo_082_1_20210115134425.png' width='206' height='30' alt='부산일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/082/2021/08/05/1111708.jpg?type=nf80_54",
# "title" : "유엔 추진 ‘현대판 노아의 방주’ 부산에 띄운다",
# "summary" : "유엔 해비타트와 부산시가 구상하는 해상도시 조감도. 부산시 제공 기후위기에 선제 대응할 수 있는 세계 최초의 해상도시 건설이 부산에서 추진된다. 에너지와 물, 식량을 자급자족할 수 있어 현대판 ‘노아의 방주’라 불리",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "020",
# "officeName" : "동아일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/020/2017/01/05/logo_020_1_20170105110505.gif' width='206' height='30' alt='동아일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/020/2021/08/06/3374511.jpg?type=nf80_54",
# "title" : "“옆집과 1억差”… 규제가 낳은 ‘다중 매매가’",
# "summary" : "직장인 허모 씨(35)는 최근 서울 노원구의 전용 45m²짜리 아파트를 사려고 중개업소에 갔다가 매물 가격이 천차만별인 걸 보고 당황했다. 같은 단지, 동일 면적, 비슷한 층인데도 싼 매물은 7억2000만 원, 비싼",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "087",
# "officeName" : "강원일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/087/2021/01/15/logo_087_1_20210115134053.png' width='206' height='30' alt='강원일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/087/2021/08/06/855081.jpg?type=nf80_54",
# "title" : "한달째 두자릿수 감염…절반이 델타변이",
# "summary" : "5일 원주지역 코로나19 누적 확진자가 1,000명을 넘어섰다. 강원도 내 18개 시·군 중 감염자 수가 1,000명을 넘은 것은 원주가 처음이다. 최근 도내 전체 감염자 수는 한달 전보다는 크게 줄었지만, 올 7월",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "021",
# "officeName" : "문화일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/021/2017/01/05/logo_021_1_20170105110505.gif' width='206' height='30' alt='문화일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/021/2021/08/06/2481001.jpg?type=nf80_54",
# "title" : "이미 반쪽 韓美훈련, 그마저도 축소 가닥",
# "summary" : "16일부터 시뮬레이션 훈련 예년보다 참가자 더 줄일 듯 靑, 북한 눈치 살피며 뒷짐만 전문가 “나라 지키는 훈련을 대북협상용으로 만든 게 패착” 韓美동맹·연합태세 약화 우려 우리 군이 8월 중순으로 예정된 한·미 연",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "088",
# "officeName" : "매일신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/088/2021/01/15/logo_088_1_20210115134127.png' width='206' height='30' alt='매일신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/088/2021/08/05/715497.jpg?type=nf80_54",
# "title" : "\'태권도장發 집단감염\' 대구 시지 학원·교습소 483곳 \'휴원 권고\'",
# "summary" : "5일 오후 1시쯤 대구 수성구 매호동의 한 영어보습학원은 전체 강의실 6곳 중 1곳을 제외하고 텅 비어 있었다. 지난 3일 인근 동네인 노변동의 한 태권도장에서 코로나19 확진자가 무더기로 나온 이후 이 학원은 재빨",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "022",
# "officeName" : "세계일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/022/2017/01/05/logo_022_1_20170105110505.gif' width='206' height='30' alt='세계일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/022/2021/08/06/3607553.jpg?type=nf80_54",
# "title" : "2050년 ‘넷제로’ 목표 실효성 논란",
# "summary" : "정부, 탄소중립 3가지 초안 공개 석탄·LNG발전 전면중단 또는 최소화 온실가스 배출 최소 96.3% 감축 추진 원전은 대안 검토 안해… 산업계 반발 내달 의견수렴후 10월 말 최종 확정 문재인 대통령이 5일 청와대",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "044",
# "officeName" : "코리아헤럴드",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/044/2017/01/05/logo_044_1_20170105110505.gif' width='206' height='30' alt='코리아헤럴드' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/044/2021/08/05/229794.jpg?type=nf80_54",
# "title" : "[News Focus] Samsung’s edge in memory chips threatened?",
# "summary" : "Amid the global chip race, news that Micron and SK hynix have developed the most advanced memory chips and are ready for",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "023",
# "officeName" : "조선일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/023/2017/01/05/logo_023_1_20170105110505.gif' width='206' height='30' alt='조선일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/023/2021/08/06/3631925.jpg?type=nf80_54",
# "title" : "정부 “원전 7%, 태양광·풍력은 최대 71%”… 원자력학회 “국민부담 年 41조~96조 증가”",
# "summary" : "지난해 기준 29% 수준인 원전 발전 비율을 2050년까지 6~7%로 축소하는 대신 태양광·풍력 등 재생에너지는 57~71%로 늘리는 내용의 ‘2050 탄소 중립 시나리오 초안’을 정부가 5일 발표했다. 일반 시민 ",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "640",
# "officeName" : "코리아중앙데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/640/2021/05/17/logo_640_1_20210517192250.png' width='206' height='30' alt='코리아중앙데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/640/2021/08/05/14888.jpg?type=nf80_54",
# "title" : "DP reps want drill with U.S. postponed",
# "summary" : "A group of 74 liberal lawmakers issued a joint statement Thursday calling for South Korea and the United States to postp",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "025",
# "officeName" : "중앙일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/025/2018/08/03/logo_025_1_20180803103703.jpg' width='206' height='30' alt='중앙일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/025/2021/08/06/3124661.jpg?type=nf80_54",
# "title" : "자영업 녹다운…전체 취업자 중 20.2%, 39년 만에 최저",
# "summary" : "서울 종로의 한 낙지볶음 음식점은 최근 무료로 제공하던 계란말이 서비스를 중단했다. 계란 가격이 전년보다 57%나 오를(통계청 7월 소비자물가 동향) 정도로 비싸져서다. 이 음식점에는 “계란 구입이 어려워 계란말이를",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "005",
# "officeName" : "국민일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/005/2017/01/05/logo_005_1_20170105110505.gif' width='206' height='30' alt='국민일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/005/2021/08/06/1462547.jpg?type=nf80_54",
# "title" : "전작권 환수하자면서 훈련 미루자는 의원들",
# "summary" : "더불어민주당을 비롯한 범여권 의원 74명이 5일 한·미 연합훈련 연기를 공개적으로 촉구했다. 한·미 양국이 이미 훈련 준비에 들어갔고 민주당 지도부 역시 훈련 진행 쪽으로 입장을 정리했지만, 아랑곳하지 않고 의원 일",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "028",
# "officeName" : "한겨레",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/028/2017/01/05/logo_028_1_20170105110505.gif' width='206' height='30' alt='한겨레' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/028/2021/08/05/2555623.jpg?type=nf80_54",
# "title" : "가야 할 길 ‘탄소중립’ 3개 시나리오…뼈 깎는 전환 안보인다",
# "summary" : "문재인 대통령이 선언한 2050년 탄소중립(탄소순배출량 0: 넷제로)을 달성하기 위해 조직된 ‘2050 탄소중립위원회’(공동위원장 김부겸 국무총리, 윤순진 민간위원장)가 탄소중립 시나리오 초안을 공개했다. 시나리오 ",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "029",
# "officeName" : "디지털타임스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_1_20180718140618.jpg' width='206' height='30' alt='디지털타임스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/029/2021/08/05/2690888.jpg?type=nf80_54",
# "title" : "임기말 文정부 원전없는 탄소중립 강행",
# "summary" : "원전 현재보다 4분의1로 감축 신재생에너지 70%로 확대 골자 1案엔 석탄발전 유지 \"기형적\" 선진국의 원전 중시계획과 반대 임기 말 문재인 정부가 공약인 \'탈원전\' 기조를 유지한 채 오는 2050년까지 탄소배출 \'",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "469",
# "officeName" : "한국일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/01/26/logo_469_1_20180126174326.gif' width='206' height='30' alt='한국일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/469/2021/08/06/622103.jpg?type=nf80_54",
# "title" : "화려한 2050 탄소중립 시나리오, 디테일이 없다",
# "summary" : "대한민국 도로 위를 달리는 자동차 100대 중 80대는 전기차고 17대는 수소차다. 가솔린·디젤 같은 내연차는 겨우 3대로 ‘희귀템\'이 됐다. 자동차 배터리를 충전할 전기의 70%는 태양열, 풍력 같은 신재생에너지로",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "008",
# "officeName" : "머니투데이",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/008/2017/01/05/logo_008_1_20170105110505.gif' width='206' height='30' alt='머니투데이' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/008/2021/08/05/4627125.jpg?type=nf80_54",
# "title" : "\"30년후 화력 없애고 원전도 줄이고\"…전기료 폭등은 국민 몫",
# "summary" : "[2050 탄소중립 시나리오 초안 공개] 정부가 \'2050년 탄소중립\' 달성을 위한 3가지 시나리오를 공개했다. 발전 분야에선 화력을 없애거나 크게 줄이고 재생에너지 비중을 최대 70%대로 늘리는 게 골자다. 현재 ",
# "publishDate" : "20210806"
# },
# {
# "officeId" : "009",
# "officeName" : "매일경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/009/2017/01/05/logo_009_1_20170105110505.gif' width='206' height='30' alt='매일경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/009/2021/08/05/4834530.jpg?type=nf80_54",
# "title" : "\"무조건 80% 줄여라\" 정부 선전포고에 기업 발등에 불 떨어졌다",
# "summary" : "정부, 온실가스 배출량 따라 \'2050 탄소중립 3가지案\' 공개 기업은 무조건 80% 감축 제시…비용부담·고용쇼크 불보듯 ◆ 2050 탄소중립 시나리오 ◆ 30년 뒤 탄소중립에 도달하기 위한 정부 시나리오가 공개됐다",
# "publishDate" : "20210806"
# }
# ]
# ,
# "liveTvList" : [
# {
# "officeId" : "422",
# "articleId" : "",
# "sectionId" : "74f",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2018/01/10/logo_422_1_20180110175610.png' width='206' height='30' alt='연합뉴스TV 뉴스리뷰' title='' class='' >",
# "officeName" : "연합뉴스TV",
# "title" : "",
# "newsKey" : "74f",
# "naverTvChannelId" : "yonhapnewstv",
# "thumbnail" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/09/02/logo_422_48_20190902185002.jpg' width='255' height='134' alt='' title='' class='' >",
# "summary" : "",
# "onairStatus" : "NOT-YET",
# "nextLiveTime" : "20:43"
# },
# {
# "officeId" : "449",
# "articleId" : "0000212971",
# "sectionId" : "74b",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/449/2018/01/10/logo_449_1_20180110175910.png' width='206' height='30' alt='채널A 뉴스A' title='' class='' >",
# "officeName" : "채널A",
# "title" : "“짧고 굵게 끝낸다더니”…4단계 연장에 자영업 절망",
# "newsKey" : "74b",
# "naverTvChannelId" : "channelanews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/449/2021/08/06/212971.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "코로나 확산이 꺾일 줄을 모르며, 결국 현행 거리두기가 2주 더 연장됩니다. 수도권의 4단계 거리두기는 무려 6주나 이어지게 되는 것이죠. 수도권에서는 오후 6시 이후 3인 이상 모임 제한이 유지되고, 3단계가 계속",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "437",
# "articleId" : "",
# "sectionId" : "742",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2018/01/10/logo_437_1_20180110175610.png' width='206' height='30' alt='JTBC 뉴스룸' title='' class='' >",
# "officeName" : "JTBC",
# "title" : "",
# "newsKey" : "742",
# "naverTvChannelId" : "jtbcnews",
# "thumbnail" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2021/06/07/logo_437_48_20210607135342.jpg' width='255' height='134' alt='' title='' class='' >",
# "summary" : "",
# "onairStatus" : "ON-AIR",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "056",
# "articleId" : "",
# "sectionId" : "355",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/01/10/logo_056_1_20180110175610.png' width='206' height='30' alt='KBS 뉴스9' title='' class='' >",
# "officeName" : "KBS",
# "title" : "",
# "newsKey" : "355",
# "naverTvChannelId" : "kbsnews",
# "thumbnail" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/07/05/logo_056_48_20210705111736.png' width='255' height='134' alt='' title='' class='' >",
# "summary" : "",
# "onairStatus" : "NOT-YET",
# "nextLiveTime" : "21:00"
# },
# {
# "officeId" : "214",
# "articleId" : "0001140440",
# "sectionId" : "370",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/214/2018/01/10/logo_214_1_20180110175710.png' width='206' height='30' alt='MBC 뉴스데스크' title='' class='' >",
# "officeName" : "MBC",
# "title" : "꺾이지 않는 확산세…거리두기 단계 2주 연장",
# "newsKey" : "370",
# "naverTvChannelId" : "imnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/214/2021/08/06/1140440.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스데스크] ◀ 앵커 ▶ 도쿄 올림픽 소식을 전해드리기에 앞서 코로나19 속보로 시작합니다. 강도 높은 거리두기와 단합된 멈춤에도 휴가철 이동과 델타 변이의 기세에 새 확진자는 사흘 연속 1천7백 명대를 이어 갔습",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "057",
# "articleId" : "0001598591",
# "sectionId" : "74e",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/057/2020/06/12/logo_057_1_20200612153812.jpg' width='206' height='30' alt='MBN 종합뉴스' title='' class='' >",
# "officeName" : "MBN",
# "title" : "김주하 앵커가 전하는 8월 6일 종합뉴스 주요뉴스",
# "newsKey" : "74e",
# "naverTvChannelId" : "mbnnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/057/2021/08/06/1598591.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "▶ 또 거리두기 연장…접종 후 마비 산재 첫 인정 정부가 현행 거리두기를 2주 연장하고, 비수도권에서도 직계가족 5인 이상 모임을 금지하기로 했습니다. 백신을 맞은 뒤 사지마비 증상을 보인 40대 간호조무사에겐 백신",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "055",
# "articleId" : "0000912964",
# "sectionId" : "371",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/055/2018/01/10/logo_055_1_20180110175610.png' width='206' height='30' alt='SBS 8뉴스' title='' class='' >",
# "officeName" : "SBS",
# "title" : "잠시 후 브라질과 준결승…\"런던 올림픽 한 풀자!\"",
# "newsKey" : "371",
# "naverTvChannelId" : "sbsnews8",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/055/2021/08/06/912964.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "<앵커> 사상 첫 올림픽 결승 진출을 노리는 여자 배구 대표팀이 잠시 뒤 브라질과 4강전을 치릅니다. 자신의 마지막 올림픽을 더 높은 곳에서 마무리하고 싶어 하는 김연경 선수를 중심으로 우리 선수들은 새로운 역사를 ",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "448",
# "articleId" : "",
# "sectionId" : "750",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_1_20180830162730.png' width='206' height='30' alt='TV조선 뉴스9' title='' class='' >",
# "officeName" : "TV조선",
# "title" : "",
# "newsKey" : "750",
# "naverTvChannelId" : "tvchosunnews",
# "thumbnail" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2019/04/25/logo_448_48_20190425162325.jpg' width='255' height='134' alt='' title='' class='' >",
# "summary" : "",
# "onairStatus" : "NOT-YET",
# "nextLiveTime" : "20:55"
# },
# {
# "officeId" : "052",
# "articleId" : "",
# "sectionId" : "751",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2018/01/10/logo_052_1_20180110175810.png' width='206' height='30' alt='YTN 뉴스나이트' title='' class='' >",
# "officeName" : "YTN",
# "title" : "",
# "newsKey" : "751",
# "naverTvChannelId" : "ytnnews24",
# "thumbnail" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/05/28/logo_052_48_20210528224335.jpg' width='255' height='134' alt='' title='' class='' >",
# "summary" : "",
# "onairStatus" : "NOT-YET",
# "nextLiveTime" : "21:48"
# }
# ]
# };
# </script>
# </div>
# <script type="text/javascript">
# 	// page onload 시에 home timelate에서 사용하는 스크립트를 초기화 시켜준다.
# 	jindo.$Fn(function(){
# 		try {
# 			news.home.TopTimelate.Controller.init(_oTopComponentData);
# 		} catch (e) { }
# 	}).attach(window, "load");
# </script>
# <div class="main_space"></div>
# <div class="main" id="container">
# <hr/>
# <div class="main_content main_content_new" id="main_content">
# <div class="main_content_inner _content_inner">
# <div class="main_component droppable" id="today_main_news">
# <div class="com_header">
# <h4 class="tit_h4 tit_main1"><strong>헤드라인 뉴스</strong></h4>
# <p class="news_info_txt">헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# </div>
# <!-- [D] 구형: .com_list.com_list_headline, 이시각주요뉴스:.newsnow, 헤드라인뉴스:.hdline_news -->
# <div class="hdline_news">
# <div class="hdline_flick">
# <div class="hdline_flick_item" style="display:block">
# <a class="lnk_hdline_main_article nclicks('mai.image', '8800011C_000000000000000000912884', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=055&amp;aid=0000912884">
# <img alt="직계가족 모임 3단계선 4명까지…대면 예배 4단계 최대 99명까지" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/055/2021/08/06/0000912884_001_20210806141605804.jpg?type=nf300_190" width="300"/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">직계가족 모임 3단계선 4명까지…대면 예배 4단…</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '8800011C_000000000000000000912884', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108061110_00000004&amp;mode=LSD&amp;mid=shm&amp;oid=055&amp;aid=0000912884">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">64</span>
# </a>
# </div>
# <div class="hdline_flick_item" style="display:none">
# <a class="lnk_hdline_main_article nclicks('mai.image', '08138263_000000000000000005526345', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0005526345">
# <img alt="백신접종 사지마비 간호조무사 산재인정…후유증 첫 사례" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/421/2021/08/06/0005526345_001_20210806104314137.jpg?type=nf300_190" width="300"/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">백신접종 사지마비 간호조무사 산재인정…후유증…</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '08138263_000000000000000005526345', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108052240_00000001&amp;mode=LSD&amp;mid=shm&amp;oid=421&amp;aid=0005526345">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">58</span>
# </a>
# </div>
# <div class="hdline_flick_navi">
# <button class="flick_btn_prev nclicks(mai.prev)" disabled="disabled" onclick="prevRecommend(); " type="button"><span class="blind">이전기사</span></button><button class="flick_btn_next nclicks(mai.next)" onclick="nextRecommend(); " type="button"><span class="blind">다음기사</span></button>
# </div> <!--[D] 버튼 비활성: disabled 속성 추가 -->
# </div>
# <ul class="hdline_article_list">
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '88000114_000000000000000011096795', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0011096795">
#                                         “노바백스 도입 안 돼도 올해 접종 차질 없어”…렘데시비르, 변이 11종 모두 효과
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000114_000000000000000011096795', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108042340_00000009&amp;mode=LSD&amp;mid=shm&amp;oid=056&amp;aid=0011096795">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">53</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000AF_000000000000000001624085', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001624085">
#                                         '폭염 속 사투' 소방관 격려...文 "소방관 안전도 중요"
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000AF_000000000000000001624085', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108061220_00000014&amp;mode=LSD&amp;mid=shm&amp;oid=052&amp;aid=0001624085">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">31</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '88000385_000000000000000004950004', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004950004">
#                                         롯데쇼핑, 2분기 영업익 76억…"송도롯데몰 세금 일시적 반영"(종합)
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000385_000000000000000004950004', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108061550_00000002&amp;mode=LSD&amp;mid=shm&amp;oid=277&amp;aid=0004950004">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">23</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000ED_000000000000000003631987', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=023&amp;aid=0003631987">
#                                         “자영업자 목소리가 불법이면 거리에 나앉아 죽으란거냐” 자영업 비대위 대표 경찰 소환
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000ED_000000000000000003631987', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108051450_00000574&amp;mode=LSD&amp;mid=shm&amp;oid=023&amp;aid=0003631987">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">42</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '8800006F_000000000000000001462628', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=005&amp;aid=0001462628">
#                                         카카오, 또 최대 실적…여민수 공동대표 “구독 생태계 확장”
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '8800006F_000000000000000001462628', 'airsGParam', '0', 'news_global_v2.0', 'AwwWahNCR7WMly07')" href="/main/clusterArticles.naver?id=c_202108060830_00000001&amp;mode=LSD&amp;mid=shm&amp;oid=005&amp;aid=0001462628">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">63</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="btn_move">
# <!-- [D] .down_off 또는 .up_off 추가시 '<span class="blind">불가능</span>' 추가 -->
# <span class="move" title="이동">이동</span> <a class="up nclicks(mai.up)" href="#SLELq" title="위로">위로</a> <a class="down_off nclicks(mai.down)" href="#SLELq" title="아래로">아래로<span class="blind">불가능</span></a>
# </div>
# </div>
# <script type="text/javascript">
#             var recommendIdx = 0;
#             var recommendLength = $("#today_main_news .hdline_flick_item").length;
#
#             function prevRecommend() {
#                 if ( recommendIdx-1 >= 0) {
#                     recommendIdx -= 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function nextRecommend() {
#                 if ( recommendIdx+1 < recommendLength) {
#                     recommendIdx += 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function recBtnDisabled() {
#                 $("#today_main_news .flick_btn_prev").removeAttr("disabled");
#                 $("#today_main_news .flick_btn_next").removeAttr("disabled");
#
#                 if ( recommendIdx === 0 ) {
#                     $("#today_main_news .flick_btn_prev").attr("disabled", "disabled");
#                 }
#                 if ( recommendIdx === recommendLength -1 ) {
#                     $("#today_main_news .flick_btn_next").attr("disabled", "disabled");
#                 }
#             }
#         </script>
# <div class="main_component droppable" id="section_politics">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(pol.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h4>
# <span class="tit_sub">
# <a class="nclicks(pol.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">일반</a><span class="bar"></span>
# <a class="nclicks(pol.party)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당</a><span class="bar"></span>
# <a class="nclicks(pol.chung)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=437&amp;aid=0000273138">
# <img alt='[단독] "북 지령문 등 80여 건"…스텔스기 반대 활동가들 USB엔' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/437/2021/08/06/273138.jpg?type=nf220_140" width="220"/>
# <strong class="r_ico r_vod_large">동영상 기사</strong>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=437&amp;aid=0000273138">[단독] "북 지령문 등 80여 건"…스텔스기 반대 활동가들 USB엔</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000622270">
# <strong>홍준표 “朴 전 대통령 잡아 넣은 윤석열, TK서 '압도적 지지' 기가 막혀”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=449&amp;aid=0000212977">
# <strong>“지도부가 주인공 아니다”…제동 걸린 이준석표 경선</strong>
# </a>
# <strong class="r_ico r_vod_txt">동영상기사</strong>
# <span class="writing">채널A</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=449&amp;aid=0000212976">
# <strong>최재형 “박근혜 즉각 사면해야”…윤석열 ‘화법 교정’</strong>
# </a>
# <strong class="r_ico r_vod_txt">동영상기사</strong>
# <span class="writing">채널A</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003607745">
# <strong>‘北 지령받고 美스텔스기 반대’ 4명에 간첩죄 혐의 적용… 野 “文대통령 해명하라”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">세계일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273138', 'airsGParam', '0', 'news_sec_v2.0', 'lk6fxPxV1zMy81YY')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0005527649">
# <strong>'전과 공방' 진흙탕 싸움 …이재명 "李 공개할 차례" 이낙연측 "적반하장"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(soc.move)" title="이동">이동</span>
# <a class="up nclicks(soc.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(soc.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_economy">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(eco.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h4>
# <span class="tit_sub">
# <a class="nclicks(eco.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">일반</a><span class="bar"></span>
# <a class="nclicks(eco.finance)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융</a><span class="bar"></span>
# <a class="nclicks(eco.domestic)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=469&amp;aid=0000622268">
# <img alt="'노재팬'에 휘청해서? 무인양품, 최대 63% 가격 인하 나선다" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/469/2021/08/06/622268.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=469&amp;aid=0000622268">'노재팬'에 휘청해서? 무인양품, 최대 63% 가격 인하 나선다</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=469&amp;aid=0000622267">
# <strong>"2.6억 아파트, 주담대 6억까지"…금융당국 뒷짐 진 사이 대출 시장 '대혼란'</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=008&amp;aid=0004627722">
# <strong>상장 첫 날 상한가 친 카뱅…임직원 총 평가차익 '5700억'</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">머니투데이</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=449&amp;aid=0000212972">
# <strong>40~50대 위중증 환자 급증…노바백스 도입 빨간불</strong>
# </a>
# <strong class="r_ico r_vod_txt">동영상기사</strong>
# <span class="writing">채널A</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=366&amp;aid=0000752589">
# <strong>내년 외항선 LNG 수입부과금 면제…선박 주유소 ‘LNG 벙커링’ 키운다</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선비즈</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88156f75_000000000000000000622268', 'airsGParam', '0', 'news_sec_v2.0', 'Md8c2scmy1HuKDXx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=417&amp;aid=0000722770">
# <strong>[美친주] 모더나, 호실적에도 주가 빠진 이유… 백신 판매량 때문?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">머니S</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(pol.move)" title="이동">이동</span>
# <a class="up nclicks(pol.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(pol.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_society">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(soc.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h4>
# <span class="tit_sub">
# <a class="nclicks(soc.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">일반</a><span class="bar"></span>
# <a class="nclicks(soc.edu)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육</a><span class="bar"></span>
# <a class="nclicks(soc.labor)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273137', 'airsGParam', '0', 'news_sec_v2.0', 'SD52OVgW56i0QF2Q')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=437&amp;aid=0000273137">
# <img alt="40대 이하 백신 예약…'인증' 하고 '신호등' 기억하세요" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/437/2021/08/06/273137.jpg?type=nf220_140" width="220"/>
# <strong class="r_ico r_vod_large">동영상 기사</strong>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273137', 'airsGParam', '0', 'news_sec_v2.0', 'SD52OVgW56i0QF2Q')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=437&amp;aid=0000273137">40대 이하 백신 예약…'인증' 하고 '신호등' 기억하세요</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273137', 'airsGParam', '0', 'news_sec_v2.0', 'SD52OVgW56i0QF2Q')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=277&amp;aid=0004950060">
# <strong>경남 확진자 127명 추가 발생 … 유흥주점·요양병원·대형마트 감염 속출(종합2보)</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273137', 'airsGParam', '0', 'news_sec_v2.0', 'SD52OVgW56i0QF2Q')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=437&amp;aid=0000273136">
# <strong>첫 확진 뒤 12일간 추가…금산 아동시설 26명 집단감염</strong>
# </a>
# <strong class="r_ico r_vod_txt">동영상기사</strong>
# <span class="writing">JTBC</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138260_000000000000000000273137', 'airsGParam', '0', 'news_sec_v2.0', 'SD52OVgW56i0QF2Q')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=469&amp;aid=0000622266">
# <strong>‘K 백신 허브’ 외쳤건만, 노바백스 미국에서 신청 연기</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# ...
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087472");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="da" id="doubleDA"></div>
# <div class="section" style="margin-bottom:20px;">
# <h4 class="eng_tit">TODAY</h4>
# <em class="today_info">08.06<span class="today_info_day">(금)</span></em>
# <div class="today" id="today_content">
# <div class="today_inner">
# <h5>공지</h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://news.naver.com/main/ombudsman/readView.naver?notiId=575" target="_blank"> <strong>언론사 편집판 심층기획 기사 영역 신설 안내</strong> <i class="list_ico_new">NEW</i> </a> </li>
# </ul>
# </div>
# <div class="today_inner">
# <h5> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=nws_nex&amp;fbm=1&amp;ie=utf8&amp;query=%EC%98%A4%EB%8A%98+%EB%82%A0%EC%94%A8">날씨</a> </h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=mns_nex&amp;fbm=1&amp;ie=utf8&amp;query=%EC%98%A4%EB%8A%98+%EB%82%A0%EC%94%A8" target="_blank"> 실시간 기상 정보 확인하기 <i aria-hidden="true" class="ico_link_arrow"></i> </a> </li>
# </ul>
# </div>
# <div class="today_inner">
# <h5> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?sm=tab_hty.top&amp;where=nexearch&amp;query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;oquery=%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;tqi=UZ%2FB6dpySDVssZJtRR8ssssssE8-265238">운세</a> </h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?sm=tab_hty.top&amp;where=nexearch&amp;query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;oquery=%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;tqi=UZ%2FB6dpySDVssZJtRR8ssssssE8-265238" target="_blank"> 오늘의 띠별 운세 확인하기 <i aria-hidden="true" class="ico_link_arrow"></i> </a> </li>
# </ul>
# </div>
# <div class="today_finance">
# <h5 class="blind">코스피,코스닥 지수</h5>
# <ul>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSPI" target="_blank"> <strong>코스피</strong>
# <div class="num">
#        3,270.36
#       </div>
# <div class="num dn">
# <i>하락</i>5.77
#       </div> </a> </li>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSDAQ" target="_blank"> <strong>코스닥</strong>
# <div class="num">
#        1,059.80
#       </div>
# <div class="num up">
# <i>상승</i>0.26
#       </div> </a> </li>
# </ul>
# </div>
# <form action="https://finance.naver.com/search/search.naver" id="stockForm" method="get" name="right.today.stockForm" onsubmit="return stock_search_1078898(); return false;" target="_blank">
# <fieldset>
# <legend>증권 종목검색</legend>
# <label class="blind" for="stockTodaySearchQuery_1078898">검색어 입력</label>
# <input class="finance_search_input" id="stockTodaySearchQuery_1078898" name="query" placeholder="종목검색" type="text">
# <button class="finance_search_btn nclicks(rig.today)">종목검색</button>
# </input></fieldset>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# function stock_search_1078898() {
# var stockObj = jindo.$('stockTodaySearchQuery_1078898');
# var searchQuery = stockObj.value.replace(/[ ]/g, "");
# stockObj.value = searchQuery;
# if (searchQuery == '') {
# alert("검색 조건이 없습니다.");
# return false;
# }
# }
# </script>
# <div class="section">
# <h4>만평</h4>
# <div class="img_rolling v1" id="rightOpinionCartoonPhoto4_1078954">
# <div class="_1" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#081_0003207173"> <img alt="[만평] 조기영 세상터치 2021년 8월 6일" height="180" src="https://mimgnews.pstatic.net/image/origin/081/2021/08/06/3207173.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">서울신문</span> </span> </span> </img></a>
# </div>
# <div class="_2" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#088_0000715505"> <img alt="[매일희평] 대선앞두고  대북채널 혼선정리??" height="180" src="https://mimgnews.pstatic.net/image/origin/088/2021/08/05/715505.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">매일신문</span> </span> </span> </img></a>
# </div>
# <div class="_3" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#028_0002555614"> <img alt="8월 6일 한겨레 그림판" height="180" src="https://mimgnews.pstatic.net/image/origin/028/2021/08/05/2555614.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">한겨레</span> </span> </span> </img></a>
# </div>
# <div class="_4" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#032_0003090195"> <img alt="2021년 8월 6일 [김용민의 그림마당]" height="180" src="https://mimgnews.pstatic.net/image/origin/032/2021/08/05/3090195.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">경향신문</span> </span> </span> </img></a>
# </div>
# <ul style="display: none;">
# </ul>
# <ul class="_temp" style="display: none;">
#    shuffle 이전 위치
#    <li class="_1"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#081_0003207173"> <img alt="[만평] 조기영 세상터치 2021년 8월 6일" height="45" src="https://mimgnews.pstatic.net/image/origin/081/2021/08/06/3207173.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_2"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#088_0000715505"> <img alt="[매일희평] 대선앞두고  대북채널 혼선정리??" height="45" src="https://mimgnews.pstatic.net/image/origin/088/2021/08/05/715505.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_3"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#028_0002555614"> <img alt="8월 6일 한겨레 그림판" height="45" src="https://mimgnews.pstatic.net/image/origin/028/2021/08/05/2555614.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_4"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#032_0003090195"> <img alt="2021년 8월 6일 [김용민의 그림마당]" height="45" src="https://mimgnews.pstatic.net/image/origin/032/2021/08/05/3090195.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# </ul>
# </div>
# <a class="more_link" href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307" title="만평 더보기"><span class="blind">만평</span>더보기</a>
# </div>
# <script type="text/javascript">
# (function () {
# rightOpinionCartoonPhoto4 = {
# _weHighLighted: null,
# _nIntervarlId: null,
# init: function (sId) {
# this.elContainer = jindo.$(sId);
# if (!this.elContainer) {
# return;
# }
# this.assign();
# this.shuffle();
# this.attach();
# },
# assign: function () {
# this.waDiv = jindo.$ElementList(jindo.$$('div', this.elContainer));
# this.weUl = jindo.$Element(jindo.$$.getSingle('ul', this.elContainer));
# },
# shuffle: function () {
# var weUl = this.weUl;
# var waLiTemp = jindo.$A(jindo.$$('ul._temp li', this.elContainer));
# var waShuffledLi = waLiTemp.shuffle();
# waShuffledLi.forEach(function (v, i, a) {
# weUl.append(v);
# });
# this.change(waShuffledLi.get(0));
# weUl.show();
# },
# attach: function () {
# var aLi = jindo.$$('li', this.weUl.$value());
# jindo.$Fn(this.choose, this).attach(aLi, 'mouseenter');
# },
# choose: function (event) {
# this.change(event.currentElement);
# },
# change: function (el) {
# this.showDivByClassName(jindo.$S(el.className.replace('on', '')).trim().toString());
# this.toggleHighlight(el);
# },
# showDivByClassName: function (sClassName) {
# var sCssQuery = 'div.' + sClassName;
# var weDiv = jindo.$Element(jindo.$$.getSingle(sCssQuery, this.elContainer));
# this.waDiv.hide();
# weDiv.show();
# },
# toggleHighlight: function (el) {
# if (this._weHighLighted) {
# this._weHighLighted.removeClass('on');
# }
# this._weHighLighted = jindo.$Element(el);
# this._weHighLighted.addClass('on');
# },
# next: function () {
# var weLi = this.weUl.child(function (v) {
# return v.hasClass('on');
# })[0];
# var weNextLi = weLi.next();
# if (!weNextLi) {
# weNextLi = this.weUl.first();
# }
# this.change(weNextLi.$value());
# }
# }
# rightOpinionCartoonPhoto4.init('rightOpinionCartoonPhoto4_1078954');
# })();
# </script>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/182956245_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="da" id="rightDoubleDA" style="display: none"></div>
# <script type="text/javascript">
#             try{
#                 jindo.$("doubleDA").innerHTML = '<div id="daHome_300250" name="daHome_300250" style="width: 300px; height: 250px;"><iframe id="home300250" name="home300250" src="https://veta.naver.com/fxshow?su=SU10306&calp=home" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_뉴스홈_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#             }catch(e){}
#         </script>
# <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div></div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.naver">마이스크랩</a>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#
#
#
# news.home.DragController.init();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </div>
# </body>
# </html>

# %%
# 헤드라인 뉴스의 구성 ul , class : hdline_article_list

news_list = bs_obj.find("ul", {"class":"hdline_article_list"})

# news_list


lis = news_list.findAll("li")

for li in lis :
    a_tag = li.find("a")
    print(a_tag.text.strip())
# Out:
# “노바백스 도입 안 돼도 올해 접종 차질 없어”…렘데시비르, 변이 11종 모두 효과
# '폭염 속 사투' 소방관 격려...文 "소방관 안전도 중요"
# 롯데쇼핑, 2분기 영업익 76억…"송도롯데몰 세금 일시적 반영"(종합)
# “자영업자 목소리가 불법이면 거리에 나앉아 죽으란거냐” 자영업 비대위 대표 경찰 소환
# 카카오, 또 최대 실적…여민수 공동대표 “구독 생태계 확장”

# %%
# 관련기사 링크 list 에 저장
link_list = []
for li in lis :
    a_tag = li.find("a")
    link_list.append("https://news.naver.com/" + a_tag["href"])

print(link_list)
# Out:
# ['https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=056&aid=0011096795', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=100&oid=052&aid=0001624085', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004950004', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=023&aid=0003631987', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=101&oid=005&aid=0001462628']

# %% [markdown]
# ### 연습문제
# - 네이버 뉴스 메인페이지의 5개 섹션의 헤드라인 기사의 타이틀

# %%
import requests

headers ={"User-Agent" : 
          "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}

url = "https://news.naver.com/"
res = requests.get(url,headers=headers)
bs_obj = bs4.BeautifulSoup(html,"html.parser")

# %%
# 수집 데이터 저장할 list
title_list = []
link_list = []
section_list = []

sections = ["헤드라인","정치", "경제", "사회", "생활/문화", "세계", "IT/과학"]
# 7개 섹션 기사를 모두 담고 있는 영역 : div id=main_content 추출

main_cont = bs_obj.find(id="main_content")
uls =  main_cont.findAll("ul")
len(uls)

# main_cont > 섹션 별 ul 태그 > 각 ul 마다 5개시끼 li 태그 > li 태그의 a 추출

for k in range(len(uls)) : # 각 ul의 index 값 : k 변수에 저장 (0 ~ 6)
    lis = uls[k].findAll("li") # 한개의 ul 태그내 모든 li 태그를 추출
    
    for li in lis : # li 한개씩 li 변수에 대입
        a_tag = li.find("a")
        title_list.append(a_tag.text.strip())
        if (k < 1):
            link_list.append("https://news.naver.com" + a_tag["href"])
        else :
            link_list.append(a_tag["href"])
        section_list.append(sections[k])

# %%
link_list[0]
# Out:
# 'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=056&aid=0011096795'

# %%
import pandas as pd
col_dict = {"section" : section_list, "news_title": title_list, "link_url": link_list}

news_df = pd.DataFrame(col_dict)
news_df
# Out:
#    section                                         news_title  \
# 0     헤드라인     “노바백스 도입 안 돼도 올해 접종 차질 없어”…렘데시비르, 변이 11종 모두 효과
# 1     헤드라인                  '폭염 속 사투' 소방관 격려...文 "소방관 안전도 중요"
# 2     헤드라인            롯데쇼핑, 2분기 영업익 76억…"송도롯데몰 세금 일시적 반영"(종합)
# 3     헤드라인    “자영업자 목소리가 불법이면 거리에 나앉아 죽으란거냐” 자영업 비대위 대표 경찰 소환
# 4     헤드라인                  카카오, 또 최대 실적…여민수 공동대표 “구독 생태계 확장”
# 5       정치        홍준표 “朴 전 대통령 잡아 넣은 윤석열, TK서 '압도적 지지' 기가 막혀”
# 6       정치                       “지도부가 주인공 아니다”…제동 걸린 이준석표 경선
# 7       정치                      최재형 “박근혜 즉각 사면해야”…윤석열 ‘화법 교정’
# 8       정치     ‘北 지령받고 美스텔스기 반대’ 4명에 간첩죄 혐의 적용… 野 “文대통령 해명하라”
# 9       정치         '전과 공방' 진흙탕 싸움 …이재명 "李 공개할 차례" 이낙연측 "적반하장"
# 10      경제      "2.6억 아파트, 주담대 6억까지"…금융당국 뒷짐 진 사이 대출 시장 '대혼란'
# 11      경제                 상장 첫 날 상한가 친 카뱅…임직원 총 평가차익 '5700억'
# 12      경제                       40~50대 위중증 환자 급증…노바백스 도입 빨간불
# 13      경제           내년 외항선 LNG 수입부과금 면제…선박 주유소 ‘LNG 벙커링’ 키운다
# 14      경제              [美친주] 모더나, 호실적에도 주가 빠진 이유… 백신 판매량 때문?
# 15      사회     경남 확진자 127명 추가 발생 … 유흥주점·요양병원·대형마트 감염 속출(종합2보)
# 16      사회                    첫 확진 뒤 12일간 추가…금산 아동시설 26명 집단감염
# 17      사회                    ‘K 백신 허브’ 외쳤건만, 노바백스 미국에서 신청 연기
# 18      사회              30대 女보육교사 화이자 2차접종 다음날 숨져… “인과성 조사 중”
# 19      사회  [주진우 라이브] 중수본 “4단계 해도 확진자 줄어들지 않는 이유…델타 변이 빠른 ...
# 20   생활/문화                   [날씨] 주말 '35도 안팎' 폭염 지속…내륙 강한 소나기
# 21   생활/문화                         칼슘, 비타민D...슬기로운 갱년기를 위한 비결
# 22   생활/문화                                 마을 앞바다 해저 보물선을 찾아라
# 23   생활/문화                      김연경, 무슨 말이 필요해? 모두 널 작품이라고 불러
# 24   생활/문화                    [날씨] 주말이 열대야·무더위 고비...내주 기세 꺾인다
# 25      세계                일본 신규 확진자 1만 5645명…누적 확진자 100만 명 넘어
# 26      세계  불붙는 미중 '백신외교' 경쟁... 美 "1억1000만분 기부" vs 中 "20억회...
# 27      세계                 2만8000년 전 ‘동굴사자’ 미라 발견…손상 없이 완벽 보존
# 28      세계               WSJ "中 '빅테크 때리기' 속 메이퇀에 벌금 10억달러 부과"
# 29      세계                          일본 코로나19 누적 확진자 100만명 넘었다
# 30   IT/과학           [르포] '메타버스'로 열린 정부 행사…"안 보여요, 안 들려요" 아우성
# 31   IT/과학              [이주의 바이오 키워드] #백신 양극화 #백신 가격인상 #백신 강국
# 32   IT/과학                 시중銀 방치 '56억 예금' 끌어안은 카카오뱅크…1조 포식하나
# 33   IT/과학          "이러다 가상 인간끼리 연애 할라"…로지 김래아 열풍에 꽃미남 버전 나온다
# 34   IT/과학                  “올해 백신 주문 더 안받아요”…모더나, 콧대 높을 만 했다
#
#                                              link_url
# 0   https://news.naver.com/main/read.naver?mode=LS...
# 1   https://news.naver.com/main/read.naver?mode=LS...
# 2   https://news.naver.com/main/read.naver?mode=LS...
# 3   https://news.naver.com/main/read.naver?mode=LS...
# 4   https://news.naver.com/main/read.naver?mode=LS...
# 5   https://news.naver.com/main/read.naver?mode=LS...
# 6   https://news.naver.com/main/read.naver?mode=LS...
# 7   https://news.naver.com/main/read.naver?mode=LS...
# 8   https://news.naver.com/main/read.naver?mode=LS...
# 9   https://news.naver.com/main/read.naver?mode=LS...
# 10  https://news.naver.com/main/read.naver?mode=LS...
# 11  https://news.naver.com/main/read.naver?mode=LS...
# 12  https://news.naver.com/main/read.naver?mode=LS...
# 13  https://news.naver.com/main/read.naver?mode=LS...
# 14  https://news.naver.com/main/read.naver?mode=LS...
# 15  https://news.naver.com/main/read.naver?mode=LS...
# 16  https://news.naver.com/main/read.naver?mode=LS...
# 17  https://news.naver.com/main/read.naver?mode=LS...
# 18  https://news.naver.com/main/read.naver?mode=LS...
# 19  https://news.naver.com/main/read.naver?mode=LS...
# 20  https://news.naver.com/main/read.naver?mode=LS...
# 21  https://news.naver.com/main/read.naver?mode=LS...
# 22  https://news.naver.com/main/read.naver?mode=LS...
# 23  https://news.naver.com/main/read.naver?mode=LS...
# 24  https://news.naver.com/main/read.naver?mode=LS...
# 25  https://news.naver.com/main/read.naver?mode=LS...
# 26  https://news.naver.com/main/read.naver?mode=LS...
# 27  https://news.naver.com/main/read.naver?mode=LS...
# 28  https://news.naver.com/main/read.naver?mode=LS...
# 29  https://news.naver.com/main/read.naver?mode=LS...
# 30  https://news.naver.com/main/read.naver?mode=LS...
# 31  https://news.naver.com/main/read.naver?mode=LS...
# 32  https://news.naver.com/main/read.naver?mode=LS...
# 33  https://news.naver.com/main/read.naver?mode=LS...
# 34  https://news.naver.com/main/read.naver?mode=LS...

# %%
news_df.to_csv("./crawl_data/naver_news.csv")
